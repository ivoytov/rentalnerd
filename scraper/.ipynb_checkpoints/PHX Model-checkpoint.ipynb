# %%
# %load_ext sql

import statsmodels.api as sma
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import datetime
from scipy import stats

import fiona
import shapely as shapely
from geopandas import GeoSeries, GeoDataFrame
from shapely.geometry import Point
from shapely.geometry import asShape
from time import gmtime, strftime

# imports
import pandas as pd
import matplotlib.pyplot as plt
import csv

# follow the usual sklearn pattern: import, instantiate, fit
from sklearn.linear_model import LinearRegression
import numpy as np

# from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

import statsmodels.formula.api as sm

# this allows plots to appear directly in the notebook
# %matplotlib inline
# Out:
# /Users/garyjob/Applications/rentalnerd/venv/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /Users/garyjob/Applications/rentalnerd/venv/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %sql mysql://prod:nerd@52.2.153.189/rental_nerd
# Out:
# Format: (postgresql|mysql)://username:password@hostname/dbname, or one of dict_keys([])
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-9416836b0f2d> in <module>()
# ----> 1 get_ipython().magic('sql mysql://prod:nerd@52.2.153.189/rental_nerd')
#       2
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# <decorator-gen-125> in execute(self, line, cell, local_ns)
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# <decorator-gen-124> in execute(self, line, cell, local_ns)
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      73
#      74         parsed = sql.parse.parse('%s\n%s' % (line, cell), self)
# ---> 75         conn = sql.connection.Connection.get(parsed['connection'])
#      76         first_word = parsed['sql'].split(None, 1)[:1]
#      77         if first_word and first_word[0].lower() == 'persist':
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/sql/connection.py in get(cls, descriptor)
#      30                 cls.current = conn
#      31             else:
# ---> 32                 cls.current = Connection(descriptor)
#      33         if cls.current:
#      34             return cls.current
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/sql/connection.py in __init__(self, connect_str)
#      10     def __init__(self, connect_str=None):
#      11         try:
# ---> 12             engine = sqlalchemy.create_engine(connect_str)
#      13         except: # TODO: bare except; but what's an ArgumentError?
#      14             print(self.tell_format())
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     384     strategy = kwargs.pop('strategy', default_strategy)
#     385     strategy = strategies.strategies[strategy]
# --> 386     return strategy.create(*args, **kwargs)
#     387
#     388
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      73                 if k in kwargs:
#      74                     dbapi_args[k] = pop_kwarg(k)
# ---> 75             dbapi = dialect_cls.dbapi(**dbapi_args)
#      76
#      77         dialect_args['dbapi'] = dbapi
#
# /Users/garyjob/Applications/rentalnerd/venv/lib/python3.4/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in dbapi(cls)
#      90     @classmethod
#      91     def dbapi(cls):
# ---> 92         return __import__('MySQLdb')
#      93
#      94     def do_executemany(self, cursor, statement, parameters, context=None):
#
# ImportError: No module named 'MySQLdb'

# %%
result = %sql (SELECT \
properties.address, \
properties.bedrooms, \
properties.bathrooms, \
properties.sqft, \
properties.source, \
properties.origin_url, \
properties.longitude, \
properties.latitude, \
properties.elevation, \
properties.year_built, \
properties.garage, \
properties.level, \
property_transactions.transaction_type, \
property_transaction_logs.price, \
property_transaction_logs.transaction_status, \
property_transaction_logs.days_on_market, \
property_transaction_logs.date_closed, \
property_transaction_logs.date_listed, \
neighborhoods.name as 'neighborhood', \
neighborhoods.id as 'nid', \
neighborhoods.shapefile_source \
FROM \
properties, \
property_transactions, \
property_transaction_logs, \
property_neighborhoods, \
neighborhoods \
WHERE \
properties.id = property_transactions.property_id AND \
property_transactions.property_transaction_log_id = property_transaction_logs.id AND \
property_transactions.transaction_type = "rental" AND \
neighborhoods.shapefile_source = "PH" AND \
properties.id = property_neighborhoods.property_id AND \
property_neighborhoods.neighborhood_id = neighborhoods.id)
        
data = result.DataFrame()
# Out:
# ERROR: Line magic function `%sql` not found.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-d372c11222e4> in <module>()
#       1 result = get_ipython().magic('sql (SELECT properties.address, properties.bedrooms, properties.bathrooms, properties.sqft, properties.source, properties.origin_url, properties.longitude, properties.latitude, properties.elevation, properties.year_built, properties.garage, properties.level, property_transactions.transaction_type, property_transaction_logs.price, property_transaction_logs.transaction_status, property_transaction_logs.days_on_market, property_transaction_logs.date_closed, property_transaction_logs.date_listed, neighborhoods.name as \'neighborhood\', neighborhoods.id as \'nid\', neighborhoods.shapefile_source FROM properties, property_transactions, property_transaction_logs, property_neighborhoods, neighborhoods WHERE properties.id = property_transactions.property_id AND property_transactions.property_transaction_log_id = property_transaction_logs.id AND property_transactions.transaction_type = "rental" AND neighborhoods.shapefile_source = "PH" AND properties.id = property_neighborhoods.property_id AND property_neighborhoods.neighborhood_id = neighborhoods.id)')
#       2
# ----> 3 data = result.DataFrame()
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'

# %%
from time import gmtime, strftime
result.csv(filename=strftime("%Y%m%d")+ " PHX rentals.csv")
# Out:
# CSV results at /Users/ilya/Dropbox/Coding Projects/rentalnerd/scraper/20151121 PHX rentals.csv

# %%
# fill NaN values with some reasonable defaults
data.garage = data.garage.fillna(True)
data.year_built = data.year_built.fillna(1980)

data.head()
# Out:
#                                     address  bedrooms  bathrooms  sqft  \
# 0       3726 W Denton Ln, Phoenix, AZ 85019         4          2  1733
# 1      4017 E Burgess Ln, Phoenix, AZ 85042         3          2  1331
# 2  4001 W Villa Rita Dr, Glendale, AZ 85308         3          2  1397
# 3  4541 W Bluefield Ave, Glendale, AZ 85308         4          2  2620
# 4        13624 N 44th Pl, Phoenix, AZ 85032         3          2  1468
#
#       source                                         origin_url  longitude  \
# 0  zillow_ph  http://www.zillow.com/homedetails/3726-W-Dento...   -112.140
# 1  zillow_ph  http://www.zillow.com/homedetails/4017-E-Burge...   -111.995
# 2  zillow_ph  http://www.zillow.com/homedetails/4001-W-Villa...   -112.145
# 3  zillow_ph  http://www.zillow.com/homedetails/4541-W-Bluef...   -112.158
# 4  zillow_ph  http://www.zillow.com/homedetails/13624-N-44th...   -111.986
#
#    latitude  elevation  year_built        ...         level  transaction_type  \
# 0   33.5162    350.530        1980        ...             1            rental
# 1   33.3898    352.617        1980        ...             1            rental
# 2   33.6503    400.324        1980        ...             1            rental
# 3   33.6518    396.672        1980        ...             1            rental
# 4   33.6107    429.627        1980        ...             1            rental
#
#   price  transaction_status days_on_market  date_closed date_listed  \
# 0   995                open            NaN         None  2015-08-18
# 1   895                open            NaN         None  2015-08-11
# 2  1150                open            NaN         None  2015-08-14
# 3  1600                open            NaN         None  2015-08-13
# 4  1575                open            NaN         None  2015-08-21
#
#       neighborhood  nid  shapefile_source
# 0        Alahambra  201                PH
# 1   South Mountain  151                PH
# 2      Deer Valley  307                PH
# 3      Deer Valley  307                PH
# 4  Paradise Valley  288                PH
#
# [5 rows x 21 columns]

# %%
import datetime

Date_final = [0.1] * len(data)

for x in range(0,len(data)):
    data
    if data["date_closed"][x] is not None :
        # print " row: "+ `x` + ": using date_rented"
        # data.ix['Date_final',x]
        Date_final[x] = data["date_closed"][x]
        
    elif data["date_listed"][x] is not None :
        # print " row: "+ `x` + ": using date_listed"
        Date_final[x] = data["date_listed"][x]
    else:
        Date_final[x] = data["date_closed"][2]
        print " row: "+ `x` + ": we are screwed"



data['date'] = pd.to_datetime(Date_final)

data.head()
# Out:
#                                     address  bedrooms  bathrooms  sqft  \
# 0       3726 W Denton Ln, Phoenix, AZ 85019         4          2  1733
# 1      4017 E Burgess Ln, Phoenix, AZ 85042         3          2  1331
# 2  4001 W Villa Rita Dr, Glendale, AZ 85308         3          2  1397
# 3  4541 W Bluefield Ave, Glendale, AZ 85308         4          2  2620
# 4        13624 N 44th Pl, Phoenix, AZ 85032         3          2  1468
#
#       source                                         origin_url  longitude  \
# 0  zillow_ph  http://www.zillow.com/homedetails/3726-W-Dento...   -112.140
# 1  zillow_ph  http://www.zillow.com/homedetails/4017-E-Burge...   -111.995
# 2  zillow_ph  http://www.zillow.com/homedetails/4001-W-Villa...   -112.145
# 3  zillow_ph  http://www.zillow.com/homedetails/4541-W-Bluef...   -112.158
# 4  zillow_ph  http://www.zillow.com/homedetails/13624-N-44th...   -111.986
#
#    latitude  elevation  year_built    ...      transaction_type  price  \
# 0   33.5162    350.530        1980    ...                rental    995
# 1   33.3898    352.617        1980    ...                rental    895
# 2   33.6503    400.324        1980    ...                rental   1150
# 3   33.6518    396.672        1980    ...                rental   1600
# 4   33.6107    429.627        1980    ...                rental   1575
#
#   transaction_status  days_on_market date_closed  date_listed  \
# 0               open             NaN        None   2015-08-18
# 1               open             NaN        None   2015-08-11
# 2               open             NaN        None   2015-08-14
# 3               open             NaN        None   2015-08-13
# 4               open             NaN        None   2015-08-21
#
#       neighborhood  nid shapefile_source       date
# 0        Alahambra  201               PH 2015-08-18
# 1   South Mountain  151               PH 2015-08-11
# 2      Deer Valley  307               PH 2015-08-14
# 3      Deer Valley  307               PH 2015-08-13
# 4  Paradise Valley  288               PH 2015-08-21
#
# [5 rows x 22 columns]

# %%
# create a column of GeoSeries - each house should be represented by a point
pts = GeoSeries([Point(x, y) for x, y in zip(data['longitude'], data['latitude'])])
data['latlong'] = pts

# %%
# filter out any outliers, defined as rent >$10k or >2,500 sq ft, or not in SF

print "Entries before filter: " + `len(data)`
data = data[  (data.sqft <= 5000) 
            & (data.price <= 3000)
            & (data.price != 0) 
            & (data.sqft != 0)
            & ((data.source == 'climbsf_rented') 
               | ((data.date_closed == 'null') & (data.date_listed > datetime.date(2015, 10, 1)) ) # eliminate listings older than 2 months
               | ((data.date_closed != 'null')) )] #include everything closed

print "Entries after filter: " + `len(data)`
data.head()
# Out:
# Entries before filter: 2200
# Entries after filter: 2072
#                                     address  bedrooms  bathrooms  sqft  \
# 0       3726 W Denton Ln, Phoenix, AZ 85019         4          2  1733
# 1      4017 E Burgess Ln, Phoenix, AZ 85042         3          2  1331
# 2  4001 W Villa Rita Dr, Glendale, AZ 85308         3          2  1397
# 3  4541 W Bluefield Ave, Glendale, AZ 85308         4          2  2620
# 4        13624 N 44th Pl, Phoenix, AZ 85032         3          2  1468
#
#       source                                         origin_url  longitude  \
# 0  zillow_ph  http://www.zillow.com/homedetails/3726-W-Dento...   -112.140
# 1  zillow_ph  http://www.zillow.com/homedetails/4017-E-Burge...   -111.995
# 2  zillow_ph  http://www.zillow.com/homedetails/4001-W-Villa...   -112.145
# 3  zillow_ph  http://www.zillow.com/homedetails/4541-W-Bluef...   -112.158
# 4  zillow_ph  http://www.zillow.com/homedetails/13624-N-44th...   -111.986
#
#    latitude  elevation  year_built            ...             price  \
# 0   33.5162    350.530        1980            ...               995
# 1   33.3898    352.617        1980            ...               895
# 2   33.6503    400.324        1980            ...              1150
# 3   33.6518    396.672        1980            ...              1600
# 4   33.6107    429.627        1980            ...              1575
#
#    transaction_status days_on_market  date_closed date_listed  \
# 0                open            NaN         None  2015-08-18
# 1                open            NaN         None  2015-08-11
# 2                open            NaN         None  2015-08-14
# 3                open            NaN         None  2015-08-13
# 4                open            NaN         None  2015-08-21
#
#       neighborhood  nid shapefile_source       date                   latlong
# 0        Alahambra  201               PH 2015-08-18   POINT (-112.14 33.5162)
# 1   South Mountain  151               PH 2015-08-11  POINT (-111.995 33.3898)
# 2      Deer Valley  307               PH 2015-08-14  POINT (-112.145 33.6503)
# 3      Deer Valley  307               PH 2015-08-13  POINT (-112.158 33.6518)
# 4  Paradise Valley  288               PH 2015-08-21  POINT (-111.986 33.6107)
#
# [5 rows x 23 columns]

# %%
data.hist(column=['bathrooms','bedrooms','price','garage','level','year_built','sqft','elevation'],figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1112a9b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e32a790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e3b2f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10d773790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e233810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e280d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11186ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1118f5c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111966690>]], dtype=object)

# %%
age = 2015 - data.year_built 
age.name = 'age'
data = pd.concat([data,age],axis=1)

# %%
result = sm.ols(formula="price ~ bedrooms + bathrooms + level + garage + age + elevation + neighborhood:sqft -1", data=data).fit()
print result.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     612.8
# Date:                Sat, 21 Nov 2015   Prob (F-statistic):               0.00
# Time:                        11:51:01   Log-Likelihood:                -14797.
# No. Observations:                2072   AIC:                         2.973e+04
# Df Residuals:                    2006   BIC:                         3.010e+04
# Df Model:                          66
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------------
# bedrooms                                   -25.0929     12.012     -2.089      0.037       -48.651    -1.535
# bathrooms                                  101.7101     17.262      5.892      0.000        67.856   135.564
# level                                        5.2268      2.770      1.887      0.059        -0.205    10.659
# garage                                      27.9554     14.485      1.930      0.054        -0.452    56.363
# age                                         -2.2212      0.628     -3.537      0.000        -3.453    -0.990
# elevation                                    1.1256      0.093     12.072      0.000         0.943     1.308
# neighborhood[Ahwatukee Foothills 0]:sqft     0.5535      0.024     22.772      0.000         0.506     0.601
# neighborhood[Alahambra]:sqft                 0.4775      0.030     15.959      0.000         0.419     0.536
# neighborhood[Alegre Community]:sqft          0.3981      0.362      1.099      0.272        -0.312     1.108
# neighborhood[Alta Mira]:sqft                 0.5452      0.096      5.680      0.000         0.357     0.733
# neighborhood[Baseline-Hardy]:sqft            0.5158      0.098      5.251      0.000         0.323     0.708
# neighborhood[Bell De Mar Crossing]:sqft      0.5408      0.105      5.154      0.000         0.335     0.747
# neighborhood[Camelback East]:sqft            0.7268      0.028     26.322      0.000         0.673     0.781
# neighborhood[Central]:sqft                   0.4351      0.042     10.291      0.000         0.352     0.518
# neighborhood[Central City]:sqft              0.5578      0.044     12.671      0.000         0.471     0.644
# neighborhood[Cyprus Southwest]:sqft          0.6515      0.078      8.326      0.000         0.498     0.805
# neighborhood[Daley Park]:sqft                0.6071      0.180      3.369      0.001         0.254     0.960
# neighborhood[Dava-Lakeshore]:sqft            0.6131      0.157      3.913      0.000         0.306     0.920
# neighborhood[Deer Valley]:sqft               0.4486      0.022     20.092      0.000         0.405     0.492
# neighborhood[Desert View]:sqft               0.6187      0.027     23.341      0.000         0.567     0.671
# neighborhood[Encanto]:sqft                   0.6191      0.034     18.260      0.000         0.553     0.686
# neighborhood[Escalante]:sqft                 0.4790      0.214      2.239      0.025         0.059     0.899
# neighborhood[Estrella]:sqft                  0.3602      0.028     12.705      0.000         0.305     0.416
# neighborhood[Evergreen]:sqft                 0.6193      0.133      4.664      0.000         0.359     0.880
# neighborhood[Gililland]:sqft                 0.4483      0.106      4.212      0.000         0.240     0.657
# neighborhood[Holdeman]:sqft                  0.6142      0.161      3.823      0.000         0.299     0.929
# neighborhood[Hughes Acres]:sqft              0.6086      0.108      5.652      0.000         0.397     0.820
# neighborhood[Jen Tilly Terrace]:sqft         0.2869      0.532      0.539      0.590        -0.757     1.331
# neighborhood[Kiwanis Park]:sqft              0.4480      0.144      3.104      0.002         0.165     0.731
# neighborhood[Kyrene-Superstition]:sqft       0.6021      0.245      2.460      0.014         0.122     1.082
# neighborhood[Laveen]:sqft                    0.3462      0.023     14.976      0.000         0.301     0.391
# neighborhood[Lindon Park]:sqft               0.5212      0.208      2.502      0.012         0.113     0.930
# neighborhood[Mach 8]:sqft                    0.6567      0.111      5.899      0.000         0.438     0.875
# neighborhood[Maple-Ash]:sqft                 0.8783      0.147      5.968      0.000         0.590     1.167
# neighborhood[Maryvale]:sqft                  0.3699      0.028     13.179      0.000         0.315     0.425
# neighborhood[McClintock]:sqft                0.5545      0.172      3.219      0.001         0.217     0.892
# neighborhood[Meyer Park]:sqft                0.6597      0.112      5.909      0.000         0.441     0.879
# neighborhood[Mitchell Park West]:sqft        0.5192      0.218      2.384      0.017         0.092     0.946
# neighborhood[New Village]:sqft               0.3101      0.069      4.463      0.000         0.174     0.446
# neighborhood[North Gateway]:sqft             0.4313      0.035     12.231      0.000         0.362     0.500
# neighborhood[North Mountain]:sqft            0.4731      0.025     18.789      0.000         0.424     0.522
# neighborhood[North Scottsdale]:sqft          0.7464      0.025     30.357      0.000         0.698     0.795
# neighborhood[Northeast 0]:sqft               0.4551      0.029     15.601      0.000         0.398     0.512
# neighborhood[Northeast 3]:sqft               0.3887      0.106      3.670      0.000         0.181     0.596
# neighborhood[Northeast 4]:sqft               0.3295      0.306      1.077      0.282        -0.270     0.929
# neighborhood[Northwest]:sqft                 0.3259      0.033      9.893      0.000         0.261     0.391
# neighborhood[Ntna-College]:sqft              0.6036      0.123      4.895      0.000         0.362     0.845
# neighborhood[Ntna-Indian Bend]:sqft          0.6595      0.188      3.499      0.000         0.290     1.029
# neighborhood[Ntna-West Rio]:sqft             0.4964      0.334      1.488      0.137        -0.158     1.150
# neighborhood[Optimist Park Ne]:sqft          0.5709      0.143      3.980      0.000         0.290     0.852
# neighborhood[Optimist Park Sw]:sqft          0.5085      0.185      2.754      0.006         0.146     0.871
# neighborhood[Paradise Valley]:sqft           0.5806      0.023     25.079      0.000         0.535     0.626
# neighborhood[Pepperwood]:sqft                0.5825      0.108      5.377      0.000         0.370     0.795
# neighborhood[Pinnacle Peak]:sqft             0.6150      0.051     12.150      0.000         0.516     0.714
# neighborhood[Riverside]:sqft                 0.7375      0.145      5.090      0.000         0.453     1.022
# neighborhood[Rural-Geneva]:sqft              0.3417      0.448      0.763      0.445        -0.536     1.220
# neighborhood[Shalimar]:sqft                  0.4881      0.169      2.896      0.004         0.158     0.819
# neighborhood[South Mountain]:sqft            0.4134      0.026     15.711      0.000         0.362     0.465
# neighborhood[South Scottsdale]:sqft          0.8081      0.027     30.378      0.000         0.756     0.860
# neighborhood[Southeast 0]:sqft               0.4852      0.027     18.261      0.000         0.433     0.537
# neighborhood[Southwest]:sqft                 0.4816      0.037     13.191      0.000         0.410     0.553
# neighborhood[Sunburst Farms]:sqft            0.7513      0.137      5.500      0.000         0.483     1.019
# neighborhood[Sunset]:sqft                    0.8405      0.113      7.466      0.000         0.620     1.061
# neighborhood[Tempe Gardens]:sqft             0.6031      0.137      4.395      0.000         0.334     0.872
# neighborhood[Tempe Royal Estates]:sqft       0.4583      0.174      2.634      0.009         0.117     0.800
# neighborhood[West Central]:sqft              0.4821      0.049      9.868      0.000         0.386     0.578
# ==============================================================================
# Omnibus:                      720.629   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5317.276
# Skew:                           1.440   Prob(JB):                         0.00
# Kurtosis:                      10.300   Cond. No.                     1.50e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %%
output = [['neighborhood','regular']]
table = ListTable()
table.append(output[0])

for row in data.neighborhood.unique():
    output_row = [row, '99']
    for i in result.params.index:
        if 'neighborhood' not in i: continue

        if 'neighborhood[' + row + ']' in i:
            output_row[1] = `result.params[i]`
            output.append(output_row)
            table.append(output_row)

table
# Out:
# [['neighborhood', 'regular'],
#  ['Alahambra', '0.47752805887178468'],
#  ['South Mountain', '0.41343746089236089'],
#  ['Deer Valley', '0.44856731998568433'],
#  ['Paradise Valley', '0.58055069048988106'],
#  ['North Mountain', '0.47310322068353339'],
#  ['Ahwatukee Foothills 0', '0.55354358479120214'],
#  ['Desert View', '0.6187191072802749'],
#  ['Encanto', '0.61912583121354403'],
#  ['Maryvale', '0.36989703686324404'],
#  ['Laveen', '0.34615063055376494'],
#  ['Estrella', '0.36015306500134059'],
#  ['North Gateway', '0.43132744549321528'],
#  ['Camelback East', '0.72684622610985705'],
#  ['New Village', '0.31007231021295123'],
#  ['Central City', '0.55775879644731696'],
#  ['North Scottsdale', '0.7464467147459658'],
#  ['Southwest', '0.48159198083295762'],
#  ['Northeast 0', '0.45506573648222925'],
#  ['South Scottsdale', '0.80809270195624561'],
#  ['Northwest', '0.3259212672328009'],
#  ['Shalimar', '0.48808590455033873'],
#  ['West Central', '0.48214182254192095'],
#  ['Central', '0.43505449605052338'],
#  ['Hughes Acres', '0.6085811703494719'],
#  ['Southeast 0', '0.48523214824968608'],
#  ['Cyprus Southwest', '0.65145848689373653'],
#  ['Sunset', '0.84053882086001941'],
#  ['Riverside', '0.73746093234359522'],
#  ['Rural-Geneva', '0.34173903817073437'],
#  ['Gililland', '0.44826588032903614'],
#  ['Ntna-College', '0.60356998041059096'],
#  ['Optimist Park Ne', '0.57094404364827012'],
#  ['Baseline-Hardy', '0.51575602597854986'],
#  ['Kiwanis Park', '0.44804746566254927'],
#  ['Meyer Park', '0.65973736636215163'],
#  ['Mach 8', '0.65670045196307081'],
#  ['Pepperwood', '0.5825386579148788'],
#  ['Optimist Park Sw', '0.50847889466812024'],
#  ['Holdeman', '0.61415311107828363'],
#  ['Daley Park', '0.60706783326376412'],
#  ['Pinnacle Peak', '0.61500815229638583'],
#  ['Sunburst Farms', '0.75125283662122178'],
#  ['Tempe Royal Estates', '0.45833237842146507'],
#  ['Northeast 3', '0.3887053168644663'],
#  ['Mitchell Park West', '0.5191640098263095'],
#  ['McClintock', '0.55451146709114574'],
#  ['Evergreen', '0.61933061450956273'],
#  ['Bell De Mar Crossing', '0.54076162374524028'],
#  ['Tempe Gardens', '0.60307953839891881'],
#  ['Maple-Ash', '0.87831022138105619'],
#  ['Ntna-West Rio', '0.49639879093403361'],
#  ['Alegre Community', '0.39811412292276338'],
#  ['Dava-Lakeshore', '0.61305912586268185'],
#  ['Escalante', '0.47903315924821754'],
#  ['Ntna-Indian Bend', '0.65950867905010235'],
#  ['Lindon Park', '0.52120689290534017'],
#  ['Kyrene-Superstition', '0.60207406453277612'],
#  ['Northeast 4', '0.32952340891268317'],
#  ['Alta Mira', '0.54522704252421561'],
#  ['Jen Tilly Terrace', '0.28694859766728642']]

# %%
path = 'rentalnerd_importer/lib/tasks/model_files/'


with open(path + 'model_hoods_ph.csv', 'wb') as csvfile:
    hoodwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    
    for i in output:
        hoodwriter.writerow(i)

# %%
dtype = [('Effect', 'S100'), ('Coefficient', float)]

with open(path + 'model_features_ph.csv', 'wb') as csvfile:
    modelwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    header = ['Effect','Coefficient']
    table.append(header)
    modelwriter.writerow(header)
    modelwriter.writerow(['base_rent', 0]) # result.params.Intercept])  hardcode 0 as base rent
    modelwriter.writerow(['bedrooms', result.params.bedrooms])
    modelwriter.writerow(['bathrooms', result.params.bathrooms])
    #modelwriter.writerow(['dist_to_park', result.params.dist_to_park])
    modelwriter.writerow(['elevation', result.params.elevation])
    modelwriter.writerow(['level', result.params.level])
    modelwriter.writerow(['age', result.params.age])
    modelwriter.writerow(['garage', 0]) #result.params.garage])
    modelwriter.writerow(['mean square error of residuals', result.mse_resid])


    
result.cov_params().to_csv(path + 'model_covs_ph.csv')
