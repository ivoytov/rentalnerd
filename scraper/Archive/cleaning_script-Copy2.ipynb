# %%
# %load_ext sql
# %sql mysql://prod:nerd@52.2.153.189/rental_nerd
# %config SqlMagic.feedback=False
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
query = %sql (\
    SELECT \
    id as 'property_id' \
    FROM \
    properties)

i = query.DataFrame().values

# %%
bad_ones = []
i = i[2000000:3000000] # change based on what set of IDs you want

# %%
for property_id in i:
    property_id = property_id[0]
    if property_id % 1000 == 0:
        print("%i property_id processed" % property_id)
        
    query = %sql (\
        SELECT \
        ptl_1.property_id, \
        count(1) as 'bad_instances'\
        FROM \
        property_transaction_logs AS ptl_1, \
        property_transaction_logs AS ptl_2 \
        WHERE \
        ptl_1.`property_id`= ptl_2.`property_id` AND \
        ptl_1.`transaction_type` = ptl_2.`transaction_type` AND \
        ptl_1.id <> ptl_2.id \
        AND \
        ( \
        ( ptl_1.date_listed IS NOT NULL AND \
        ptl_2.date_listed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_1.date_listed < ptl_2.date_listed AND ptl_2.date_listed < ptl_1.date_closed \
        ) \
        OR \
        ( ptl_1.date_listed IS NOT NULL AND \
        ptl_2.date_closed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_1.date_listed < ptl_2.date_closed AND \
        ptl_2.date_closed < ptl_1.date_closed \
        ) \
         OR ( \
        ptl_1.date_listed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_2.date_listed IS NOT NULL AND \
        ptl_2.date_closed IS NOT NULL AND \
        ptl_1.date_listed > ptl_2.date_listed AND \
        ptl_1.date_closed < ptl_2.date_closed ) ) \
        AND \
        ptl_1.property_id = :property_id )
    
    if(query.DataFrame().bad_instances.ix[0] == 1):
        bad_ones.append(property_id)
        f = open('bad_instances_3mm.txt', 'a')
        print(property_id, file=f,flush=False)
        f.close()
# Out:
# 4118000 property_id processed
# 4119000 property_id processed
# 4121000 property_id processed
# 4122000 property_id processed
# 4123000 property_id processed
# 4124000 property_id processed
# 4125000 property_id processed
# 4126000 property_id processed
# 4127000 property_id processed
# 4128000 property_id processed
# 4129000 property_id processed
# 4130000 property_id processed
# 4131000 property_id processed
# 4132000 property_id processed
# 4134000 property_id processed
# 4135000 property_id processed
# 4136000 property_id processed
# 4138000 property_id processed
# 4140000 property_id processed
# 4142000 property_id processed
# 4143000 property_id processed
# 4147000 property_id processed
# 4148000 property_id processed
# 4150000 property_id processed
# 4152000 property_id processed
# 4153000 property_id processed
# 4154000 property_id processed
# 4155000 property_id processed
# 4157000 property_id processed
# 4158000 property_id processed
# 4160000 property_id processed
# 4161000 property_id processed
# 4162000 property_id processed
# 4163000 property_id processed
# 4164000 property_id processed
# 4165000 property_id processed
# 4166000 property_id processed
# 4167000 property_id processed
# 4168000 property_id processed
# 4169000 property_id processed
# 4171000 property_id processed
# 4172000 property_id processed
# 4173000 property_id processed
# 4174000 property_id processed
# 4175000 property_id processed
# 4176000 property_id processed
# 4177000 property_id processed
# 4178000 property_id processed
# 4179000 property_id processed
# 4180000 property_id processed
# 4181000 property_id processed
# 4182000 property_id processed
# 4183000 property_id processed
# 4185000 property_id processed
# 4186000 property_id processed
# 4188000 property_id processed
# 4189000 property_id processed
# 4191000 property_id processed
# 4192000 property_id processed
# 4193000 property_id processed
# 4194000 property_id processed
# 4195000 property_id processed
# 4196000 property_id processed
# 4197000 property_id processed
# 4198000 property_id processed
# 4199000 property_id processed
# 4200000 property_id processed
# 4201000 property_id processed
# 4203000 property_id processed
# 4205000 property_id processed
# 4206000 property_id processed
# 4207000 property_id processed
# 4208000 property_id processed
# 4209000 property_id processed
# 4210000 property_id processed
# 4213000 property_id processed
# 4215000 property_id processed
# 4216000 property_id processed
# 4217000 property_id processed
# 4218000 property_id processed
# 4219000 property_id processed
# 4221000 property_id processed
# 4222000 property_id processed
# 4223000 property_id processed
# 4224000 property_id processed
# 4226000 property_id processed
# 4227000 property_id processed
# 4228000 property_id processed
# 4229000 property_id processed
# 4230000 property_id processed
# 4231000 property_id processed
# 4232000 property_id processed
# 4233000 property_id processed
# 4235000 property_id processed
# 4236000 property_id processed
# 4237000 property_id processed
# 4238000 property_id processed
# 4239000 property_id processed
# 4240000 property_id processed
# 4241000 property_id processed
# 4242000 property_id processed
# 4243000 property_id processed
# 4245000 property_id processed
# 4246000 property_id processed
# 4247000 property_id processed
# 4248000 property_id processed
# 4249000 property_id processed
# 4250000 property_id processed
# 4252000 property_id processed
# 4255000 property_id processed
# 4256000 property_id processed
# 4258000 property_id processed
# 4259000 property_id processed
# 4261000 property_id processed
# 4263000 property_id processed
# 4264000 property_id processed
# 4265000 property_id processed
# 4266000 property_id processed
# 4267000 property_id processed
# 4268000 property_id processed
# 4272000 property_id processed
# 4279000 property_id processed
# 4280000 property_id processed
# 4281000 property_id processed
# 4282000 property_id processed
# 4284000 property_id processed
# 4288000 property_id processed
# 4289000 property_id processed
# 4291000 property_id processed
# 4292000 property_id processed
# 4293000 property_id processed
# 4297000 property_id processed
# 4298000 property_id processed
# 4303000 property_id processed
# 4305000 property_id processed
# 4307000 property_id processed
# 4309000 property_id processed
# 4311000 property_id processed
# 4312000 property_id processed
# 4313000 property_id processed
# 4314000 property_id processed
# 4315000 property_id processed
# 4316000 property_id processed
# 4318000 property_id processed
# 4320000 property_id processed
# 4322000 property_id processed
# 4323000 property_id processed
# 4325000 property_id processed
# 4328000 property_id processed
# 4329000 property_id processed
# 4330000 property_id processed
# 4331000 property_id processed
# 4332000 property_id processed
# 4335000 property_id processed
# 4336000 property_id processed
# 4337000 property_id processed
# 4338000 property_id processed
# 4341000 property_id processed
# 4343000 property_id processed
# 4344000 property_id processed
# 4347000 property_id processed
# 4348000 property_id processed
# 4349000 property_id processed
# 4350000 property_id processed
# 4351000 property_id processed
# 4353000 property_id processed
# 4354000 property_id processed
# 4355000 property_id processed
# 4356000 property_id processed
# 4357000 property_id processed
# 4358000 property_id processed
# 4361000 property_id processed
# 4364000 property_id processed
# 4365000 property_id processed
# 4366000 property_id processed
# 4367000 property_id processed
# 4368000 property_id processed
# 4369000 property_id processed
# 4370000 property_id processed
# 4371000 property_id processed
# 4375000 property_id processed
# 4376000 property_id processed
# 4377000 property_id processed
# 4380000 property_id processed
# 4381000 property_id processed
# 4382000 property_id processed
# 4386000 property_id processed
# 4387000 property_id processed
# 4388000 property_id processed
# 4390000 property_id processed
# 4392000 property_id processed
# 4393000 property_id processed
# 4394000 property_id processed
# 4395000 property_id processed
# 4397000 property_id processed
# 4399000 property_id processed
# 4400000 property_id processed
# 4401000 property_id processed
# 4402000 property_id processed
# 4404000 property_id processed
# 4405000 property_id processed
# 4408000 property_id processed
# 4410000 property_id processed
# 4411000 property_id processed
# 4412000 property_id processed
# 4413000 property_id processed
# 4414000 property_id processed
# 4416000 property_id processed
# 4418000 property_id processed
# 4422000 property_id processed
# 4423000 property_id processed
# 4425000 property_id processed
# 4426000 property_id processed
# 4427000 property_id processed
# 4428000 property_id processed
# 4429000 property_id processed
# 4430000 property_id processed
# 4432000 property_id processed
# 4434000 property_id processed
# 4435000 property_id processed
# 4436000 property_id processed
# 4438000 property_id processed
# 4441000 property_id processed
# 4442000 property_id processed
# 4446000 property_id processed
# 4447000 property_id processed
# 4448000 property_id processed
# 4449000 property_id processed
# 4450000 property_id processed
# 4451000 property_id processed
# 4453000 property_id processed
# 4454000 property_id processed
# 4456000 property_id processed
# 4459000 property_id processed
# 4460000 property_id processed
# 4462000 property_id processed
# 4463000 property_id processed
# 4464000 property_id processed
# 4466000 property_id processed
# 4468000 property_id processed
# 4472000 property_id processed
# 4473000 property_id processed
# 4475000 property_id processed
# 4476000 property_id processed
# 4477000 property_id processed
# 4478000 property_id processed
# 4480000 property_id processed
# 4482000 property_id processed
# 4483000 property_id processed
# 4485000 property_id processed
# 4487000 property_id processed
# 4488000 property_id processed
# 4490000 property_id processed
# 4493000 property_id processed
# 4497000 property_id processed
# 4499000 property_id processed
# 4503000 property_id processed
# 4506000 property_id processed
# 4509000 property_id processed
# 4511000 property_id processed
# 4512000 property_id processed
# 4513000 property_id processed
# 4514000 property_id processed
# 4515000 property_id processed
# 4516000 property_id processed
# 4517000 property_id processed
# 4520000 property_id processed
# 4521000 property_id processed
# 4523000 property_id processed
# 4525000 property_id processed
# 4527000 property_id processed
# 4528000 property_id processed
# 4529000 property_id processed
# 4530000 property_id processed
# 4534000 property_id processed
# 4538000 property_id processed
# 4539000 property_id processed
# 4543000 property_id processed
# 4544000 property_id processed
# 4545000 property_id processed
# 4548000 property_id processed
# 4549000 property_id processed
# 4553000 property_id processed
# 4555000 property_id processed
# 4556000 property_id processed
# 4557000 property_id processed
# 4558000 property_id processed
# 4559000 property_id processed
# 4560000 property_id processed
# 4562000 property_id processed
# 4563000 property_id processed
# 4565000 property_id processed
# 4567000 property_id processed
# 4569000 property_id processed
# 4570000 property_id processed
# 4571000 property_id processed
# 4574000 property_id processed
# 4575000 property_id processed
# 4579000 property_id processed
# 4580000 property_id processed
# 4586000 property_id processed
# 4590000 property_id processed
# 4592000 property_id processed
# 4594000 property_id processed
# 4598000 property_id processed
# 4600000 property_id processed
# 4601000 property_id processed
# 4602000 property_id processed
# 4604000 property_id processed
# 4608000 property_id processed
# 4609000 property_id processed
# 4610000 property_id processed
# 4613000 property_id processed
# 4616000 property_id processed
# 4617000 property_id processed
# 4618000 property_id processed
# 4622000 property_id processed
# 4624000 property_id processed
# 4626000 property_id processed
# 4637000 property_id processed
# 4639000 property_id processed
# 4643000 property_id processed
# 4645000 property_id processed
# 4646000 property_id processed
# 4648000 property_id processed
# 4649000 property_id processed
# 4653000 property_id processed
# 4656000 property_id processed
# 4658000 property_id processed
# 4660000 property_id processed
# 4663000 property_id processed
# 4666000 property_id processed
# 4667000 property_id processed
# 4669000 property_id processed
# 4671000 property_id processed
# 4672000 property_id processed
# 4673000 property_id processed
# 4675000 property_id processed
# 4678000 property_id processed
# 4679000 property_id processed
# 4680000 property_id processed
# 4682000 property_id processed
# 4683000 property_id processed
# 4684000 property_id processed
# 4685000 property_id processed
# 4686000 property_id processed
# 4688000 property_id processed
# 4689000 property_id processed
# 4690000 property_id processed
# 4692000 property_id processed
# 4693000 property_id processed
# 4694000 property_id processed
# 4695000 property_id processed
# 4696000 property_id processed
# 4698000 property_id processed
# 4699000 property_id processed
# 4701000 property_id processed
# 4702000 property_id processed
# 4703000 property_id processed
# 4707000 property_id processed
# 4708000 property_id processed
# 4709000 property_id processed
# 4711000 property_id processed
# 4714000 property_id processed
# 4715000 property_id processed
# 4717000 property_id processed
# 4719000 property_id processed
# 4720000 property_id processed
# 4721000 property_id processed
# 4723000 property_id processed
# 4724000 property_id processed
# 4725000 property_id processed
# 4728000 property_id processed
# 4729000 property_id processed
# 4732000 property_id processed
# 4733000 property_id processed
# 4737000 property_id processed
# 4738000 property_id processed
# 4740000 property_id processed
# 4743000 property_id processed
# 4744000 property_id processed
# 4746000 property_id processed
# 4747000 property_id processed
# 4748000 property_id processed
# 4752000 property_id processed
# 4756000 property_id processed
# 4757000 property_id processed
# 4759000 property_id processed
# 4761000 property_id processed
# 4762000 property_id processed
# 4763000 property_id processed
# 4765000 property_id processed
# 4766000 property_id processed
# 4767000 property_id processed
# 4769000 property_id processed
# 4772000 property_id processed
# 4774000 property_id processed
# 4775000 property_id processed
# 4776000 property_id processed
# 4777000 property_id processed
# 4778000 property_id processed
# 4779000 property_id processed
# 4782000 property_id processed
# 4784000 property_id processed
# 4785000 property_id processed
# 4786000 property_id processed
# 4787000 property_id processed
# 4788000 property_id processed
# 4789000 property_id processed
# 4792000 property_id processed
# 4793000 property_id processed
# 4795000 property_id processed
# 4796000 property_id processed
# 4797000 property_id processed
# 4802000 property_id processed
# 4804000 property_id processed
# 4807000 property_id processed
# 4810000 property_id processed
# 4811000 property_id processed
# 4815000 property_id processed
# 4816000 property_id processed
# 4818000 property_id processed
# 4821000 property_id processed
# 4823000 property_id processed
# 4827000 property_id processed
# 4832000 property_id processed
# 4835000 property_id processed
# 4837000 property_id processed
# 4838000 property_id processed
# 4844000 property_id processed
# 4846000 property_id processed
# 4847000 property_id processed
# 4848000 property_id processed
# 4849000 property_id processed
# 4850000 property_id processed
# 4851000 property_id processed
# 4854000 property_id processed
# 4856000 property_id processed
# 4857000 property_id processed
# 4861000 property_id processed
# 4862000 property_id processed
# 4868000 property_id processed
# 4869000 property_id processed
# 4870000 property_id processed
# 4871000 property_id processed
# 4872000 property_id processed
# 4873000 property_id processed
# 4877000 property_id processed
# 4878000 property_id processed
# 4880000 property_id processed
# 4881000 property_id processed
# 4882000 property_id processed
# 4883000 property_id processed
# 4884000 property_id processed
# 4885000 property_id processed
# 4888000 property_id processed
# 4889000 property_id processed
# 4890000 property_id processed
# 4891000 property_id processed
# 4892000 property_id processed
# 4893000 property_id processed
# 4894000 property_id processed
# 4895000 property_id processed
# 4896000 property_id processed
# 4897000 property_id processed
# 4898000 property_id processed
# 4899000 property_id processed
# 4900000 property_id processed
# 4901000 property_id processed
# 4903000 property_id processed
# 4904000 property_id processed
# 4906000 property_id processed
# 4908000 property_id processed
# 4909000 property_id processed
# 4910000 property_id processed
# 4911000 property_id processed
# 4912000 property_id processed
# 4913000 property_id processed
# 4914000 property_id processed
# 4915000 property_id processed
# 4916000 property_id processed
# 4917000 property_id processed
# 4919000 property_id processed
# 4920000 property_id processed
# 4921000 property_id processed
# 4922000 property_id processed
# 4923000 property_id processed
# 4924000 property_id processed
# 4925000 property_id processed
# 4926000 property_id processed
# 4927000 property_id processed
# 4928000 property_id processed
# 4929000 property_id processed
# 4930000 property_id processed
# 4931000 property_id processed
# 4932000 property_id processed
# 4933000 property_id processed
# 4934000 property_id processed
# 4935000 property_id processed
# 4936000 property_id processed
# 4937000 property_id processed
# 4938000 property_id processed
# 4939000 property_id processed
# 4940000 property_id processed
# 4941000 property_id processed
# 4942000 property_id processed
# 4943000 property_id processed
# 4944000 property_id processed
# 4945000 property_id processed
# 4946000 property_id processed
# 4949000 property_id processed
# 4951000 property_id processed
# 4952000 property_id processed
# 4954000 property_id processed
# 4955000 property_id processed
# 4956000 property_id processed
# 4958000 property_id processed
# 4960000 property_id processed
# 4961000 property_id processed
# 4962000 property_id processed
# 4963000 property_id processed
# 4964000 property_id processed
# 4965000 property_id processed
# 4966000 property_id processed
# 4968000 property_id processed
# 4969000 property_id processed
# 4970000 property_id processed
# 4972000 property_id processed
# 4973000 property_id processed
# 4975000 property_id processed
# 4976000 property_id processed
# 4978000 property_id processed
# 4979000 property_id processed
# 4981000 property_id processed
# 4983000 property_id processed
# 4984000 property_id processed
# 4985000 property_id processed
# 4988000 property_id processed
# 4989000 property_id processed
# 4990000 property_id processed
# 4991000 property_id processed
# 4993000 property_id processed
# 4994000 property_id processed
# 4995000 property_id processed
# 4996000 property_id processed
# 4997000 property_id processed
# 4998000 property_id processed
# 4999000 property_id processed
# 5000000 property_id processed
# 5002000 property_id processed
# 5003000 property_id processed
# 5004000 property_id processed
# 5005000 property_id processed
# 5006000 property_id processed
# 5008000 property_id processed
# 5009000 property_id processed
# 5010000 property_id processed
# 5011000 property_id processed
# 5012000 property_id processed
# 5013000 property_id processed
# 5016000 property_id processed
# 5017000 property_id processed
# 5019000 property_id processed
# 5020000 property_id processed
# 5021000 property_id processed
# 5022000 property_id processed
# 5023000 property_id processed
# 5025000 property_id processed
# 5026000 property_id processed
# 5027000 property_id processed
# 5028000 property_id processed
# 5029000 property_id processed
# 5030000 property_id processed
# 5031000 property_id processed
# 5032000 property_id processed
# 5035000 property_id processed
# 5036000 property_id processed
# 5037000 property_id processed
# 5038000 property_id processed
# 5039000 property_id processed
# 5040000 property_id processed
# 5041000 property_id processed
# 5044000 property_id processed
# 5045000 property_id processed
# 5046000 property_id processed
# 5047000 property_id processed
# 5049000 property_id processed
# 5050000 property_id processed
# 5051000 property_id processed
# 5058000 property_id processed
# 5059000 property_id processed
# 5060000 property_id processed
# 5062000 property_id processed
# 5065000 property_id processed
# 5067000 property_id processed
# 5070000 property_id processed
# 5071000 property_id processed
# 5072000 property_id processed
# 5075000 property_id processed
# 5076000 property_id processed
# 5077000 property_id processed
# 5078000 property_id processed
# 5079000 property_id processed
# 5080000 property_id processed
# 5081000 property_id processed
# 5082000 property_id processed
# 5084000 property_id processed
# 5087000 property_id processed
# 5088000 property_id processed
# 5090000 property_id processed
# 5091000 property_id processed
# 5092000 property_id processed
# 5093000 property_id processed
# 5098000 property_id processed
# 5099000 property_id processed
# 5100000 property_id processed
# 5101000 property_id processed
# 5102000 property_id processed
# 5103000 property_id processed
# 5104000 property_id processed
# 5105000 property_id processed
# 5106000 property_id processed
# 5107000 property_id processed
# 5114000 property_id processed
# 5118000 property_id processed
# 5121000 property_id processed
# 5123000 property_id processed
# 5124000 property_id processed
# 5126000 property_id processed
# 5129000 property_id processed
# 5130000 property_id processed
# 5132000 property_id processed
# 5133000 property_id processed
# 5134000 property_id processed
# 5136000 property_id processed
# 5138000 property_id processed
# 5142000 property_id processed
# 5143000 property_id processed
# 5144000 property_id processed
# 5146000 property_id processed
# 5150000 property_id processed
# 5151000 property_id processed
# 5152000 property_id processed
# 5154000 property_id processed
# 5156000 property_id processed
# 5157000 property_id processed
# 5158000 property_id processed
# 5162000 property_id processed
# 5163000 property_id processed
# 5167000 property_id processed
# 5168000 property_id processed
# 5172000 property_id processed
# 5174000 property_id processed
# 5177000 property_id processed
# 5178000 property_id processed
# 5180000 property_id processed
# 5181000 property_id processed
# 5182000 property_id processed
# 5183000 property_id processed
# 5184000 property_id processed
# 5185000 property_id processed
# 5192000 property_id processed
# 5196000 property_id processed
# 5197000 property_id processed
# 5198000 property_id processed
# 5200000 property_id processed
# 5201000 property_id processed
# 5202000 property_id processed
# 5207000 property_id processed
# 5209000 property_id processed
# 5214000 property_id processed
# 5215000 property_id processed
# 5217000 property_id processed
# 5218000 property_id processed
# 5219000 property_id processed
# 5221000 property_id processed
# 5223000 property_id processed
# 5226000 property_id processed
# 5227000 property_id processed
# 5228000 property_id processed
# 5229000 property_id processed
# 5232000 property_id processed
# 5234000 property_id processed
# 5240000 property_id processed
# 5241000 property_id processed
# 5242000 property_id processed
# 5243000 property_id processed
# 5244000 property_id processed
# 5245000 property_id processed
# 5249000 property_id processed
# 5250000 property_id processed
# 5253000 property_id processed
# 5259000 property_id processed
# 5265000 property_id processed
# 5268000 property_id processed
# 5269000 property_id processed
# 5270000 property_id processed
# 5271000 property_id processed
# 5272000 property_id processed
# 5276000 property_id processed
# 5278000 property_id processed
# 5279000 property_id processed
# 5280000 property_id processed
# 5281000 property_id processed
# 5282000 property_id processed
# 5284000 property_id processed
# 5285000 property_id processed
# 5286000 property_id processed
# 5289000 property_id processed
# 5290000 property_id processed
# 5291000 property_id processed
# 5293000 property_id processed
# 5295000 property_id processed
# 5296000 property_id processed
# 5298000 property_id processed
# 5299000 property_id processed
# 5300000 property_id processed
# 5303000 property_id processed
# 5305000 property_id processed
# 5307000 property_id processed
# 5309000 property_id processed
# 5310000 property_id processed
# 5311000 property_id processed
# 5312000 property_id processed
# 5314000 property_id processed
# 5319000 property_id processed
# 5320000 property_id processed
# 5321000 property_id processed
# 5322000 property_id processed
# 5325000 property_id processed
# 5326000 property_id processed
# 5328000 property_id processed
# 5329000 property_id processed
# 5330000 property_id processed
# 5342000 property_id processed
# 5344000 property_id processed
# 5348000 property_id processed
# 5349000 property_id processed
# 5351000 property_id processed
# 5352000 property_id processed
# 5355000 property_id processed
# 5358000 property_id processed
# 5359000 property_id processed
# 5369000 property_id processed
# 5370000 property_id processed
# 5374000 property_id processed
# 5375000 property_id processed
# 5382000 property_id processed
# 5383000 property_id processed
# 5387000 property_id processed
# 5388000 property_id processed
# 5389000 property_id processed
# 5393000 property_id processed
# 5394000 property_id processed
# 5396000 property_id processed
# 5398000 property_id processed
# 5400000 property_id processed
# 5402000 property_id processed
# 5405000 property_id processed
# 5407000 property_id processed
# 5410000 property_id processed
# 5411000 property_id processed
# 5413000 property_id processed
# 5414000 property_id processed
# 5415000 property_id processed
# 5416000 property_id processed
# 5418000 property_id processed
# 5423000 property_id processed
# 5424000 property_id processed
# 5425000 property_id processed
# 5427000 property_id processed
# 5428000 property_id processed
# 5429000 property_id processed
# 5430000 property_id processed
# 5431000 property_id processed
# 5432000 property_id processed
# 5433000 property_id processed
# 5435000 property_id processed
# 5436000 property_id processed
# 5437000 property_id processed
# 5438000 property_id processed
# 5440000 property_id processed
# 5443000 property_id processed
# 5444000 property_id processed
# 5445000 property_id processed
# 5447000 property_id processed
# 5449000 property_id processed
# 5450000 property_id processed
# 5451000 property_id processed
# 5452000 property_id processed
# 5454000 property_id processed
# 5456000 property_id processed
# 5457000 property_id processed
# 5461000 property_id processed
# 5462000 property_id processed
# 5464000 property_id processed
# 5465000 property_id processed
# 5466000 property_id processed
# 5467000 property_id processed
# 5468000 property_id processed
# 5469000 property_id processed
# 5470000 property_id processed
# 5471000 property_id processed
# 5472000 property_id processed
# 5476000 property_id processed
# 5477000 property_id processed
# 5478000 property_id processed
# 5482000 property_id processed
# 5484000 property_id processed
# 5486000 property_id processed
# 5487000 property_id processed
# 5490000 property_id processed
# 5491000 property_id processed
# 5492000 property_id processed
# 5494000 property_id processed
# 5496000 property_id processed
# 5498000 property_id processed
# 5499000 property_id processed
# 5500000 property_id processed
# 5502000 property_id processed
# 5503000 property_id processed
# 5504000 property_id processed
# 5505000 property_id processed
# 5506000 property_id processed
# 5507000 property_id processed
# 5508000 property_id processed
# 5509000 property_id processed
# 5512000 property_id processed
# 5513000 property_id processed
# 5515000 property_id processed
# 5516000 property_id processed
# 5517000 property_id processed
# 5523000 property_id processed
# 5524000 property_id processed
# 5526000 property_id processed
# 5528000 property_id processed
# 5529000 property_id processed
# 5531000 property_id processed
# 5533000 property_id processed
# 5535000 property_id processed
# 5536000 property_id processed
# 5537000 property_id processed
# 5538000 property_id processed
# 5539000 property_id processed
# 5540000 property_id processed
# 5541000 property_id processed
# 5542000 property_id processed
# 5545000 property_id processed
# 5546000 property_id processed
# 5547000 property_id processed
# 5548000 property_id processed
# 5549000 property_id processed
# 5550000 property_id processed
# 5551000 property_id processed
# 5552000 property_id processed
# 5554000 property_id processed
# 5555000 property_id processed
# 5556000 property_id processed
# 5562000 property_id processed
# 5564000 property_id processed
# 5566000 property_id processed
# 5568000 property_id processed
# 5569000 property_id processed
# 5570000 property_id processed
# 5572000 property_id processed
# 5573000 property_id processed
# 5576000 property_id processed
# 5577000 property_id processed
# 5578000 property_id processed
# 5580000 property_id processed
# 5581000 property_id processed
# 5583000 property_id processed
# 5584000 property_id processed
# 5585000 property_id processed
# 5587000 property_id processed
# 5588000 property_id processed
# 5592000 property_id processed
# 5594000 property_id processed
# 5595000 property_id processed
# 5596000 property_id processed
# 5598000 property_id processed
# 5600000 property_id processed
# 5601000 property_id processed
# 5602000 property_id processed
# 5603000 property_id processed
# 5605000 property_id processed
# 5610000 property_id processed
# 5615000 property_id processed
# 5616000 property_id processed
# 5617000 property_id processed
# 5620000 property_id processed
# 5622000 property_id processed
# 5623000 property_id processed
# 5625000 property_id processed
# 5626000 property_id processed
# 5629000 property_id processed
# 5630000 property_id processed
# 5631000 property_id processed
# 5632000 property_id processed
# 5635000 property_id processed
# 5636000 property_id processed
# 5637000 property_id processed
# 5638000 property_id processed
# 5639000 property_id processed
# 5642000 property_id processed
# 5643000 property_id processed
# 5646000 property_id processed
# 5649000 property_id processed
# 5651000 property_id processed
# 5654000 property_id processed
# 5656000 property_id processed
# 5658000 property_id processed
# 5660000 property_id processed
# 5661000 property_id processed
# 5663000 property_id processed
# 5664000 property_id processed
# 5666000 property_id processed
# 5667000 property_id processed
# 5668000 property_id processed
# 5669000 property_id processed
# 5670000 property_id processed
# 5672000 property_id processed
# 5673000 property_id processed
# 5674000 property_id processed
# 5675000 property_id processed
# 5676000 property_id processed
# 5677000 property_id processed
# 5678000 property_id processed
# 5679000 property_id processed
# 5682000 property_id processed
# 5685000 property_id processed
# 5686000 property_id processed
# 5688000 property_id processed
# 5691000 property_id processed
# 5693000 property_id processed
# 5698000 property_id processed
# 5701000 property_id processed
# 5702000 property_id processed
# 5703000 property_id processed
# 5705000 property_id processed
# 5706000 property_id processed
# 5707000 property_id processed
# 5708000 property_id processed
# 5710000 property_id processed
# 5714000 property_id processed
# 5716000 property_id processed
# 5717000 property_id processed
# 5718000 property_id processed
# 5719000 property_id processed
# 5720000 property_id processed
# 5721000 property_id processed
# 5722000 property_id processed
# 5725000 property_id processed
# 5726000 property_id processed
# 5727000 property_id processed
# 5728000 property_id processed
# 5729000 property_id processed
# 5730000 property_id processed
# 5731000 property_id processed
# 5732000 property_id processed
# 5733000 property_id processed
# 5734000 property_id processed
# 5736000 property_id processed
# 5737000 property_id processed
# 5738000 property_id processed
# 5739000 property_id processed
# 5740000 property_id processed
# 5741000 property_id processed
# 5743000 property_id processed
# 5745000 property_id processed
# 5751000 property_id processed
# 5752000 property_id processed
# 5754000 property_id processed
# 5755000 property_id processed
# 5756000 property_id processed
# 5758000 property_id processed
# 5759000 property_id processed
# 5762000 property_id processed
# 5763000 property_id processed
# 5765000 property_id processed
# 5766000 property_id processed
# 5767000 property_id processed
# 5768000 property_id processed
# 5769000 property_id processed
# 5770000 property_id processed
# 5771000 property_id processed
# 5772000 property_id processed
# 5776000 property_id processed
# 5777000 property_id processed
# 5778000 property_id processed
# 5780000 property_id processed
# 5781000 property_id processed
# 5783000 property_id processed
# 5784000 property_id processed
# 5786000 property_id processed
# 5788000 property_id processed
# 5789000 property_id processed
# 5790000 property_id processed
# 5792000 property_id processed

# %%
print(bad_ones)
# Out:
# [4117923, 4123035, 4123069, 4142664, 4143053, 4144729, 4147898, 4148602, 4154369, 4155968, 4156089, 4156117, 4156299, 4156327, 4156415, 4156434, 4156509, 4156685, 4156819, 4156894, 4156914, 4157000, 4159411, 4174532, 4179028, 4183796, 4185188, 4185397, 4185793, 4186684, 4196430, 4198388, 4200823, 4201166, 4201168, 4201273, 4201284, 4201386, 4201476, 4201504, 4201577, 4201599, 4201622, 4201635, 4201685, 4201687, 4201728, 4201730, 4201755, 4201793, 4201824, 4201835, 4201846, 4201854, 4201877, 4201878, 4201887, 4201925, 4201933, 4201951, 4201972, 4202002, 4202008, 4202050, 4202054, 4202098, 4202123, 4202128, 4202132, 4202141, 4202159, 4202162, 4202168, 4202172, 4202175, 4202189, 4202216, 4202218, 4202223, 4202265, 4202294, 4202295, 4202306, 4202319, 4202333, 4202337, 4202382, 4202398, 4202422, 4202435, 4202443, 4202463, 4202483, 4202505, 4202565, 4202606, 4202620, 4202627, 4202647, 4202671, 4202690, 4202694, 4202715, 4202716, 4202724, 4202732, 4202741, 4202763, 4202765, 4202802, 4202831, 4202837, 4202852, 4202861, 4202865, 4202868, 4202911, 4202912, 4202915, 4202921, 4202987, 4202989, 4203001, 4203019, 4203027, 4203038, 4203044, 4203058, 4203076, 4203078, 4203086, 4203107, 4203115, 4203117, 4203132, 4203140, 4203142, 4203205, 4203218, 4203230, 4203234, 4203235, 4203242, 4203244, 4203246, 4203255, 4203256, 4203265, 4203269, 4203276, 4203311, 4203317, 4203329, 4203338, 4203343, 4203356, 4203382, 4203387, 4203415, 4203426, 4203490, 4203501, 4203502, 4203533, 4203549, 4203556, 4203588, 4203601, 4203627, 4203637, 4203662, 4203691, 4203699, 4203753, 4203779, 4203791, 4203816, 4203817, 4203832, 4203837, 4203840, 4203846, 4203876, 4203884, 4203891, 4203920, 4203970, 4203998, 4204010, 4204013, 4204020, 4204049, 4204052, 4204072, 4204103, 4204107, 4204135, 4204165, 4204192, 4204196, 4204212, 4204218, 4204233, 4204259, 4204282, 4204292, 4204311, 4204314, 4204318, 4204338, 4204380, 4204401, 4204438, 4204471, 4204486, 4204544, 4204614, 4204620, 4204634, 4204638, 4204647, 4204681, 4204750, 4204781, 4204801, 4204807, 4204824, 4204839, 4204845, 4204897, 4204909, 4204914, 4204999, 4205004, 4205015, 4205021, 4205042, 4205053, 4205057, 4205065, 4205067, 4205102, 4205106, 4205111, 4205132, 4205143, 4205152, 4205158, 4205165, 4205183, 4205204, 4205214, 4205217, 4205249, 4205252, 4205283, 4205304, 4205311, 4205319, 4205349, 4205362, 4205381, 4205384, 4205386, 4205397, 4205409, 4205416, 4205418, 4205432, 4205446, 4205447, 4205484, 4205495, 4205508, 4205520, 4205536, 4205539, 4205541, 4205562, 4205576, 4205586, 4205598, 4205636, 4205655, 4205682, 4205692, 4205734, 4205768, 4205773, 4205792, 4205833, 4205862, 4205906, 4205929, 4205946, 4205959, 4205967, 4206010, 4206023, 4206039, 4206152, 4206177, 4206181, 4206203, 4206224, 4206227, 4206236, 4206238, 4206280, 4206311, 4206422, 4206431, 4206433, 4206461, 4206465, 4206485, 4206504, 4206564, 4206568, 4206571, 4206585, 4206593, 4206684, 4206698, 4206730, 4206735, 4206764, 4206766, 4206775, 4206785, 4206856, 4206862, 4206897, 4206964, 4206965, 4206976, 4207016, 4207037, 4207056, 4207057, 4207108, 4207113, 4207185, 4207225, 4207322, 4207329, 4207345, 4207388, 4207397, 4207422, 4207479, 4207497, 4207516, 4207574, 4207616, 4207745, 4207773, 4207784, 4207808, 4207830, 4207847, 4207894, 4207951, 4207959, 4207994, 4208013, 4208016, 4208047, 4208067, 4208084, 4208128, 4208150, 4208154, 4208177, 4208191, 4208211, 4208228, 4208306, 4208316, 4208327, 4208343, 4208346, 4208352, 4208359, 4208364, 4208379, 4208417, 4208492, 4208508, 4208512, 4208563, 4208575, 4208591, 4208598, 4208628, 4208652, 4208662, 4208684, 4208688, 4208696, 4208702, 4208707, 4208711, 4208735, 4208741, 4208758, 4208781, 4208806, 4208829, 4208865, 4208874, 4208893, 4208939, 4208959, 4208960, 4208996, 4208999, 4209034, 4209051, 4209095, 4209138, 4209177, 4209181, 4209187, 4209205, 4209218, 4209252, 4209259, 4209296, 4209320, 4209332, 4209334, 4209358, 4209361, 4209397, 4209400, 4209408, 4209422, 4209436, 4209455, 4209456, 4209474, 4209509, 4209520, 420 ...
