# %%
# %load_ext sql
import statsmodels.api as sma
import datetime

import fiona
import shapely as shapely
from geopandas import GeoSeries, GeoDataFrame
from shapely.geometry import Point
from shapely.geometry import asShape
from time import gmtime, strftime

# imports
import pandas as pd
import matplotlib.pyplot as plt
import csv

# follow the usual sklearn pattern: import, instantiate, fit
from sklearn.linear_model import LinearRegression
import numpy as np

from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

import statsmodels.formula.api as sm

# this allows plots to appear directly in the notebook
# %matplotlib inline
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql://prod:nerd@52.2.153.189/rental_nerd
# Out:
# u'Connected: prod@rental_nerd'

# %%
result = %sql (SELECT \
properties.address, \
properties.bedrooms, \
properties.bathrooms, \
properties.sqft, \
properties.source, \
properties.origin_url, \
properties.longitude, \
properties.latitude, \
properties.elevation, \
properties.year_built, \
properties.garage, \
properties.level, \
properties.luxurious, \
property_transactions.transaction_type, \
property_transaction_logs.price, \
property_transaction_logs.transaction_status, \
property_transaction_logs.days_on_market, \
property_transaction_logs.date_closed, \
property_transaction_logs.date_listed, \
neighborhoods.name as 'neighborhood', \
neighborhoods.id as 'nid', \
neighborhoods.shapefile_source \
FROM \
properties, \
property_transactions, \
property_transaction_logs, \
property_neighborhoods, \
neighborhoods \
WHERE \
properties.id = property_transactions.property_id AND \
property_transactions.property_transaction_log_id = property_transaction_logs.id AND \
property_transactions.transaction_type = "rental" AND \
neighborhoods.shapefile_source = "SF" AND \
properties.id = property_neighborhoods.property_id AND \
property_neighborhoods.neighborhood_id = neighborhoods.id)
        
data = result.DataFrame()
# Out:
# 1027 rows affected.

# %%
result.csv(filename=strftime("%Y%m%d")+ " rentals.csv")
# Out:
# CSV results at /Users/ilya/Dropbox/Coding Projects/rentalnerd/scraper/20151025 rentals.csv

# %%
# fill NaN values with some reasonable defaults
data.garage = data.garage.fillna(False)
data.year_built = data.year_built.fillna(1915)

data.luxurious = data.luxurious.fillna(False)

data.luxurious = data.luxurious.astype(bool)

data.head()
# Out:
#                                            address  bedrooms  bathrooms  sqft  \
# 0                              814 Hayes Street #2         3          2  1200
# 1            Mcallister St San Francisco, CA 94115         4          2  1700
# 2            Mcallister St San Francisco, CA 94115         2          1  1150
# 3  1301 Fulton St APT 207, San Francisco, CA 94117         2          1   925
# 4            Anzavista Ave San Francisco, CA 94115         0          1   750
#
#            source                                         origin_url  \
# 0  climbsf_rented    http://www.climbsf.com/for-rent/814-hayes-st-2/
# 1       zillow_sf  http://www.zillow.com/homedetails/Mcallister-S...
# 2       zillow_sf  http://www.zillow.com/homedetails/Mcallister-S...
# 3       zillow_sf  http://www.zillow.com/homedetails/1301-Fulton-...
# 4       zillow_sf  http://www.zillow.com/homedetails/Anzavista-Av...
#
#    longitude  latitude  elevation  year_built       ...         luxurious  \
# 0   -122.430   37.7762    42.1639        1915       ...             False
# 1   -122.436   37.7781    60.9689        1915       ...             False
# 2   -122.436   37.7781    60.9689        1915       ...             False
# 3   -122.439   37.7767    63.5880        1915       ...             False
# 4   -122.444   37.7796   106.3460        1915       ...             False
#
#    transaction_type price transaction_status  days_on_market date_closed  \
# 0            rental  5000             closed             NaN  2014-04-09
# 1            rental  8900               open             NaN        None
# 2            rental  5900               open             NaN        None
# 3            rental  3800               open             NaN        None
# 4            rental  2295               open             NaN        None
#
#    date_listed  neighborhood nid shapefile_source
# 0         None  Alamo Square   1               SF
# 1   2015-02-08  Alamo Square   1               SF
# 2   2015-02-23  Alamo Square   1               SF
# 3   2015-09-01  Alamo Square   1               SF
# 4   2015-08-05    Anza Vista   2               SF
#
# [5 rows x 22 columns]

# %%
Date_final = [0.1] * len(data)

for x in range(0,len(data)):
    data
    if data["date_closed"][x] is not None :
        # print " row: "+ `x` + ": using date_rented"
        # data.ix['Date_final',x]
        Date_final[x] = data["date_closed"][x]
        
    elif data["date_listed"][x] is not None :
        # print " row: "+ `x` + ": using date_listed"
        Date_final[x] = data["date_listed"][x]
    else:
        Date_final[x] = data["date_closed"][2]
        print " row: "+ `x` + ": we are screwed"



data['date'] = pd.to_datetime(Date_final)

data.head()
# Out:
#                                            address  bedrooms  bathrooms  sqft  \
# 0                              814 Hayes Street #2         3          2  1200
# 1            Mcallister St San Francisco, CA 94115         4          2  1700
# 2            Mcallister St San Francisco, CA 94115         2          1  1150
# 3  1301 Fulton St APT 207, San Francisco, CA 94117         2          1   925
# 4            Anzavista Ave San Francisco, CA 94115         0          1   750
#
#            source                                         origin_url  \
# 0  climbsf_rented    http://www.climbsf.com/for-rent/814-hayes-st-2/
# 1       zillow_sf  http://www.zillow.com/homedetails/Mcallister-S...
# 2       zillow_sf  http://www.zillow.com/homedetails/Mcallister-S...
# 3       zillow_sf  http://www.zillow.com/homedetails/1301-Fulton-...
# 4       zillow_sf  http://www.zillow.com/homedetails/Anzavista-Av...
#
#    longitude  latitude  elevation  year_built    ...      transaction_type  \
# 0   -122.430   37.7762    42.1639        1915    ...                rental
# 1   -122.436   37.7781    60.9689        1915    ...                rental
# 2   -122.436   37.7781    60.9689        1915    ...                rental
# 3   -122.439   37.7767    63.5880        1915    ...                rental
# 4   -122.444   37.7796   106.3460        1915    ...                rental
#
#    price transaction_status days_on_market  date_closed date_listed  \
# 0   5000             closed            NaN   2014-04-09        None
# 1   8900               open            NaN         None  2015-02-08
# 2   5900               open            NaN         None  2015-02-23
# 3   3800               open            NaN         None  2015-09-01
# 4   2295               open            NaN         None  2015-08-05
#
#    neighborhood nid shapefile_source       date
# 0  Alamo Square   1               SF 2014-04-09
# 1  Alamo Square   1               SF 2015-02-08
# 2  Alamo Square   1               SF 2015-02-23
# 3  Alamo Square   1               SF 2015-09-01
# 4    Anza Vista   2               SF 2015-08-05
#
# [5 rows x 23 columns]

# %%
# create a column of GeoSeries - each house should be represented by a point
pts = GeoSeries([Point(x, y) for x, y in zip(data['longitude'], data['latitude'])])
data['latlong'] = pts

# %%
dist_to_park = [999999] * len(data) # fill with dummy values to be filtered out
closest_park = ['None'] * len(data)
latlong = data['latlong'].values
with fiona.open('data/RPD_Parks_4326/parks_4326.shp') as fiona_collection:
    for park in fiona_collection:
        park_name = park["properties"]["map_park_n"]
        # Use Shapely to create the polygon
        shape = asShape( park['geometry'] )
        if shape.area < 0.001:   # change to 0.000001 for real data
            print park_name + ' is too small at ' + `shape.area` 
            continue
            
        #print "checking for proximity to: " + park_name + ' with area: ' + `shape.area`
        for row in range(0,len(data)):
            point = latlong[row] # longitude, latitude
            dist = shape.distance(point) * 100000
            if dist < dist_to_park[row]: 
                dist_to_park[row] = dist
                closest_park[row] = park_name

print 'Done'
data['dist_to_park'] = dist_to_park
data['closest_park'] = closest_park
data.head()
# Out:
# Maritime Plaza is too small at 8.333416041071514e-07
# Victoria Manalo Draves Park is too small at 1.0414108652372042e-06
# Crocker Amazon Playground is too small at 2.335089291946154e-05
# Dearborn Community Garden is too small at 6.384420351348188e-08
# Angelo J. Rossi Playground is too small at 2.6786514833549074e-06
# Lake Merced Park is too small at 0.0002516841071582249
# Telegraph Hill/Pioneer Park is too small at 2.0250235515636755e-06
# Head & Brotherood Mini Park is too small at 2.2842949387512543e-07
# Balboa Natural Area is too small at 7.628411322265208e-07
# Broadway Tunnel West Mini Park is too small at 5.138207003055309e-08
# Alamo Square is too small at 5.253994710747828e-06
# 24th & York Mini Park is too small at 4.939779756558067e-08
# Mt. Davidson Park is too small at 1.684320788581448e-05
# Union Square is too small at 1.076244689464398e-06
# Midtown Terrace Playground is too small at 4.999909744839785e-06
# Precita Park is too small at 9.150017154907253e-07
# Brooks Park is too small at 1.5354832683227666e-06
# Adam Rodgers Park is too small at 1.1334586337861152e-06
# John McLaren Park is too small at 0.00012926543047010142
# Russian Hill Open Space is too small at 3.983418875406988e-07
# Beideman & O'Farrell Mini Park is too small at 2.4518591981378515e-08
# Mullen & Peralta Mini Park is too small at 1.863497809635393e-07
# Alta Plaza Park is too small at 4.928986328119509e-06
# Ina Coolbrith Park is too small at 3.573055370089921e-07
# Dogpatch/Miller Memorial Garden is too small at 1.0767516984810728e-07
# Louis Sutter Playground is too small at 5.75807638780225e-06
# Joseph Conrad Mini Park is too small at 6.387403297412363e-08
# Geneva Avenue Strip is too small at 9.594872996689325e-08
# 29th & Diamond Open Space is too small at 3.372585423149393e-07
# Diamond & Farnum Open Space is too small at 2.875622968890608e-08
# Cow Hollow Playground is too small at 6.188292073135964e-08
# Coso & Precita Mini Park is too small at 6.226468008590154e-08
# Duncan & Castro Open Space is too small at 2.397736033385076e-07
# Hawk Hill is too small at 2.005993246809935e-06
# Herz Playground is too small at 2.760805220617754e-06
# Dorothy Erskine Park is too small at 6.607523788025506e-07
# Argonne Playground is too small at 3.393491772166019e-07
# Mt. Olympus is too small at 8.490259437786529e-08
# Edgehill Mountain is too small at 9.640723779051192e-07
# Alioto Mini Park is too small at 6.69852889445249e-08
# Kite Hill is too small at 1.1875097477699357e-06
# Ridgetop Plaza is too small at 1.1515761986200772e-07
# Broadway Tunnel East Mini Park is too small at 1.3502462748961951e-08
# Golden Gate Heights Park is too small at 2.8770804247042982e-06
# George Christopher Playground is too small at 2.816520793526006e-06
# Ferry Park is too small at 1.7640843120144974e-06
# Chesnut & Kearny Open Space is too small at 3.3511959257647285e-08
# Bay View Park is too small at 1.6605940985886756e-05
# 10th Ave & Clement Mini Park is too small at 3.4324663732568383e-07
# Glen Canyon Park is too small at 3.2244055895260945e-05
# Aptos Playground is too small at 1.989083799220228e-06
# Walter Haas Playground is too small at 1.9146687587795825e-06
# Golden Gate Park is too small at 0.00042493138816672194
# Camp Mather is too small at 0.00013989822888904908
# Billy Goat Hill is too small at 1.5176999724497963e-06
# St. Mary's Square is too small at 5.87095588332992e-07
# Little Hollywood Park is too small at 5.435273816410738e-07
# Done
#                                            address  bedrooms  bathrooms  sqft  \
# 0                              814 Hayes Street #2         3          2  1200
# 1            Mcallister St San Francisco, CA 94115         4          2  1700
# 2            Mcallister St San Francisco, CA 94115         2          1  1150
# 3  1301 Fulton St APT 207, San Francisco, CA 94117         2          1   925
# 4            Anzavista Ave San Francisco, CA 94115         0          1   750
#
#            source                                         origin_url  \
# 0  climbsf_rented    http://www.climbsf.com/for-rent/814-hayes-st-2/
# 1       zillow_sf  http://www.zillow.com/homedetails/Mcallister-S...
# 2       zillow_sf  http://www.zillow.com/homedetails/Mcallister-S...
# 3       zillow_sf  http://www.zillow.com/homedetails/1301-Fulton-...
# 4       zillow_sf  http://www.zillow.com/homedetails/Anzavista-Av...
#
#    longitude  latitude  elevation  year_built     ...       days_on_market  \
# 0   -122.430   37.7762    42.1639        1915     ...                  NaN
# 1   -122.436   37.7781    60.9689        1915     ...                  NaN
# 2   -122.436   37.7781    60.9689        1915     ...                  NaN
# 3   -122.439   37.7767    63.5880        1915     ...                  NaN
# 4   -122.444   37.7796   106.3460        1915     ...                  NaN
#
#    date_closed date_listed  neighborhood  nid shapefile_source       date  \
# 0   2014-04-09        None  Alamo Square    1               SF 2014-04-09
# 1         None  2015-02-08  Alamo Square    1               SF 2015-02-08
# 2         None  2015-02-23  Alamo Square    1               SF 2015-02-23
# 3         None  2015-09-01  Alamo Square    1               SF 2015-09-01
# 4         None  2015-08-05    Anza Vista    2               SF 2015-08-05
#
#                     latlong dist_to_park closest_park
# 0   POINT (-122.43 37.7762)       999999         None
# 1  POINT (-122.436 37.7781)       999999         None
# 2  POINT (-122.436 37.7781)       999999         None
# 3  POINT (-122.439 37.7767)       999999         None
# 4  POINT (-122.444 37.7796)       999999         None
#
# [5 rows x 26 columns]

# %%
# create year dummy variables (because date isn't very intuitive variable)
data["year"] = pd.DatetimeIndex(data["date"]).to_period('Y')

# %%
# filter out any outliers, defined as rent >$10k or >2,500 sq ft, or not in SF

print "Entries before filter: " + `len(data)`
data = data[  (data.sqft <= 3000) 
            & (data.price <= 8000) 
            & (data.price != 0) 
            & (data.bedrooms <= 4) 
            & (data.bathrooms <= 3) 
            & (data.sqft != 0)
            & (data.year != pd.Period('1969', freq='A-DEC'))
            & (data.address > '(Undisclosed Address) San Francisco, CA 94999')  # eliminate (Undisclosed)
            & ((data.source == 'climbsf_rented') 
               | ((data.date_closed == 'null') & (data.date_listed > datetime.date(2015, 9, 1)) ) # eliminate listings older than 2 months
               | ((data.date_closed != 'null')) )] #include everything closed

print "Entries after filter: " + `len(data)`
data.head()
# Out:
# Entries before filter: 1027
# Entries after filter: 754
#                                              address  bedrooms  bathrooms  \
# 0                                814 Hayes Street #2         3          2
# 2              Mcallister St San Francisco, CA 94115         2          1
# 3    1301 Fulton St APT 207, San Francisco, CA 94117         2          1
# 4              Anzavista Ave San Francisco, CA 94115         0          1
# 7  1180 Broderick St APT 304, San Francisco, CA 9...         2          2
#
#    sqft          source                                         origin_url  \
# 0  1200  climbsf_rented    http://www.climbsf.com/for-rent/814-hayes-st-2/
# 2  1150       zillow_sf  http://www.zillow.com/homedetails/Mcallister-S...
# 3   925       zillow_sf  http://www.zillow.com/homedetails/1301-Fulton-...
# 4   750       zillow_sf  http://www.zillow.com/homedetails/Anzavista-Av...
# 7  1500       zillow_sf  http://www.zillow.com/homedetails/1180-Broderi...
#
#    longitude  latitude  elevation  year_built ...   date_closed  date_listed  \
# 0   -122.430   37.7762    42.1639        1915 ...    2014-04-09         None
# 2   -122.436   37.7781    60.9689        1915 ...          None   2015-02-23
# 3   -122.439   37.7767    63.5880        1915 ...          None   2015-09-01
# 4   -122.444   37.7796   106.3460        1915 ...          None   2015-08-05
# 7   -122.441   37.7809    72.9697        1986 ...          None   2015-10-07
#
#    neighborhood nid  shapefile_source       date                   latlong  \
# 0  Alamo Square   1                SF 2014-04-09   POINT (-122.43 37.7762)
# 2  Alamo Square   1                SF 2015-02-23  POINT (-122.436 37.7781)
# 3  Alamo Square   1                SF 2015-09-01  POINT (-122.439 37.7767)
# 4    Anza Vista   2                SF 2015-08-05  POINT (-122.444 37.7796)
# 7    Anza Vista   2                SF 2015-10-07  POINT (-122.441 37.7809)
#
#   dist_to_park closest_park year
# 0       999999         None 2014
# 2       999999         None 2015
# 3       999999         None 2015
# 4       999999         None 2015
# 7       999999         None 2015
#
# [5 rows x 27 columns]

# %%
data.hist(column=['bathrooms','bedrooms','price','garage','level','year_built','sqft','elevation','luxurious','dist_to_park'],figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1113d8490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f0b8bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f19c610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111a174d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10eae0210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111646090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1113262d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111753ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1117e4d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111430a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11123a550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1111a4690>]], dtype=object)

# %%
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %%
age = 2015 - data.year_built 
age.name = 'age'
data = pd.concat([data,age],axis=1)

# %%
result = sm.ols(formula="price ~ level + bedrooms + bathrooms + garage + age + elevation + neighborhood:sqft:year:luxurious -1", data=data).fit()
print result.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0
:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                            0          0        nan        nan             0         0
# neighborhood[Cow Hollow]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                                0          0        nan        nan             0         0
# neighborhood[Crocker Amazon]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                            0          0        nan        nan             0         0
# neighborhood[Diamond Heights]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                     -0.8543      0.733     -1.166      0.244        -2.294     0.585
# neighborhood[Downtown]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                             1.3544      0.352      3.850      0.000         0.663     2.045
# neighborhood[Duboce Triangle]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                           0          0        nan        nan             0         0
# neighborhood[Eureka Valley / Dolores Heights]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]      1.9128      0.299      6.391      0.000         1.325     2.501
# neighborhood[Excelsior]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                            0.6756      0.913      0.740      0.460        -1.118     2.470
# neighborhood[Financial District/Barbary Coast]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]          0          0        nan        nan             0         0
# neighborhood[Forest Hill]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                               0          0        nan        nan             0         0
# neighborhood[Forest Hills Extension]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                    0          0        nan        nan             0         0
# neighborhood[Glen Park]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                            0.3881      0.396      0.980      0.327        -0.389     1.166
# neighborhood[Golden Gate Heights]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                       0          0        nan        nan             0         0
# neighborhood[Golden Gate Park]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                          0          0        nan        nan             0         0
# neighborhood[Haight Ashbury]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                            0          0        nan        nan             0         0
# neighborhood[Hayes Valley]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                              0          0        nan        nan             0         0
# neighborhood[Ingleside]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                                 0          0        nan        nan             0         0
# neighborhood[Ingleside Heights]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                         0          0        nan        nan             0         0
# neighborhood[Ingleside Terrace]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                         0          0        nan        nan             0         0
# neighborhood[Inner Mission]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                        2.0309      0.563      3.605      0.000         0.924     3.137
# neighborhood[Inner Parkside]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                            0          0        nan        nan             0         0
# neighborhood[Inner Richmond]:sqft:year[Period('2014', 'A-DEC')]:luxurious[False]                       1.9284      0.755      2.555      0.011         0.446     3.411
# ...
# neighborhood[Sunnyside]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                                  0          0        nan        nan             0         0
# neighborhood[Telegraph Hill]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                             0          0        nan        nan             0         0
# neighborhood[Tenderloin]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                                 0          0        nan        nan             0         0
# neighborhood[Twin Peaks]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                                 0          0        nan        nan             0         0
# neighborhood[Van Ness/Civic Center]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                      0          0        nan        nan             0         0
# neighborhood[Visitacion Valley]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                          0          0        nan        nan             0         0
# neighborhood[West Portal]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                                0          0        nan        nan             0         0
# neighborhood[Western Addition]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                           0          0        nan        nan             0         0
# neighborhood[Westwood Highlands]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                         0          0        nan        nan             0         0
# neighborhood[Westwood Park]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                              0          0        nan        nan             0         0
# neighborhood[Yerba Buena]:sqft:year[Period('2014', 'A-DEC')]:luxurious[True]                           2.6494      0.405      6.543      0.000         1.854     3.445
# neighborhood[Alamo Square]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                               0          0        nan        nan             0         0
# neighborhood[Anza Vista]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                 0          0        nan        nan             0         0
# neighborhood[Bayview]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                    0          0        nan        nan             0         0
# neighborhood[Bayview Heights]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                            0          0        nan        nan             0         0
# neighborhood[Bernal Heights]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                             0          0        nan        nan             0         0
# neighborhood[Buena Vista Park/Ashbury Heights]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True
:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                   0          0        nan        nan             0         0
# neighborhood[Pine Lake Park]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                             0          0        nan        nan             0         0
# neighborhood[Portola]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                    0          0        nan        nan             0         0
# neighborhood[Potrero Hill]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                               0          0        nan        nan             0         0
# neighborhood[Presidio Heights]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                           0          0        nan        nan             0         0
# neighborhood[Russian Hill]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                          1.6269      0.535      3.042      0.002         0.577     2.677
# neighborhood[Sherwood Forest]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                            0          0        nan        nan             0         0
# neighborhood[Silver Terrace]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                             0          0        nan        nan             0         0
# neighborhood[South Beach]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                           2.7387      0.180     15.198      0.000         2.385     3.093
# neighborhood[South of Market]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                       2.5052      0.717      3.496      0.001         1.098     3.912
# neighborhood[Stonestown]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                 0          0        nan        nan             0         0
# neighborhood[Sunnyside]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                  0          0        nan        nan             0         0
# neighborhood[Telegraph Hill]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                             0          0        nan        nan             0         0
# neighborhood[Tenderloin]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                 0          0        nan        nan             0         0
# neighborhood[Twin Peaks]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                 0          0        nan        nan             0         0
# neighborhood[Van Ness/Civic Center]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                 1.2318      0.604      2.039      0.042         0.045     2.418
# neighborhood[Visitacion Valley]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                          0          0        nan        nan             0         0
# neighborhood[West Portal]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                                0          0        nan        nan             0         0
# neighborhood[Western Addition]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                           0          0        nan        nan             0         0
# neighborhood[Westwood Highlands]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                         0          0        nan        nan             0         0
# neighborhood[Westwood Park]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                              0          0        nan        nan             0         0
# neighborhood[Yerba Buena]:sqft:year[Period('2015', 'A-DEC')]:luxurious[True]                           3.1373      0.357      8.791      0.000         2.436     3.838
# ==============================================================================
# Omnibus:                       85.704   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              459.010
# Skew:                           0.340   Prob(JB):                    2.12e-100
# Kurtosis:                       6.761   Cond. No.                     5.79e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 2.09e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
output = [['neighborhood','regular','luxurious']]
table = ListTable()
table.append(output[0])

for row in data.neighborhood.unique():
    output_row = [row, '99', '99']
    for i in result.params.index:
        if 'neighborhood' not in i: continue

        if '2015' in i:
            if 'neighborhood[' + row + ']' in i:
                if 'luxurious[True]' in i:
                    output_row[2] = `result.params[i]`
                    output.append(output_row)
                    table.append(output_row)

                if 'luxurious[False]' in i:
                    output_row[1] = `result.params[i]`

table
# Out:
# [['neighborhood', 'regular', 'luxurious'],
#  ['Alamo Square', '2.2246034838814572', '0.0'],
#  ['Anza Vista', '1.2098172285850686', '0.0'],
#  ['Bayview', '1.0508877646212693', '0.0'],
#  ['Bernal Heights', '1.2992948542384921', '0.0'],
#  ['Buena Vista Park/Ashbury Heights', '1.2678929184621808', '0.0'],
#  ['Central Richmond', '1.3129581873294009', '0.0'],
#  ['Central Sunset', '0.73651159654275156', '0.0'],
#  ['Corona Heights', '1.8200162464974605', '0.0'],
#  ['Cow Hollow', '1.8700225566692763', '0.0'],
#  ['Crocker Amazon', '0.18092141319875132', '0.0'],
#  ['Diamond Heights', '0.78924520465226666', '0.0'],
#  ['Downtown', '1.6111331615714395', '0.057738505280628849'],
#  ['Duboce Triangle', '1.7445038171244334', '3.3809040719344274'],
#  ['Eureka Valley / Dolores Heights', '2.1439548922932259', '0.0'],
#  ['Excelsior', '0.16066496189650314', '0.0'],
#  ['Financial District/Barbary Coast',
#   '2.897095361343351',
#   '1.4611199176884768'],
#  ['Yerba Buena', '2.6877894460043423', '3.1372514473596294'],
#  ['Forest Hill', '0.94633698382419185', '0.0'],
#  ['Forest Hills Extension', '0.58109069196850616', '0.0'],
#  ['Glen Park', '1.1626391686017814', '0.0'],
#  ['Golden Gate Heights', '0.85552857622220491', '0.0'],
#  ['Golden Gate Park', '1.6069500056963051', '0.0'],
#  ['Haight Ashbury', '1.2923612049731306', '0.0'],
#  ['Hayes Valley', '2.2601626919687829', '2.5515943077488257'],
#  ['Ingleside', '0.49842433421074872', '0.0'],
#  ['Ingleside Heights', '0.40337349361818609', '0.0'],
#  ['Ingleside Terrace', '1.4127303217013887', '0.0'],
#  ['Inner Mission', '2.2415377321523784', '2.2775757756849861'],
#  ['Inner Parkside', '0.74791213378923238', '0.0'],
#  ['Inner Richmond', '1.1426769176189626', '0.0'],
#  ['Inner Sunset', '1.4625926453156932', '0.0'],
#  ['Jordan Park / Laurel Heights', '1.8389744166029671', '0.0'],
#  ['Lake Street', '1.2892211639753741', '0.0'],
#  ['Lake Shore', '0.95509910479757898', '0.0'],
#  ['Lone Mountain', '1.5909577820832539', '0.0'],
#  ['Lower Pacific Heights', '2.3888697831340928', '0.0'],
#  ['Marina', '2.2274343046642029', '0.0'],
#  ['Merced Heights', '0.41295314228724078', '0.0'],
#  ['Merced Manor', '1.1340442313843093', '0.0'],
#  ['Midtown Terrace', '0.088519379591829317', '0.0'],
#  ['Miraloma Park', '0.44944093139100671', '0.0'],
#  ['Mission Bay', '2.8356941999877003', '0.0'],
#  ['Mission Dolores', '2.5923635420085889', '0.0'],
#  ['Mission Terrace', '0.95290322337404354', '0.0'],
#  ['Noe Valley', '1.8949656614516832', '0.0'],
#  ['North Beach', '2.2158514433649614', '0.0'],
#  ['North Panhandle', '1.5957426968791752', '0.0'],
#  ['North Waterfront', '3.5271565289959446', '0.0'],
#  ['Oceanview', '0.37496397315515262', '0.0'],
#  ['Outer Mission', '-0.27716014595921123', '0.0'],
#  ['Outer Parkside', '1.2143830407611969', '0.0'],
#  ['Outer Richmond', '1.002988107146912', '0.0'],
#  ['Outer Sunset', '0.90463236467394492', '0.0'],
#  ['Pacific Heights', '1.831203326855128', '0.0'],
#  ['Parkside', '0.3562818416601814', '0.0'],
#  ['Cole Valley/Parnassus Heights', '1.4000990957170414', '0.0'],
#  ['Pine Lake Park', '0.9155316485068572', '0.0'],
#  ['Portola', '0.63539154481538862', '0.0'],
#  ['Potrero Hill', '1.6899110484421491', '0.0'],
#  ['Presidio Heights', '1.8544459597140328', '0.0'],
#  ['Russian Hill', '2.6011147015864271', '1.6269203514659587'],
#  ['Silver Terrace', '0.94435593990830125', '0.0'],
#  ['South Beach', '2.3557387247177748', '2.7387275351603879'],
#  ['South of Market', '2.3733873412841491', '2.5051559908026837'],
#  ['Stonestown', '1.0718050978785785', '0.0'],
#  ['Sunnyside', '1.1090837826551858', '0.0'],
#  ['Telegraph Hill', '3.7031025227755436', '0.0'],
#  ['Twin Peaks', '0.98813570008876517', '0.0'],
#  ['Van Ness/Civic Center', '1.9257972337429368', '1.23179472114356'],
#  ['Visitacion Valley', '-0.13550640025886929', '0.0'],
#  ['West Portal', '1.1943065218908084', '0.0'],
#  ['Western Addition', '1.7055240838735366', '0.0'],
#  ['Westwood Highlands', '0.4958314737327727', '0.0'],
#  ['Westwood Park', '0.72778462422096046', '0.0'],
#  ['Sherwood Forest', '0.23406419219530897', '0.0'],
#  ['Tenderloin', '2.4137279466693524', '0.0'],
#  ['Central Waterfront/Dogpatch', '1.7637928320879985', '0.0'],
#  ['Candlestick Point', '0.076849101005255105', '0.0'],
#  ['Bayview Heights', '-0.27524361718219564', '0.0'],
#  ['Nob Hill', '2.1695819051473655', '0.0']]

# %%
path = 'rentalnerd_importer/lib/tasks/model_files/'

dtype = [('Effect', 'S100'), ('Coefficient', float)]

with open(path + 'model_features_sf_' + strftime("%Y%m%d") + '.csv', 'wb') as csvfile:
    modelwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    header = ['Effect','Coefficient']
    table.append(header)
    modelwriter.writerow(header)
    modelwriter.writerow(['base_rent', 0]) # result.params.Intercept])  hardcode 0 as base rent
    modelwriter.writerow(['bedrooms', result.params.bedrooms])
    modelwriter.writerow(['bathrooms', result.params.bathrooms])
    #modelwriter.writerow(['dist_to_park', result.params.dist_to_park])
    modelwriter.writerow(['elevation', result.params.elevation])
    modelwriter.writerow(['level', result.params.level])
    modelwriter.writerow(['age', result.params.age])
    modelwriter.writerow(['garage', result.params.garage])

# %%
with open(path + 'model_hoods_sf_' + strftime("%Y%m%d") + '.csv', 'wb') as csvfile:
    hoodwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    
    for i in output:
        hoodwriter.writerow(i)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-2e0966ac91eb> in <module>()
# ----> 1 price_per_adj_foot = data['price'] / data['adj_sqft']
#       2 price_per_adj_foot.name = 'price_per_adj_foot'
#       3 adj_price = data['price'] * data['area_multiplier']
#       4 adj_price.name = 'adj_price'
#       5 data = pd.concat([data, price_per_adj_foot, adj_price], axis=1)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1912             return self._getitem_multilevel(key)
#    1913         else:
# -> 1914             return self._getitem_column(key)
#    1915
#    1916     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1919         # get column
#    1920         if self.columns.is_unique:
# -> 1921             return self._get_item_cache(key)
#    1922
#    1923         # duplicate columns & possible reduce dimensionaility
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1088         res = cache.get(item)
#    1089         if res is None:
# -> 1090             values = self._data.get(item)
#    1091             res = self._box_item_values(item, values)
#    1092             cache[item] = res
#
# /usr/local/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3100
#    3101             if not isnull(item):
# -> 3102                 loc = self.items.get_loc(item)
#    3103             else:
#    3104                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1690                 raise ValueError('tolerance argument only valid if using pad, '
#    1691                                  'backfill or nearest lookups')
# -> 1692             return self._engine.get_loc(_values_from_object(key))
#    1693
#    1694         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'adj_sqft'
