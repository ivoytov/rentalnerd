# %%
# %load_ext sql
# %sql mysql://root@localhost/rental_nerd
# %sql mysql://prod:nerd@52.2.153.189/rental_nerd

# imports
import pandas as pd
import numpy as np
import datetime as dt
import timeit  # for timing models
import contextlib
from sklearn import metrics
from sklearn import cross_validation as cv
import matplotlib.pyplot as plt

import os
import gc

from slacker import Slacker
import json
import requests
from cloudinary.uploader import upload
from cloudinary.utils import cloudinary_url
from cloudinary.api import delete_resources_by_tag, resources_by_tag

# this allows plots to appear directly in the notebook
# %matplotlib inline

import xgboost as xgb

# today's date for output filenames
today = dt.date.today()

# where to save the xgb models - they get huge so keep them out of any git path
model_path = '/home/ilya/rentalnerd-models/'
csv_path = '/home/ilya/Code/rentalnerd/scraper/'

# booster parameters
param = {'verbose': 0,
         'silent': 0,
         'objective':'binary:logistic',
         'booster': 'gbtree',
         'eval_metric':'error', 
#          'updater': 'grow_gpu_hist',
         'eta': 0.1, # not tuned, learning rate with default of 0.3
         'max_depth': 10,  # all of the following parameters are __tuned__ so do not change them
         'alpha': 2.6456,
         'gamma': 6.4589, 
         'subsample': 0.9893,
         'colsample_bytree': 0.6759,
         'min_child_weight': 16,
         'max_delta_step': 0
#          'max_depth': 15,  # tuning from 6/9/2017
#          'alpha': 8.97,
#          'gamma': 9.37, 
#          'subsample': 0.8,
#          'colsample_bytree': 0.35,
#          'min_child_weight': 20,
#          'max_delta_step': 0.09
#          'max_depth': 5,  # tuning from 6/10/2017
#          'alpha': 0,
#          'gamma': 20, 
#          'subsample': 1,
#          'colsample_bytree': 1,
#          'min_child_weight': 1,
#          'max_delta_step': 9.6
        }

num_round = 5000 # pick a high number - XGB will abort as soon as accuracy drops in the testing set

import os
# slack secrets (in your ~/.bashrc)
webhook_url = os.environ.get('SLACK_URL')
slacker = Slacker(os.environ.get('SLACK_TOKEN'))

discount = 10.0 # consider sales within this percent of list to be "good sales"
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
def sanitize(data, zipcode_list = None):
    # abort if the city has no top zipcodes
    if data.empty:
        return 0    
    
    data.drop(['abnormal', 'bookmarked', 'created_at', 'ignore', 'is_latest', 'id', 'closed_diff_id', 'listed_diff_id',
                      'notes', 'source', 'updated_at', 'home_type', 'sfh', 'description', 
                    'event_name', 'neighborhood'], axis=1, inplace=True)
    
    # filters out any non-sensical values or fat finger mistakes in MLS listings
    print("Entries before filter: ", len(data))

    if(data.transaction_type.iloc[0] == 'sales'):
        data = data[ data.price > 50000 ]
    else:
        data = data [ data.price > 500 ]
    
    if(zipcode_list is not None):
        data = data[data.zipcode.isin(zipcode_list)]
        
#     data = data [ (data.price_closed - data.price_listed).abs() < 50000 ]

    slack("Entries after filter: %i" % len(data))
    
    # fills in some sensible defaults where data is missing
    data["near_golf_course"] = data["near_golf_course"].apply(lambda x: True if x == 1.0 else False)
    data["has_pool"] = data["has_pool"].apply(lambda x: True if x == 1.0 else False)
    data["garage"] = data["garage"].apply(lambda x: True if x == 1.0 else False)
    data['date_closed'] = data['date_closed'].apply(lambda x: 0 if x == None else (x - dt.date(2000, 1, 1)).days)
    data['date_closed'] = data['date_closed'].astype(int)
    data["school_district_id"] = data["school_district_id"].astype(str)
    
    # convert the area name into dummy variables
    dm = pd.get_dummies(data[['area_name', 'zipcode']], prefix=['area_name','zipcode'])
    data = pd.concat([data, dm], axis=1)
    del dm
    
    return data

def plot_rounds(plot):
    # uploads the graph to the web and returns the URL
    
    fig = plot.get_figure()
    fig.tight_layout()
    
    fig.savefig('temp_plot.png')
    
    response = upload("temp_plot.png")
    url, options = cloudinary_url(response['public_id'],
        format = response['format'],
        crop = "fill")
    return url

def slack(text, url = None, title = None):
    print("Slacking: " + text)
    
    if url == None:
        data=json.dumps({"text": text})
    else:
        data = json.dumps( { "text": text, "attachments": [ { "fallback": "Model MAE"
                                           , "title": title
                                           , "image_url": url } ] } )
    
    response = requests.post(webhook_url, data , headers={'Content-Type': 'application/json'})
    if response.status_code != 200:
        raise ValueError('Request to slack returned an error %s, the response is:\n%s' % (response.status_code, response.text))

# %%
limit = 100000000

# %%
query = %sql (\
    SELECT \
    area_name_zipcodes.area_name, \
    properties.*, \
    property_transaction_logs.id as 'transaction_id', \
    property_transaction_logs.*, \
    property_school_districts.school_district_id \
    FROM  \
    property_transaction_logs \
    LEFT JOIN \
    properties on properties.id = property_transaction_logs.`property_id`  \
    LEFT JOIN \
    area_name_zipcodes on properties.zipcode = area_name_zipcodes.zipcode \
    LEFT JOIN \
    property_school_districts ON property_school_districts.property_id = properties.id \
    where \
    home_type = 'sfh' AND \
    ( abnormal = false OR abnormal IS NULL OR abnormal = 0 ) and \
    properties.sqft between 1 and 10000 and \
    property_transaction_logs.price between 500 and 400000 and \
    properties.bedrooms <= 6 and \
    properties.bathrooms <= 6 and \
    transaction_type = 'sales' and  \
    date_closed is not null and \
    price_closed is not null and \
    days_on_market is not null and \
    transaction_status = 'closed' \
    ORDER BY property_transaction_logs.date_closed DESC \
    LIMIT :limit )


closed = query.DataFrame()
# Out:
# 192633 rows affected.

# %%
closed.columns.values
# Out:
# array(['area_name', 'id', 'address', 'neighborhood', 'bedrooms',
#        'bathrooms', 'sqft', 'source', 'origin_url', 'created_at',
#        'updated_at', 'latitude', 'longitude', 'elevation',
#        'lookup_address', 'luxurious', 'garage', 'year_built', 'level',
#        'dist_to_park', 'sfh', 'dist_to_golf_course', 'zipcode',
#        'near_golf_course', 'home_type', 'has_pool', 'bookmarked', 'notes',
#        'hoa_fees', 'lot', 'zestimate_rent', 'zestimate_sale', 'saves',
#        'event_name', 'construction', 'adult', 'description', 'rooms',
#        'stories', 'images', 'transaction_id', 'id', 'price',
#        'transaction_status', 'date_listed', 'date_closed',
#        'days_on_market', 'created_at', 'updated_at', 'property_id',
#        'transaction_type', 'is_latest', 'abnormal', 'ignore',
#        'closed_diff_id', 'listed_diff_id', 'price_listed', 'price_closed',
#        'date_transacted_latest', 'school_district_id'], dtype=object)

# %%
query = %sql (\
    SELECT \
    area_name_zipcodes.area_name, \
    properties.*, \
    property_transaction_logs.id as 'transaction_id', \
    property_transaction_logs.*, \
    property_school_districts.school_district_id \
    FROM  \
    property_transaction_logs \
    LEFT JOIN \
    properties on properties.id = property_transaction_logs.`property_id`  \
    LEFT JOIN \
    area_name_zipcodes on properties.zipcode = area_name_zipcodes.zipcode \
    LEFT JOIN \
    property_school_districts ON property_school_districts.property_id = properties.id \
    where \
    home_type = 'sfh' AND \
    is_latest = 1 AND \
    ( abnormal = false OR abnormal IS NULL OR abnormal = 0 ) and \
    properties.sqft between 1 and 10000 and \
    property_transaction_logs.price between 500 and 400000 and \
    properties.bedrooms <= 6 and \
    properties.bathrooms <= 6 and \
    transaction_type = 'sales' AND \
    transaction_status = 'open' AND \
    area_name = 'PH' \
    LIMIT :limit )

for_sale = query.DataFrame()
# Out:
# 11453 rows affected.

# %%
q = pd.concat([closed,for_sale])
q.set_index('property_id', inplace=True)
q.index.name = 'property_id'

# %%
print(closed.columns)
# Out:
# Index(['area_name', 'id', 'address', 'neighborhood', 'bedrooms', 'bathrooms',
#        'sqft', 'source', 'origin_url', 'created_at', 'updated_at', 'latitude',
#        'longitude', 'elevation', 'lookup_address', 'luxurious', 'garage',
#        'year_built', 'level', 'dist_to_park', 'sfh', 'dist_to_golf_course',
#        'zipcode', 'near_golf_course', 'home_type', 'has_pool', 'bookmarked',
#        'notes', 'hoa_fees', 'lot', 'zestimate_rent', 'zestimate_sale', 'saves',
#        'event_name', 'construction', 'adult', 'description', 'rooms',
#        'stories', 'images', 'transaction_id', 'id', 'price',
#        'transaction_status', 'date_listed', 'date_closed', 'days_on_market',
#        'created_at', 'updated_at', 'property_id', 'transaction_type',
#        'is_latest', 'abnormal', 'ignore', 'closed_diff_id', 'listed_diff_id',
#        'price_listed', 'price_closed', 'date_transacted_latest',
#        'school_district_id'],
#       dtype='object')

# %%
print(q.columns)
q = sanitize(q)
# Out:
# Index(['area_name', 'id', 'address', 'neighborhood', 'bedrooms', 'bathrooms',
#        'sqft', 'source', 'origin_url', 'created_at', 'updated_at', 'latitude',
#        'longitude', 'elevation', 'lookup_address', 'luxurious', 'garage',
#        'year_built', 'level', 'dist_to_park', 'sfh', 'dist_to_golf_course',
#        'zipcode', 'near_golf_course', 'home_type', 'has_pool', 'bookmarked',
#        'notes', 'hoa_fees', 'lot', 'zestimate_rent', 'zestimate_sale', 'saves',
#        'event_name', 'construction', 'adult', 'description', 'rooms',
#        'stories', 'images', 'transaction_id', 'id', 'price',
#        'transaction_status', 'date_listed', 'date_closed', 'days_on_market',
#        'created_at', 'updated_at', 'transaction_type', 'is_latest', 'abnormal',
#        'ignore', 'closed_diff_id', 'listed_diff_id', 'price_listed',
#        'price_closed', 'date_transacted_latest', 'school_district_id'],
#       dtype='object')
# Entries before filter:  204086
# Slacking: Entries after filter: 183217
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for_sale = q[q.transaction_status == 'open']
sold = q[q.transaction_status == 'closed']

# %%
sold['good_sell'] = (sold.price_closed >= (sold.price_listed * (1 - discount )))
# Out:
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sold[['good_sell','price_listed','price_closed','days_on_market']].head(20)
# Out:
#             good_sell  price_listed price_closed days_on_market
# property_id
# 4234493          True      150000.0        59000          16043
# 4115746          True       99900.0        82900          15328
# 6892289          True      339000.0       320000             47
# 837292           True      200000.0       200000             45
# 2061569          True      175900.0       175000             78
# 376414           True      303900.0       300000             38
# 1575509          True      249000.0       245000             39
# 7849052          True      218000.0       218000             57
# 507755           True      369900.0       360000             30
# 8951394          True      198500.0       192500              0
# 7563145          True      249000.0       250000              1
# 7385609          True      165000.0       165000            105
# 7429824          True      245000.0       245000             34
# 935658           True      189900.0       187000             35
# 941931           True      165000.0       165000             37
# 7427138          True      295500.0       287500             52
# 8950815          True      197770.0       202000             35
# 1941536          True      269900.0       272500             55
# 8948703          True      260000.0       265000             41
# 1538780          True      369900.0       370000             94

# %%
for_sale['days_on_market'] = (today - for_sale.date_listed).apply(lambda x: x.days)
for_sale = for_sale[for_sale.days_on_market < 180]

for_sale[['price','price_closed','date_listed','days_on_market', 'transaction_status']].head(20)
# Out:
# /home/ilya/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#               price price_closed date_listed  days_on_market  \
# property_id
# 31822        395000         None  2017-05-16              39
# 32259        395000         None  2017-05-26              29
# 32611        399888         None  2017-04-25              60
# 32803        395000         None  2017-06-15               9
# 32834         75000         None  2017-06-09              15
# 1955193      170000         None  2016-09-14             283
# 8962038      399500         None  2017-06-22               2
# 306980       135000         None  2017-05-19              36
# 307200       279000         None  2016-04-01             449
# 307703       348900         None  2017-06-18               6
# 307724       358900         None  2017-04-27              58
# 307749       365000         None  2017-04-06              79
# 8924012      230000         None  2017-06-12              12
# 24695        204900         None  2016-05-26             394
# 25052        240999         None  2017-02-15             129
# 311113       349900         None  2017-06-01              23
# 311537       400000         None  2017-03-07             109
# 311567       325000         None  2017-03-23              93
# 312013       208000         None  2013-01-04            1632
# 312125        89000         None  2014-01-30            1241
#
#             transaction_status
# property_id
# 31822                     open
# 32259                     open
# 32611                     open
# 32803                     open
# 32834                     open
# 1955193                   open
# 8962038                   open
# 306980                    open
# 307200                    open
# 307703                    open
# 307724                    open
# 307749                    open
# 8924012                   open
# 24695                     open
# 25052                     open
# 311113                    open
# 311537                    open
# 311567                    open
# 312013                    open
# 312125                    open

# %%
for_sale.days_on_market.hist()

# %%
ind2remove = ['Unnamed: 0', 'id', 'address', 'area_name', 'date_listed', 'listed_diff_id', 'lookup_address',
              'origin_url', 'neighborhood', 'zipcode', 'luxurious', 'transaction_status', 'transaction_type',
              'images','zestimate_sale','zestimate_rent', 'price', 'price_closed', 'date_transacted_latest', 
              'school_district_id']
factors = np.setdiff1d(sold.columns, ind2remove).tolist()

# %%
sales_train, sales_test = cv.train_test_split(sold, test_size = 0.25) # set aside X% of the dataset for testing

# %%
sales_train.columns.values
# Out:
# array(['area_name', 'address', 'bedrooms', 'bathrooms', 'sqft',
#        'origin_url', 'latitude', 'longitude', 'elevation',
#        'lookup_address', 'luxurious', 'garage', 'year_built', 'level',
#        'dist_to_park', 'dist_to_golf_course', 'zipcode',
#        'near_golf_course', 'has_pool', 'hoa_fees', 'lot', 'zestimate_rent',
#        'zestimate_sale', 'saves', 'construction', 'adult', 'rooms',
#        'stories', 'images', 'transaction_id', 'price',
#        'transaction_status', 'date_listed', 'date_closed',
#        'days_on_market', 'transaction_type', 'price_listed',
#        'price_closed', 'date_transacted_latest', 'school_district_id',
#        'area_name_BAY_AREA', 'area_name_DENVER', 'area_name_DETROIT',
#        'area_name_HOUSTON', 'area_name_PH', 'area_name_PORTLAND',
#        'area_name_SEATTLE', 'area_name_SF', 'area_name_ST_LOUIS',
#        'area_name_TUSCON', 'area_name_VEGAS', 'zipcode_07924',
#        'zipcode_15768', 'zipcode_31406', 'zipcode_32055', 'zipcode_33186',
#        'zipcode_35077', 'zipcode_36541', 'zipcode_36582', 'zipcode_36619',
#        'zipcode_36693', 'zipcode_36695', 'zipcode_47371', 'zipcode_48021',
#        'zipcode_48030', 'zipcode_48075', 'zipcode_48089', 'zipcode_48091',
#        'zipcode_48101', 'zipcode_48122', 'zipcode_48124', 'zipcode_48126',
#        'zipcode_48127', 'zipcode_48128', 'zipcode_48146', 'zipcode_48152',
#        'zipcode_48192', 'zipcode_48201', 'zipcode_48202', 'zipcode_48203',
#        'zipcode_48204', 'zipcode_48205', 'zipcode_48206', 'zipcode_48207',
#        'zipcode_48208', 'zipcode_48209', 'zipcode_48210', 'zipcode_48211',
#        'zipcode_48212', 'zipcode_48213', 'zipcode_48214', 'zipcode_48215',
#        'zipcode_48216', 'zipcode_48217', 'zipcode_48219', 'zipcode_48220',
#        'zipcode_48221', 'zipcode_48223', 'zipcode_48224', 'zipcode_48226',
#        'zipcode_48227', 'zipcode_48228', 'zipcode_48230', 'zipcode_48234',
#        'zipcode_48235', 'zipcode_48237', 'zipcode_48238', 'zipcode_48239',
#        'zipcode_48240', 'zipcode_48336', 'zipcode_63101', 'zipcode_63103',
#        'zipcode_63104', 'zipcode_63105', 'zipcode_63106', 'zipcode_63107',
#        'zipcode_63108', 'zipcode_63109', 'zipcode_63110', 'zipcode_63111',
#        'zipcode_63112', 'zipcode_63113', 'zipcode_63114', 'zipcode_63115',
#        'zipcode_63117', 'zipcode_63122', 'zipcode_63125', 'zipcode_63126',
#        'zipcode_63127', 'zipcode_63128', 'zipcode_63129', 'zipcode_63131',
#        'zipcode_63132', 'zipcode_63134', 'zipcode_63135', 'zipcode_63137',
#        'zipcode_63138', 'zipcode_63139', 'zipcode_63141', 'zipcode_63143',
#        'zipcode_63144', 'zipcode_63146', 'zipcode_75028', 'zipcode_75065',
#        'zipcode_75077', 'zipcode_75407', 'zipcode_75409', 'zipcode_75454',
#        'zipcode_75490', 'zipcode_76210', 'zipcode_77002', 'zipcode_77003',
#        'zipcode_77004', 'zipcode_77005', 'zipcode_77006', 'zipcode_77007',
#        'zipcode_77008', 'zipcode_77009', 'zipcode_77011', 'zipcode_77012',
#        'zipcode_77013', 'zipcode_77014', 'zipcode_77015', 'zipcode_77016',
#        'zipcode_77017', 'zipcode_77018', 'zipcode_77019', 'zipcode_77020',
#        'zipcode_77021', 'zipcode_77022', 'zipcode_77023', 'zipcode_77024',
#        'zipcode_77025', 'zipcode_77026', 'zipcode_77028', 'zipcode_77029',
#        'zipcode_77031', 'zipcode_77033', 'zipcode_77034', 'zipcode_77035',
#        'zipcode_77036', 'zipcode_77037', 'zipcode_77038', 'zipcode_77039',
#        'zipcode_77040', 'zipcode_77042', 'zipcode_77043', 'zipcode_77044',
#        'zipcode_77045', 'zipcode_77047', 'zipcode_77048', 'zipcode_77049',
#        'zipcode_77051', 'zipcode_77053', 'zipcode_77054', 'zipcode_77055',
#        'zipcode_77056', 'zipcode_77057', 'zipcode_77058', 'zipcode_77059',
#        'zipcode_77060', 'zipcode_77061', 'zipcode_77062', 'zipcode_77063',
#        'zipcode_77064', 'zipcode_77066', 'zipcode_77067', 'zipcode_77068',
#        'zipcode_77069', 'zipcode_77070', 'zipcode_77071', 'zipcode_77072',
#        'zipcode_77073', 'zipcode_77074', 'zipcode_77075', 'zipcode_77076',
#        'zipcode_77077', 'zipcode_77078', 'zipcode_77079', 'zipcode_77080',
#        'zipcode_77082', 'zipcode_77083', 'zipcode_77084', 'zipcode_77085',
#        'zipcode_77086', 'zipcode_77087', 'zipcode_77088', 'zipcode_77089',
#        'zipcode_77090', 'zipcode_77091', 'zipcode_77092', 'zipcode_77093',
#        'zipcode_77094', 'zipcode_77095', 'zipcode_77096', 'zipcode_77098',
#        'zipcode_77099', 'zipcode_77336', 'zipcode_77339', 'zipcode_77345',
#        'zipcode_77381', 'zipcode_77382', 'zipcode_77429', 'zipcode_77433',
#        'zipcode_77441', 'zipcode_77449', 'zipcode_77450', 'zipcode_77477',
#        'zipcode_77502', 'zipcode_77506', 'zipcode_77511', 'zipcode_77530',
#        'zipcode_77536', 'zipcode_77546', 'zipcode_77547', 'zipcode_77571',
#        'zipcode_77573', 'zipcode_77581', 'zipcode_77584', 'zipcode_77598',
#        'zipcode_80002', 'zipcode_80003', 'zipcode_80010', 'zipcode_80011',
#        'zipcode_80012', 'zipcode_80013', 'zipcode_80014', 'zipcode_80015',
#        'zipcode_80016', 'zipcode_80017', 'zipcode_80021', 'zipcode_80022',
#        'zipcode_80030', 'zipcode_80033', 'zipcode_80110', 'zipcode_80111',
#        'zipcode_80113', 'zipcode_80120', 'zipcode_80121', 'zipcode_80123',
#        'zipcode_80127', 'zipcode_80128', 'zipcode_80203', 'zipcode_80204',
#        'zipcode_80205', 'zipcode_80206', 'zipcode_80207', 'zipcode_80209',
#        'zipcode_80210', 'zipcode_80211', 'zipcode_80212', 'zipcode_80214',
#        'zipcode_80215', 'zipcode_80216', 'zipcode_80218', 'zipcode_80219',
#        'zipcode_80220', 'zipcode_80221', 'zipcode_80222', 'zipcode_80223',
#        'zipcode_80224', 'zipcode_80226', 'zipcode_80227', 'zipcode_80228',
#        'zipcode_80229', 'zipcode_80230', 'zipcode_80231', 'zipcode_80232',
#        'zipcode_80233', 'zipcode_80234', 'zipcode_80235', 'zipcode_80236',
#        'zipcode_80237', 'zipcode_80238', 'zipcode_80239', 'zipcode_80241',
#        'zipcode_80246', 'zipcode_80247', 'zipcode_80249', 'zipcode_80260',
#        'zipcode_80465', 'zipcode_80601', 'zipcode_83646', 'zipcode_83702',
#        'zipcode_83703', 'zipcode_83704', 'zipcode_83705', 'zipcode_83706',
#        'zipcode_83709', 'zipcode_83712', 'zipcode_83713', 'zipcode_83714',
#        'zipcode_83716', 'zipcode_85003', 'zipcode_85004', 'zipcode_85006',
#        'zipcode_85007', 'zipcode_85008', 'zipcode_85009', 'zipcode_85012',
#        'zipcode_85013', 'zipcode_85014', 'zipcode_85015', 'zipcode_85016',
#        'zipcode_85017', 'zipcode_85018', 'zipcode_85019', 'zipcode_85020',
#        'zipcode_85021', 'zipcode_85022', 'zipcode_85023', 'zipcode_85024',
#        'zipcode_85027', 'zipcode_85028', 'zipcode_85029', 'zipcode_85031',
#        'zipcode_85032', 'zipcode_85033', 'zipcode_85034', 'zipcode_85035',
#        'zipcode_85037', 'zipcode_85040', 'zipcode_85041', 'zipcode_85042',
#        'zipcode_85043', 'zipcode_85044', 'zipcode_85045', 'zipcode_85048',
#        'zipcode_85050', 'zipcode_85051', 'zipcode_85053', 'zipcode_85054',
#        'zipcode_85083', 'zipcode_85085', 'zipcode_85086', 'zipcode_85087',
#        'zipcode_85118', 'zipcode_85120', 'zipcode_85132', 'zipcode_85138',
#        'zipcode_85139', 'zipcode_85140', 'zipcode_85142', 'zipcode_85143',
#        'zipcode_85201', 'zipcode_85202', 'zipcode_85203', 'zipcode_85204',
#        'zipcode_85205', 'zipcode_85206', 'zipcode_85207', 'zipcode_85208',
#        'zipcode_85209', 'zipcode_85210', 'zipcode_85212', 'zipcode_85213',
#        'zipcode_85215', 'zipcode_85224', 'zipcode_85225', 'zipcode_85226',
#        'zipcode_85233', 'zipcode_85234', 'zipcode_85238', 'zipcode_85239',
#        'zipcode_85242', 'zipcode_85248', 'zipcode_85249', 'zipcode_85250',
#        'zipcode_85251', 'zipcode_85253', 'zipcode_85254', 'zipcode_85255',
#        'zipcode_85257', 'zipcode_85258', 'zipcode_85259', 'zipcode_85260',
#        'zipcode_85262', 'zipcode_85263', 'zipcode_85266', 'zipcode_85268',
#        'zipcode_85281', 'zipcode_85282', 'zipcode_85283', 'zipcode_85284',
#        'zipcode_85286', 'zipcode_85295', 'zipcode_85296', 'zipcode_85297',
#        'zipcode_85298', 'zipcode_85301', 'zipcode_85302', 'zipcode_85303',
#        'zipcode_85304', 'zipcode_85305', 'zipcode_85306', 'zipcode_85307',
#        'zipcode_85308', 'zipcode_85310', 'zipcode_85320', 'zipcode_85321',
#        'zipcode_85322', 'zipcode_85323', 'zipcode_85326', 'zipcode_85331',
#        'zipcode_85335', 'zipcode_85337', 'zipcode_85338', 'zipcode_85339',
#        'zipcode_85340', 'zipcode_85342', 'zipcode_85345', 'zipcode_85351',
#        'zipcode_85353', 'zipcode_85354', 'zipcode_85355', 'zipcode_85361',
#        'zipcode_85363', 'zipcode_85373', 'zipcode_85374', 'zipcode_85375',
#        'zipcode_85377', 'zipcode_85378', 'zipcode_85379', 'zipcode_85381',
#        'zipcode_85382', 'zipcode_85383', 'zipcode_85387', 'zipcode_85388',
#        'zipcode_85390', 'zipcode_85392', 'zipcode_85395', 'zipcode_85396',
#        'zipcode_85615', 'zipcode_85641', 'zipcode_85701', 'zipcode_85704',
#        'zipcode_85705', 'zipcode_85706', 'zipcode_85710', 'zipcode_85711',
#        'zipcode_85712', 'zipcode_85713', 'zipcode_85714', 'zipcode_85715',
#        'zipcode_85716', 'zipcode_85718', 'zipcode_85719', 'zipcode_85730',
#        'zipcode_85745', 'zipcode_85746', 'zipcode_85747', 'zipcode_85748',
#        'zipcode_85749', 'zipcode_85750', 'zipcode_85756', 'zipcode_85757',
#        'zipcode_85930', 'zipcode_85936', 'zipcode_86301', 'zipcode_86303',
#        'zipcode_86305', 'zipcode_86314', 'zipcode_86327', 'zipcode_89030',
#        'zipcode_89032', 'zipcode_89074', 'zipcode_89101', 'zipcode_89102',
#        'zipcode_89103', 'zipcode_89104', 'zipcode_89106', 'zipcode_89107',
#        'zipcode_89108', 'zipcode_89109', 'zipcode_89110', 'zipcode_89113',
#        'zipcode_89115', 'zipcode_89117', 'zipcode_89118', 'zipcode_89119',
#        'zipcode_89121', 'zipcode_89122', 'zipcode_89123', 'zipcode_89124',
#        'zipcode_89128', 'zipcode_89129', 'zipcode_89130', 'zipcode_89131',
#        'zipcode_89134', 'zipcode_89135', 'zipcode_89138', 'zipcode_89139',
#        'zipcode_89141', 'zipcode_89142', 'zipcode_89143', 'zipcode_89144',
#        'zipcode_89145', 'zipcode_89146', 'zipcode_89147', 'zipcode_89148',
#        'zipcode_89149', 'zipcode_89156', 'zipcode_89166', 'zipcode_89169',
#        'zipcode_89178', 'zipcode_89179', 'zipcode_89183', 'zipcode_90266',
#        'zipcode_91711', 'zipcode_93292', 'zipcode_93901', 'zipcode_93906',
#        'zipcode_93933', 'zipcode_93960', 'zipcode_94014', 'zipcode_94019',
#        'zipcode_94020', 'zipcode_94025', 'zipcode_94030', 'zipcode_94037',
#        'zipcode_94038', 'zipcode_94044', 'zipcode_94061', 'zipcode_94062',
#        'zipcode_94063', 'zipcode_94066', 'zipcode_94070', 'zipcode_94080',
#        'zipcode_94085', 'zipcode_94086', 'zipcode_94087', 'zipcode_94089',
#        'zipcode_94107', 'zipcode_94110', 'zipcode_94112', 'zipcode_94122',
#        'zipcode_94124', 'zipcode_94131', 'zipcode_94301', 'zipcode_94303',
#        'zipcode_94305', 'zipcode_94401', 'zipcode_94402', 'zipcode_94403',
#        'zipcode_94501', 'zipcode_94502', 'zipcode_94503', 'zipcode_94505',
#        'zipcode_94506', 'zipcode_94507', 'zipcode_94508', 'zipcode_94509',
#        'zipcode_94510', 'zipcode_94511', 'zipcode_94513', 'zipcode_94514',
#        'zipcode_94515', 'zipcode_94516', 'zipcode_94517', 'zipcode_94518',
#        'zipcode_94519', 'zipcode_94520', 'zipcode_94521', 'zipcode_94523',
#        'zipcode_94525', 'zipcode_94526', 'zipcode_94530', 'zipcode_94531',
#        'zipcode_94533', 'zipcode_94534', 'zipcode_94536', 'zipcode_94538',
#        'zipcode_94539', 'zipcode_94541', 'zipcode_94542', 'zipcode_94544',
#        'zipcode_94545', 'zipcode_94546', 'zipcode_94547', 'zipcode_94548',
#        'zipcode_94549', 'zipcode_94550', 'zipcode_94551', 'zipcode_94553',
#        'zipcode_94555', 'zipcode_94556', 'zipcode_94558', 'zipcode_94559',
#        'zipcode_94560', 'zipcode_94561', 'zipcode_94563', 'zipcode_94564',
#        'zipcode_94565', 'zipcode_94566', 'zipcode_94567', 'zipcode_94568',
#        'zipcode_94569', 'zipcode_94572', 'zipcode_94574', 'zipcode_94577',
#        'zipcode_94578', 'zipcode_94579', 'zipcode_94580', 'zipcode_94582',
#        'zipcode_94583', 'zipcode_94585', 'zipcode_94586', 'zipcode_94587',
#        'zipcode_94588', 'zipcode_94589', 'zipcode_94590', 'zipcode_94591',
#        'zipcode_94592', 'zipcode_94595', 'zipcode_94596', 'zipcode_94597',
#        'zipcode_94598', 'zipcode_94601', 'zipcode_94602', 'zipcode_94603',
#        'zipcode_94605', 'zipcode_94606', 'zipcode_94607', 'zipcode_94608',
#        'zipcode_94609', 'zipcode_94610', 'zipcode_94611', 'zipcode_94612',
#        'zipcode_94618', 'zipcode_94619', 'zipcode_94621', 'zipcode_94702',
#        'zipcode_94703', 'zipcode_94704', 'zipcode_94705', 'zipcode_94706',
#        'zipcode_94707', 'zipcode_94708', 'zipcode_94709', 'zipcode_94710',
#        'zipcode_94801', 'zipcode_94803', 'zipcode_94804', 'zipcode_94805',
#        'zipcode_94806', 'zipcode_94901', 'zipcode_94903', 'zipcode_94928',
#        'zipcode_94930', 'zipcode_94931', 'zipcode_94941', 'zipcode_94945',
#        'zipcode_94947', 'zipcode_94949', 'zipcode_94952', 'zipcode_94954',
#        'zipcode_94960', 'zipcode_95005', 'zipcode_95006', 'zipcode_95007',
#        'zipcode_95008', 'zipcode_95018', 'zipcode_95020', 'zipcode_95023',
#        'zipcode_95035', 'zipcode_95037', 'zipcode_95046', 'zipcode_95050',
#        'zipcode_95051', 'zipcode_95054', 'zipcode_95060', 'zipcode_95062',
#        'zipcode_95066', 'zipcode_95070', 'zipcode_95076', 'zipcode_95110',
#        'zipcode_95111', 'zipcode_95112', 'zipcode_95116', 'zipcode_95117',
#        'zipcode_95118', 'zipcode_95120', 'zipcode_95121', 'zipcode_95122',
#        'zipcode_95123', 'zipcode_95124', 'zipcode_95125', 'zipcode_95126',
#        'zipcode_95127', 'zipcode_95128', 'zipcode_95129', 'zipcode_95131',
#        'zipcode_95132', 'zipcode_95133', 'zipcode_95135', 'zipcode_95136',
#        'zipcode_95138', 'zipcode_95139', 'zipcode_95148', 'zipcode_95307',
#        'zipcode_95336', 'zipcode_95337', 'zipcode_95340', 'zipcode_95348',
#        'zipcode_95391', 'zipcode_95401', 'zipcode_95403', 'zipcode_95404',
#        'zipcode_95405', 'zipcode_95407', 'zipcode_95409', 'zipcode_95421',
#        'zipcode_95422', 'zipcode_95423', 'zipcode_95424', 'zipcode_95426',
#        'zipcode_95436', 'zipcode_95437', 'zipcode_95443', 'zipcode_95445',
#        'zipcode_95446', 'zipcode_95448', 'zipcode_95449', 'zipcode_95451',
#        'zipcode_95453', 'zipcode_95457', 'zipcode_95458', 'zipcode_95460',
#        'zipcode_95461', 'zipcode_95462', 'zipcode_95464', 'zipcode_95467',
#        'zipcode_95469', 'zipcode_95472', 'zipcode_95476', 'zipcode_95482',
#        'zipcode_95485', 'zipcode_95490', 'zipcode_95492', 'zipcode_95616',
#        'zipcode_95628', 'zipcode_95666', 'zipcode_95687', 'zipcode_95688',
#        'zipcode_96140', 'zipcode_97005', 'zipcode_97015', 'zipcode_97030',
#        'zipcode_97034', 'zipcode_97035', 'zipcode_97080', 'zipcode_97086',
#        'zipcode_97201', 'zipcode_97202', 'zipcode_97203', 'zipcode_97206',
#        'zipcode_97209', 'zipcode_97210', 'zipcode_97211', 'zipcode_97212',
#        'zipcode_97213', 'zipcode_97214', 'zipcode_97215', 'zipcode_97216',
#        'zipcode_97217', 'zipcode_97218', 'zipcode_97219', 'zipcode_97220',
#        'zipcode_97221', 'zipcode_97222', 'zipcode_97223', 'zipcode_97224',
#        'zipcode_97225', 'zipcode_97227', 'zipcode_97229', 'zipcode_97230',
#        'zipcode_97231', 'zipcode_97232', 'zipcode_97233', 'zipcode_97236',
#        'zipcode_97239', 'zipcode_97266', 'zipcode_97267', 'zipcode_97701',
#        'zipcode_97703', 'zipcode_98011', 'zipcode_98028', 'zipcode_98034',
#        'zipcode_98040', 'zipcode_98056', 'zipcode_98057', 'zipcode_98103',
#        'zipcode_98105', 'zipcode_98106', 'zipcode_98107', 'zipcode_98108',
#        'zipcode_98112', 'zipcode_98115', 'zipcode_98116', 'zipcode_98117',
#        'zipcode_98118', 'zipcode_98119', 'zipcode_98122', 'zipcode_98125',
#        'zipcode_98126', 'zipcode_98133', 'zipcode_98136', 'zipcode_98144',
#        'zipcode_98146', 'zipcode_98148', 'zipcode_98155', 'zipcode_98166',
#        'zipcode_98168', 'zipcode_98177', 'zipcode_98178', 'zipcode_98188',
#        'zipcode_98198', 'zipcode_98199', 'zipcode_98607', 'zipcode_98660',
#        'zipcode_98661', 'zipcode_98663', 'zipcode_98664', 'zipcode_98665',
#        'zipcode_98683', 'good_sell'], dtype=object)

# %%
# init empty model that we can load into on the second iteration
bst = xgb.Booster()

# first run the price model
label = 'good_sell'
f = factors
f.remove(label) # this happens in place

dtrain = xgb.DMatrix(sales_train[f].values, label=sales_train[label], feature_names=sales_train[f].columns.values)
dtest = xgb.DMatrix(sales_test[f].values, label=sales_test[label], feature_names=f)
watchlist  = [(dtrain,'train'),(dtest,'eval')]

progress = dict()
xgb_model = xgb.train( param, dtrain, num_round, evals = watchlist, early_stopping_rounds = 20 
                      , verbose_eval = 10, evals_result = progress )

if hasattr(xgb_model, 'best_score'):
    print("Early stopping occured, best_score %f, best_iteration %i" % (xgb_model.best_score, xgb_model.best_iteration))
    
slack("Training set: %i\tTesting set: %i" % (len(sales_train.index), len(sales_test.index)))
# Out:
# [0]	train-error:0.003494	eval-error:0.003673
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [10]	train-error:0	eval-error:0
# [20]	train-error:0	eval-error:0
# Stopping. Best iteration:
# [1]	train-error:0	eval-error:0
#
# Early stopping occured, best_score 0.000000, best_iteration 1
# Slacking: Training set: 129066	Testing set: 43022

# %%
sales_train.good_sell
# Out:
# property_id
# 7400270    True
# 4217031    True
# 7389545    True
# 1876493    True
# 2183097    True
# 5583945    True
# 357174     True
# 4182678    True
# 4842999    True
# 1528713    True
# 1857434    True
# 6285038    True
# 1151811    True
# 4095138    True
# 4104051    True
# 6909090    True
# 1003890    True
# 54364      True
# 1876868    True
# 1858572    True
# 7458590    True
# 2071242    True
# 7132552    True
# 6343854    True
# 7085836    True
# 6982619    True
# 4735766    True
# 7315564    True
# 6267712    True
# 937356     True
#            ...
# 137906     True
# 637433     True
# 5769889    True
# 7086047    True
# 1845941    True
# 7221615    True
# 6269308    True
# 366509     True
# 6589813    True
# 767342     True
# 341046     True
# 933986     True
# 1500198    True
# 5747609    True
# 1157982    True
# 1547128    True
# 7099702    True
# 150280     True
# 5047624    True
# 91599      True
# 7067024    True
# 5749213    True
# 912734     True
# 5526542    True
# 1924930    True
# 6853710    True
# 1874077    True
# 2156208    True
# 427568     True
# 6374448    True
# Name: good_sell, dtype: bool

# %%
xgb_model.save_model(model_path + 'good_sell_' + today.strftime('%Y%m%d') + '.model')

# %%
curve = pd.DataFrame()
curve['test'] = progress['eval']['error']
curve['train'] = progress['train']['error']

url = plot_rounds(curve.plot())
slack("", url, "Error by Round (%)")

url = plot_rounds(xgb.plot_importance(xgb_model,max_num_features=20))
slack("", url, "Feature Importance")
# Out:
# /home/ilya/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Slacking:
# /home/ilya/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Slacking:

# %%
# load for sale properties
target = xgb.DMatrix( for_sale[f].values, feature_names=f)
ypred = xgb_model.predict(target, ntree_limit=(xgb_model.best_iteration if hasattr(xgb_model, 'best_score') else None))

# %%
values = np.column_stack((for_sale.index.values
                         ,for_sale.transaction_id.values
                         ,for_sale.address.values
                         ,ypred
                         ,for_sale.price.values
                         ,for_sale['origin_url'].values))
output = pd.DataFrame(values[:,1:],index=values[:,0],columns=['transaction_id', 'address','ypred',
                                                              'list', 'url'])
output.index.name = 'property_id'
output = output.sort_values(by='ypred',ascending=False)
# output = output[output.ypred > 0.50]
file = csv_path + 'good_sell/gs_target_list_' + today.strftime('%Y%m%d') + '.csv'
output.to_csv(file)
slacker.files.upload(file, channels='#progress')

# %%
output.head(10)
# Out:
#             transaction_id                                 address    ypred  \
# property_id
# 31822             17891939  306 W Edgemont Ave, Phoenix, AZ 85003   0.54954
# 871429            17750645   938 E Corrall St, Avondale, AZ 85323   0.54954
# 872347            21810415    125 N 116th Ave, Avondale, AZ 85323   0.54954
# 872460            19980117    1313 S 121st Ln, Avondale, AZ 85323   0.54954
# 872499            21810429    1318 S 121st Ln, Avondale, AZ 85323   0.54954
# 872539            17859827   1401 S 122nd Ave, Avondale, AZ 85323   0.54954
# 872640            17932207    1610 S 116th Ln, Avondale, AZ 85323   0.54954
# 872794            21810497    2305 S 119th Dr, Avondale, AZ 85323   0.54954
# 873271            19984818       619 S 2nd St, Avondale, AZ 85323   0.54954
# 873281            21807618    710 S 120th Ave, Avondale, AZ 85323   0.54954
#
#                list                                                url
# property_id
# 31822        395000  https://www.zillow.com/homedetails/306-W-Edgem...
# 871429       218000  https://www.zillow.com/homedetails/938-E-Corra...
# 872347       225000  https://www.zillow.com/homedetails/125-N-116th...
# 872460       169000  https://www.zillow.com/homedetails/1313-S-121s...
# 872499       177000  https://www.zillow.com/homedetails/1318-S-121s...
# 872539       192400  https://www.zillow.com/homedetails/1401-S-122n...
# 872640       214900  https://www.zillow.com/homedetails/1610-S-116t...
# 872794       279900  https://www.zillow.com/homedetails/2305-S-119t...
# 873271       150000  https://www.zillow.com/homedetails/619-S-2nd-S...
# 873281       245000  https://www.zillow.com/homedetails/710-S-120th...

# %%
len(for_sale.index)
# Out:
# 11129
