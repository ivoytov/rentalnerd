# %%
# %load_ext sql
# %sql mysql://prod:nerd@52.2.153.189/rental_nerd
# %config SqlMagic.feedback=False
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
query = %sql (\
    SELECT \
    id as 'property_id' \
    FROM \
    properties)

i = query.DataFrame().values

# %%
bad_ones = []
i = i[1000000:2000000] # change based on what set of IDs you want

# %%
for property_id in i:
    property_id = property_id[0]
    if property_id % 1000 == 0:
        print("%i property_id processed" % property_id)
        
    query = %sql (\
        SELECT \
        ptl_1.property_id, \
        count(1) as 'bad_instances'\
        FROM \
        property_transaction_logs AS ptl_1, \
        property_transaction_logs AS ptl_2 \
        WHERE \
        ptl_1.`property_id`= ptl_2.`property_id` AND \
        ptl_1.`transaction_type` = ptl_2.`transaction_type` AND \
        ptl_1.id <> ptl_2.id \
        AND \
        ( \
        ( ptl_1.date_listed IS NOT NULL AND \
        ptl_2.date_listed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_1.date_listed < ptl_2.date_listed AND ptl_2.date_listed < ptl_1.date_closed \
        ) \
        OR \
        ( ptl_1.date_listed IS NOT NULL AND \
        ptl_2.date_closed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_1.date_listed < ptl_2.date_closed AND \
        ptl_2.date_closed < ptl_1.date_closed \
        ) \
         OR ( \
        ptl_1.date_listed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_2.date_listed IS NOT NULL AND \
        ptl_2.date_closed IS NOT NULL AND \
        ptl_1.date_listed > ptl_2.date_listed AND \
        ptl_1.date_closed < ptl_2.date_closed ) ) \
        AND \
        ptl_1.property_id = :property_id )
    
    if(query.DataFrame().bad_instances.ix[0] == 1):
        bad_ones.append(property_id)
        f = open('bad_instances_2mm.txt', 'a')
        print(property_id, file=f,flush=False)
        f.close()
# Out:
# 2284000 property_id processed
# 2286000 property_id processed
# 2291000 property_id processed
# 2292000 property_id processed
# 2293000 property_id processed
# 2294000 property_id processed
# 2296000 property_id processed
# 2298000 property_id processed
# 2300000 property_id processed
# 2301000 property_id processed
# 2303000 property_id processed
# 2306000 property_id processed
# 2308000 property_id processed
# 2309000 property_id processed
# 2310000 property_id processed
# 2312000 property_id processed
# 2313000 property_id processed
# 2314000 property_id processed
# 2315000 property_id processed
# 2316000 property_id processed
# 2317000 property_id processed
# 2318000 property_id processed
# 2319000 property_id processed
# 2320000 property_id processed
# 2321000 property_id processed
# 2330000 property_id processed
# 2335000 property_id processed
# 2336000 property_id processed
# 2338000 property_id processed
# 2341000 property_id processed
# 2342000 property_id processed
# 2349000 property_id processed
# 2350000 property_id processed
# 2352000 property_id processed
# 2353000 property_id processed
# 2354000 property_id processed
# 2358000 property_id processed
# 2360000 property_id processed
# 2362000 property_id processed
# 2363000 property_id processed
# 2364000 property_id processed
# 2365000 property_id processed
# 2366000 property_id processed
# 2367000 property_id processed
# 2368000 property_id processed
# 2370000 property_id processed
# 2371000 property_id processed
# 2374000 property_id processed
# 2375000 property_id processed
# 2378000 property_id processed
# 2381000 property_id processed
# 2383000 property_id processed
# 2385000 property_id processed
# 2386000 property_id processed
# 2393000 property_id processed
# 2394000 property_id processed
# 2396000 property_id processed
# 2398000 property_id processed
# 2401000 property_id processed
# 2403000 property_id processed
# 2404000 property_id processed
# 2407000 property_id processed
# 2412000 property_id processed
# 2413000 property_id processed
# 2416000 property_id processed
# 2420000 property_id processed
# 2421000 property_id processed
# 2424000 property_id processed
# 2426000 property_id processed
# 2430000 property_id processed
# 2433000 property_id processed
# 2435000 property_id processed
# 2436000 property_id processed
# 2437000 property_id processed
# 2438000 property_id processed
# 2439000 property_id processed
# 2441000 property_id processed
# 2443000 property_id processed
# 2445000 property_id processed
# 2447000 property_id processed
# 2450000 property_id processed
# 2454000 property_id processed
# 2455000 property_id processed
# 2459000 property_id processed
# 2461000 property_id processed
# 2462000 property_id processed
# 2466000 property_id processed
# 2467000 property_id processed
# 2470000 property_id processed
# 2471000 property_id processed
# 2473000 property_id processed
# 2476000 property_id processed
# 2479000 property_id processed
# 2481000 property_id processed
# 2482000 property_id processed
# 2483000 property_id processed
# 2484000 property_id processed
# 2485000 property_id processed
# 2486000 property_id processed
# 2487000 property_id processed
# 2489000 property_id processed
# 2490000 property_id processed
# 2491000 property_id processed
# 2492000 property_id processed
# 2493000 property_id processed
# 2495000 property_id processed
# 2496000 property_id processed
# 2500000 property_id processed
# 2506000 property_id processed
# 2508000 property_id processed
# 2509000 property_id processed
# 2510000 property_id processed
# 2517000 property_id processed
# 2519000 property_id processed
# 2522000 property_id processed
# 2523000 property_id processed
# 2524000 property_id processed
# 2525000 property_id processed
# 2526000 property_id processed
# 2527000 property_id processed
# 2528000 property_id processed
# 2531000 property_id processed
# 2533000 property_id processed
# 2534000 property_id processed
# 2535000 property_id processed
# 2539000 property_id processed
# 2540000 property_id processed
# 2541000 property_id processed
# 2542000 property_id processed
# 2544000 property_id processed
# 2546000 property_id processed
# 2547000 property_id processed
# 2548000 property_id processed
# 2549000 property_id processed
# 2550000 property_id processed
# 2551000 property_id processed
# 2552000 property_id processed
# 2553000 property_id processed
# 2555000 property_id processed
# 2556000 property_id processed
# 2557000 property_id processed
# 2558000 property_id processed
# 2559000 property_id processed
# 2560000 property_id processed
# 2563000 property_id processed
# 2565000 property_id processed
# 2567000 property_id processed
# 2569000 property_id processed
# 2570000 property_id processed
# 2571000 property_id processed
# 2572000 property_id processed
# 2576000 property_id processed
# 2577000 property_id processed
# 2578000 property_id processed
# 2579000 property_id processed
# 2581000 property_id processed
# 2582000 property_id processed
# 2584000 property_id processed
# 2585000 property_id processed
# 2587000 property_id processed
# 2589000 property_id processed
# 2590000 property_id processed
# 2591000 property_id processed
# 2592000 property_id processed
# 2593000 property_id processed
# 2595000 property_id processed
# 2597000 property_id processed
# 2598000 property_id processed
# 2599000 property_id processed
# 2600000 property_id processed
# 2602000 property_id processed
# 2605000 property_id processed
# 2609000 property_id processed
# 2610000 property_id processed
# 2618000 property_id processed
# 2620000 property_id processed
# 2622000 property_id processed
# 2623000 property_id processed
# 2624000 property_id processed
# 2625000 property_id processed
# 2626000 property_id processed
# 2627000 property_id processed
# 2628000 property_id processed
# 2631000 property_id processed
# 2632000 property_id processed
# 2633000 property_id processed
# 2635000 property_id processed
# 2636000 property_id processed
# 2642000 property_id processed
# 2644000 property_id processed
# 2647000 property_id processed
# 2651000 property_id processed
# 2653000 property_id processed
# 2655000 property_id processed
# 2656000 property_id processed
# 2657000 property_id processed
# 2658000 property_id processed
# 2663000 property_id processed
# 2667000 property_id processed
# 2668000 property_id processed
# 2669000 property_id processed
# 2671000 property_id processed
# 2672000 property_id processed
# 2673000 property_id processed
# 2674000 property_id processed
# 2675000 property_id processed
# 2679000 property_id processed
# 2680000 property_id processed
# 2682000 property_id processed
# 2683000 property_id processed
# 2687000 property_id processed
# 2688000 property_id processed
# 2689000 property_id processed
# 2691000 property_id processed
# 2694000 property_id processed
# 2695000 property_id processed
# 2696000 property_id processed
# 2697000 property_id processed
# 2698000 property_id processed
# 2699000 property_id processed
# 2700000 property_id processed
# 2701000 property_id processed
# 2702000 property_id processed
# 2703000 property_id processed
# 2704000 property_id processed
# 2706000 property_id processed
# 2707000 property_id processed
# 2712000 property_id processed
# 2713000 property_id processed
# 2715000 property_id processed
# 2717000 property_id processed
# 2718000 property_id processed
# 2719000 property_id processed
# 2723000 property_id processed
# 2724000 property_id processed
# 2726000 property_id processed
# 2727000 property_id processed
# 2730000 property_id processed
# 2732000 property_id processed
# 2733000 property_id processed
# 2737000 property_id processed
# 2738000 property_id processed
# 2739000 property_id processed
# 2741000 property_id processed
# 2745000 property_id processed
# 2746000 property_id processed
# 2747000 property_id processed
# 2749000 property_id processed
# 2750000 property_id processed
# 2753000 property_id processed
# 2754000 property_id processed
# 2756000 property_id processed
# 2758000 property_id processed
# 2761000 property_id processed
# 2764000 property_id processed
# 2766000 property_id processed
# 2767000 property_id processed
# 2768000 property_id processed
# 2770000 property_id processed
# 2772000 property_id processed
# 2777000 property_id processed
# 2781000 property_id processed
# 2784000 property_id processed
# 2785000 property_id processed
# 2787000 property_id processed
# 2790000 property_id processed
# 2793000 property_id processed
# 2796000 property_id processed
# 2797000 property_id processed
# 2799000 property_id processed
# 2801000 property_id processed
# 2802000 property_id processed
# 2805000 property_id processed
# 2806000 property_id processed
# 2809000 property_id processed
# 2810000 property_id processed
# 2811000 property_id processed
# 2814000 property_id processed
# 2816000 property_id processed
# 2817000 property_id processed
# 2825000 property_id processed
# 2829000 property_id processed
# 2830000 property_id processed
# 2831000 property_id processed
# 2833000 property_id processed
# 2839000 property_id processed
# 2840000 property_id processed
# 2842000 property_id processed
# 2845000 property_id processed
# 2847000 property_id processed
# 2848000 property_id processed
# 2849000 property_id processed
# 2850000 property_id processed
# 2853000 property_id processed
# 2854000 property_id processed
# 2856000 property_id processed
# 2857000 property_id processed
# 2858000 property_id processed
# 2859000 property_id processed
# 2860000 property_id processed
# 2862000 property_id processed
# 2866000 property_id processed
# 2867000 property_id processed
# 2868000 property_id processed
# 2871000 property_id processed
# 2872000 property_id processed
# 2873000 property_id processed
# 2874000 property_id processed
# 2876000 property_id processed
# 2880000 property_id processed
# 2881000 property_id processed
# 2882000 property_id processed
# 2886000 property_id processed
# 2888000 property_id processed
# 2889000 property_id processed
# 2901000 property_id processed
# 2902000 property_id processed
# 2904000 property_id processed
# 2906000 property_id processed
# 2907000 property_id processed
# 2908000 property_id processed
# 2909000 property_id processed
# 2910000 property_id processed
# 2912000 property_id processed
# 2913000 property_id processed
# 2914000 property_id processed
# 2915000 property_id processed
# 2916000 property_id processed
# 2917000 property_id processed
# 2921000 property_id processed
# 2923000 property_id processed
# 2924000 property_id processed
# 2925000 property_id processed
# 2926000 property_id processed
# 2928000 property_id processed
# 2931000 property_id processed
# 2934000 property_id processed
# 2935000 property_id processed
# 2936000 property_id processed
# 2937000 property_id processed
# 2938000 property_id processed
# 2939000 property_id processed
# 2940000 property_id processed
# 2941000 property_id processed
# 2942000 property_id processed
# 2943000 property_id processed
# 2944000 property_id processed
# 2945000 property_id processed
# 2946000 property_id processed
# 2950000 property_id processed
# 2951000 property_id processed
# 2952000 property_id processed
# 2953000 property_id processed
# 2956000 property_id processed
# 2961000 property_id processed
# 2967000 property_id processed
# 2968000 property_id processed
# 2969000 property_id processed
# 2970000 property_id processed
# 2972000 property_id processed
# 2973000 property_id processed
# 2974000 property_id processed
# 2975000 property_id processed
# 2982000 property_id processed
# 2983000 property_id processed
# 2985000 property_id processed
# 2986000 property_id processed
# 2987000 property_id processed
# 2988000 property_id processed
# 2989000 property_id processed
# 2990000 property_id processed
# 2995000 property_id processed
# 3001000 property_id processed
# 3002000 property_id processed
# 3008000 property_id processed
# 3009000 property_id processed
# 3013000 property_id processed
# 3014000 property_id processed
# 3017000 property_id processed
# 3020000 property_id processed
# 3021000 property_id processed
# 3022000 property_id processed
# 3024000 property_id processed
# 3025000 property_id processed
# 3028000 property_id processed
# 3029000 property_id processed
# 3031000 property_id processed
# 3032000 property_id processed
# 3033000 property_id processed
# 3034000 property_id processed
# 3036000 property_id processed
# 3037000 property_id processed
# 3038000 property_id processed
# 3039000 property_id processed
# 3042000 property_id processed
# 3048000 property_id processed
# 3049000 property_id processed
# 3050000 property_id processed
# 3051000 property_id processed
# 3053000 property_id processed
# 3054000 property_id processed
# 3059000 property_id processed
# 3060000 property_id processed
# 3061000 property_id processed
# 3068000 property_id processed
# 3071000 property_id processed
# 3073000 property_id processed
# 3074000 property_id processed
# 3076000 property_id processed
# 3078000 property_id processed
# 3079000 property_id processed
# 3080000 property_id processed
# 3082000 property_id processed
# 3083000 property_id processed
# 3084000 property_id processed
# 3085000 property_id processed
# 3086000 property_id processed
# 3087000 property_id processed
# 3088000 property_id processed
# 3090000 property_id processed
# 3092000 property_id processed
# 3093000 property_id processed
# 3094000 property_id processed
# 3097000 property_id processed
# 3099000 property_id processed
# 3100000 property_id processed
# 3102000 property_id processed
# 3108000 property_id processed
# 3111000 property_id processed
# 3115000 property_id processed
# 3116000 property_id processed
# 3118000 property_id processed
# 3119000 property_id processed
# 3120000 property_id processed
# 3121000 property_id processed
# 3123000 property_id processed
# 3124000 property_id processed
# 3125000 property_id processed
# 3126000 property_id processed
# 3127000 property_id processed
# 3128000 property_id processed
# 3129000 property_id processed
# 3130000 property_id processed
# 3131000 property_id processed
# 3135000 property_id processed
# 3136000 property_id processed
# 3140000 property_id processed
# 3141000 property_id processed
# 3142000 property_id processed
# 3143000 property_id processed
# 3144000 property_id processed
# 3145000 property_id processed
# 3146000 property_id processed
# 3149000 property_id processed
# 3150000 property_id processed
# 3151000 property_id processed
# 3153000 property_id processed
# 3154000 property_id processed
# 3155000 property_id processed
# 3157000 property_id processed
# 3158000 property_id processed
# 3161000 property_id processed
# 3163000 property_id processed
# 3166000 property_id processed
# 3167000 property_id processed
# 3168000 property_id processed
# 3169000 property_id processed
# 3170000 property_id processed
# 3174000 property_id processed
# 3175000 property_id processed
# 3176000 property_id processed
# 3177000 property_id processed
# 3180000 property_id processed
# 3183000 property_id processed
# 3187000 property_id processed
# 3191000 property_id processed
# 3192000 property_id processed
# 3193000 property_id processed
# 3194000 property_id processed
# 3198000 property_id processed
# 3199000 property_id processed
# 3201000 property_id processed
# 3203000 property_id processed
# 3204000 property_id processed
# 3205000 property_id processed
# 3206000 property_id processed
# 3207000 property_id processed
# 3213000 property_id processed
# 3214000 property_id processed
# 3215000 property_id processed
# 3216000 property_id processed
# 3219000 property_id processed
# 3221000 property_id processed
# 3223000 property_id processed
# 3225000 property_id processed
# 3226000 property_id processed
# 3227000 property_id processed
# 3228000 property_id processed
# 3229000 property_id processed
# 3230000 property_id processed
# 3234000 property_id processed
# 3235000 property_id processed
# 3236000 property_id processed
# 3237000 property_id processed
# 3238000 property_id processed
# 3239000 property_id processed
# 3240000 property_id processed
# 3241000 property_id processed
# 3244000 property_id processed
# 3246000 property_id processed
# 3247000 property_id processed
# 3249000 property_id processed
# 3250000 property_id processed
# 3251000 property_id processed
# 3254000 property_id processed
# 3255000 property_id processed
# 3256000 property_id processed
# 3257000 property_id processed
# 3258000 property_id processed
# 3259000 property_id processed
# 3260000 property_id processed
# 3262000 property_id processed
# 3265000 property_id processed
# 3269000 property_id processed
# 3272000 property_id processed
# 3273000 property_id processed
# 3274000 property_id processed
# 3277000 property_id processed
# 3278000 property_id processed
# 3280000 property_id processed
# 3281000 property_id processed
# 3283000 property_id processed
# 3286000 property_id processed
# 3287000 property_id processed
# 3291000 property_id processed
# 3292000 property_id processed
# 3294000 property_id processed
# 3297000 property_id processed
# 3299000 property_id processed
# 3300000 property_id processed
# 3302000 property_id processed
# 3303000 property_id processed
# 3304000 property_id processed
# 3306000 property_id processed
# 3310000 property_id processed
# 3312000 property_id processed
# 3314000 property_id processed
# 3316000 property_id processed
# 3317000 property_id processed
# 3318000 property_id processed
# 3319000 property_id processed
# 3320000 property_id processed
# 3323000 property_id processed
# 3324000 property_id processed
# 3325000 property_id processed
# 3326000 property_id processed
# 3328000 property_id processed
# 3329000 property_id processed
# 3330000 property_id processed
# 3331000 property_id processed
# 3332000 property_id processed
# 3335000 property_id processed
# 3336000 property_id processed
# 3337000 property_id processed
# 3339000 property_id processed
# 3340000 property_id processed
# 3341000 property_id processed
# 3342000 property_id processed
# 3343000 property_id processed
# 3345000 property_id processed
# 3346000 property_id processed
# 3348000 property_id processed
# 3353000 property_id processed
# 3355000 property_id processed
# 3360000 property_id processed
# 3361000 property_id processed
# 3364000 property_id processed
# 3365000 property_id processed
# 3366000 property_id processed
# 3370000 property_id processed
# 3371000 property_id processed
# 3374000 property_id processed
# 3376000 property_id processed
# 3378000 property_id processed
# 3379000 property_id processed
# 3380000 property_id processed
# 3385000 property_id processed
# 3387000 property_id processed
# 3388000 property_id processed
# 3389000 property_id processed
# 3390000 property_id processed
# 3391000 property_id processed
# 3395000 property_id processed
# 3398000 property_id processed
# 3400000 property_id processed
# 3402000 property_id processed
# 3405000 property_id processed
# 3409000 property_id processed
# 3412000 property_id processed
# 3414000 property_id processed
# 3416000 property_id processed
# 3417000 property_id processed
# 3418000 property_id processed
# 3419000 property_id processed
# 3420000 property_id processed
# 3421000 property_id processed
# 3423000 property_id processed
# 3424000 property_id processed
# 3426000 property_id processed
# 3427000 property_id processed
# 3429000 property_id processed
# 3432000 property_id processed
# 3433000 property_id processed
# 3435000 property_id processed
# 3436000 property_id processed
# 3437000 property_id processed
# 3438000 property_id processed
# 3440000 property_id processed
# 3443000 property_id processed
# 3448000 property_id processed
# 3449000 property_id processed
# 3451000 property_id processed
# 3455000 property_id processed
# 3460000 property_id processed
# 3462000 property_id processed
# 3465000 property_id processed
# 3466000 property_id processed
# 3467000 property_id processed
# 3468000 property_id processed
# 3470000 property_id processed
# 3472000 property_id processed
# 3476000 property_id processed
# 3477000 property_id processed
# 3478000 property_id processed
# 3480000 property_id processed
# 3481000 property_id processed
# 3483000 property_id processed
# 3484000 property_id processed
# 3485000 property_id processed
# 3487000 property_id processed
# 3488000 property_id processed
# 3491000 property_id processed
# 3495000 property_id processed
# 3498000 property_id processed
# 3501000 property_id processed
# 3502000 property_id processed
# 3506000 property_id processed
# 3511000 property_id processed
# 3513000 property_id processed
# 3519000 property_id processed
# 3520000 property_id processed
# 3528000 property_id processed
# 3530000 property_id processed
# 3532000 property_id processed
# 3533000 property_id processed
# 3534000 property_id processed
# 3535000 property_id processed
# 3537000 property_id processed
# 3539000 property_id processed
# 3541000 property_id processed
# 3549000 property_id processed
# 3560000 property_id processed
# 3561000 property_id processed
# 3562000 property_id processed
# 3563000 property_id processed
# 3565000 property_id processed
# 3569000 property_id processed
# 3570000 property_id processed
# 3571000 property_id processed
# 3573000 property_id processed
# 3574000 property_id processed
# 3575000 property_id processed
# 3576000 property_id processed
# 3578000 property_id processed
# 3581000 property_id processed
# 3584000 property_id processed
# 3585000 property_id processed
# 3588000 property_id processed
# 3591000 property_id processed
# 3593000 property_id processed
# 3595000 property_id processed
# 3597000 property_id processed
# 3598000 property_id processed
# 3599000 property_id processed
# 3601000 property_id processed
# 3602000 property_id processed
# 3605000 property_id processed
# 3606000 property_id processed
# 3607000 property_id processed
# 3608000 property_id processed
# 3609000 property_id processed
# 3610000 property_id processed
# 3614000 property_id processed
# 3615000 property_id processed
# 3617000 property_id processed
# 3618000 property_id processed
# 3619000 property_id processed
# 3620000 property_id processed
# 3621000 property_id processed
# 3622000 property_id processed
# 3623000 property_id processed
# 3624000 property_id processed
# 3625000 property_id processed
# 3626000 property_id processed
# 3627000 property_id processed
# 3628000 property_id processed
# 3629000 property_id processed
# 3632000 property_id processed
# 3633000 property_id processed
# 3635000 property_id processed
# 3636000 property_id processed
# 3637000 property_id processed
# 3638000 property_id processed
# 3640000 property_id processed
# 3642000 property_id processed
# 3644000 property_id processed
# 3646000 property_id processed
# 3647000 property_id processed
# 3650000 property_id processed
# 3652000 property_id processed
# 3653000 property_id processed
# 3656000 property_id processed
# 3657000 property_id processed
# 3659000 property_id processed
# 3661000 property_id processed
# 3662000 property_id processed
# 3667000 property_id processed
# 3670000 property_id processed
# 3674000 property_id processed
# 3675000 property_id processed
# 3676000 property_id processed
# 3677000 property_id processed
# 3678000 property_id processed
# 3679000 property_id processed
# 3681000 property_id processed
# 3682000 property_id processed
# 3683000 property_id processed
# 3686000 property_id processed
# 3687000 property_id processed
# 3689000 property_id processed
# 3693000 property_id processed
# 3696000 property_id processed
# 3708000 property_id processed
# 3710000 property_id processed
# 3715000 property_id processed
# 3716000 property_id processed
# 3718000 property_id processed
# 3720000 property_id processed
# 3722000 property_id processed
# 3723000 property_id processed
# 3724000 property_id processed
# 3726000 property_id processed
# 3728000 property_id processed
# 3729000 property_id processed
# 3732000 property_id processed
# 3734000 property_id processed
# 3735000 property_id processed
# 3737000 property_id processed
# 3738000 property_id processed
# 3739000 property_id processed
# 3741000 property_id processed
# 3743000 property_id processed
# 3744000 property_id processed
# 3748000 property_id processed
# 3751000 property_id processed
# 3755000 property_id processed
# 3756000 property_id processed
# 3757000 property_id processed
# 3759000 property_id processed
# 3763000 property_id processed
# 3764000 property_id processed
# 3765000 property_id processed
# 3766000 property_id processed
# 3767000 property_id processed
# 3768000 property_id processed
# 3769000 property_id processed
# 3770000 property_id processed
# 3771000 property_id processed
# 3772000 property_id processed
# 3774000 property_id processed
# 3776000 property_id processed
# 3780000 property_id processed
# 3781000 property_id processed
# 3784000 property_id processed
# 3787000 property_id processed
# 3789000 property_id processed
# 3793000 property_id processed
# 3796000 property_id processed
# 3798000 property_id processed
# 3800000 property_id processed
# 3801000 property_id processed
# 3802000 property_id processed
# 3805000 property_id processed
# 3808000 property_id processed
# 3811000 property_id processed
# 3812000 property_id processed
# 3813000 property_id processed
# 3814000 property_id processed
# 3815000 property_id processed
# 3816000 property_id processed
# 3817000 property_id processed
# 3818000 property_id processed
# 3820000 property_id processed
# 3821000 property_id processed
# 3824000 property_id processed
# 3825000 property_id processed
# 3826000 property_id processed
# 3830000 property_id processed
# 3835000 property_id processed
# 3836000 property_id processed
# 3838000 property_id processed
# 3842000 property_id processed
# 3844000 property_id processed
# 3845000 property_id processed
# 3847000 property_id processed
# 3848000 property_id processed
# 3853000 property_id processed
# 3854000 property_id processed
# 3856000 property_id processed
# 3857000 property_id processed
# 3858000 property_id processed
# 3859000 property_id processed
# 3862000 property_id processed
# 3863000 property_id processed
# 3864000 property_id processed
# 3865000 property_id processed
# 3868000 property_id processed
# 3869000 property_id processed
# 3873000 property_id processed
# 3874000 property_id processed
# 3875000 property_id processed
# 3876000 property_id processed
# 3879000 property_id processed
# 3880000 property_id processed
# 3882000 property_id processed
# 3886000 property_id processed
# 3888000 property_id processed
# 3893000 property_id processed
# 3896000 property_id processed
# 3897000 property_id processed
# 3900000 property_id processed
# 3902000 property_id processed
# 3905000 property_id processed
# 3906000 property_id processed
# 3908000 property_id processed
# 3909000 property_id processed
# 3910000 property_id processed
# 3914000 property_id processed
# 3915000 property_id processed
# 3916000 property_id processed
# 3917000 property_id processed
# 3918000 property_id processed
# 3919000 property_id processed
# 3924000 property_id processed
# 3927000 property_id processed
# 3930000 property_id processed
# 3932000 property_id processed
# 3933000 property_id processed
# 3934000 property_id processed
# 3940000 property_id processed
# 3945000 property_id processed
# 3947000 property_id processed
# 3948000 property_id processed
# 3951000 property_id processed
# 3952000 property_id processed
# 3954000 property_id processed
# 3958000 property_id processed
# 3959000 property_id processed
# 3960000 property_id processed
# 3961000 property_id processed
# 3962000 property_id processed
# 3967000 property_id processed
# 3968000 property_id processed
# 3969000 property_id processed
# 3970000 property_id processed
# 3971000 property_id processed
# 3973000 property_id processed
# 3974000 property_id processed
# 3979000 property_id processed
# 3980000 property_id processed
# 3983000 property_id processed
# 3986000 property_id processed
# 3987000 property_id processed
# 3991000 property_id processed
# 3992000 property_id processed
# 3994000 property_id processed
# 3997000 property_id processed
# 3998000 property_id processed
# 3999000 property_id processed
# 4001000 property_id processed
# 4002000 property_id processed
# 4003000 property_id processed
# 4004000 property_id processed
# 4006000 property_id processed
# 4007000 property_id processed
# 4008000 property_id processed
# 4009000 property_id processed
# 4010000 property_id processed
# 4011000 property_id processed
# 4012000 property_id processed
# 4013000 property_id processed
# 4014000 property_id processed
# 4015000 property_id processed
# 4016000 property_id processed
# 4017000 property_id processed
# 4019000 property_id processed
# 4020000 property_id processed
# 4021000 property_id processed
# 4022000 property_id processed
# 4023000 property_id processed
# 4025000 property_id processed
# 4027000 property_id processed
# 4029000 property_id processed
# 4031000 property_id processed
# 4033000 property_id processed
# 4034000 property_id processed
# 4035000 property_id processed
# 4037000 property_id processed
# 4038000 property_id processed
# 4039000 property_id processed
# 4040000 property_id processed
# 4044000 property_id processed
# 4045000 property_id processed
# 4046000 property_id processed
# 4047000 property_id processed
# 4048000 property_id processed
# 4049000 property_id processed
# 4050000 property_id processed
# 4051000 property_id processed
# 4052000 property_id processed
# 4053000 property_id processed
# 4054000 property_id processed
# 4055000 property_id processed
# 4056000 property_id processed
# 4057000 property_id processed
# 4058000 property_id processed
# 4059000 property_id processed
# 4060000 property_id processed
# 4061000 property_id processed
# 4062000 property_id processed
# 4063000 property_id processed
# 4064000 property_id processed
# 4065000 property_id processed
# 4067000 property_id processed
# 4068000 property_id processed
# 4071000 property_id processed
# 4072000 property_id processed
# 4073000 property_id processed
# 4075000 property_id processed
# 4076000 property_id processed
# 4078000 property_id processed
# 4079000 property_id processed
# 4080000 property_id processed
# 4081000 property_id processed
# 4082000 property_id processed
# 4083000 property_id processed
# 4084000 property_id processed
# 4085000 property_id processed
# 4086000 property_id processed
# 4087000 property_id processed
# 4088000 property_id processed
# 4089000 property_id processed
# 4090000 property_id processed
# 4091000 property_id processed
# 4094000 property_id processed
# 4096000 property_id processed
# 4101000 property_id processed
# 4103000 property_id processed
# 4104000 property_id processed
# 4105000 property_id processed
# 4107000 property_id processed
# 4108000 property_id processed
# 4109000 property_id processed
# 4110000 property_id processed
# 4112000 property_id processed
# 4113000 property_id processed
# 4115000 property_id processed

# %%
print(bad_ones)
# Out:
# [2284484, 2284787, 2284827, 2284847, 2284872, 2284959, 2284988, 2284989, 2285056, 2285267, 2285341, 2285410, 2285765, 2285810, 2285834, 2286140, 2286169, 2286255, 2286281, 2286395, 2286450, 2286587, 2287082, 2287211, 2287239, 2287242, 2287343, 2287438, 2287472, 2287743, 2287865, 2289239, 2289889, 2289982, 2290197, 2290207, 2290307, 2290353, 2290402, 2290412, 2290856, 2290933, 2291004, 2291009, 2291014, 2291051, 2291367, 2291422, 2291748, 2291790, 2292015, 2292057, 2292059, 2292076, 2292130, 2292172, 2292489, 2292771, 2292788, 2292948, 2292980, 2292984, 2293147, 2293242, 2293286, 2293480, 2293548, 2293623, 2294315, 2294938, 2295024, 2295028, 2295079, 2295174, 2295512, 2295629, 2295635, 2295923, 2295943, 2296157, 2296184, 2296275, 2296317, 2296320, 2296344, 2296434, 2296565, 2296746, 2296959, 2296992, 2297121, 2297201, 2297248, 2297881, 2297935, 2298009, 2298081, 2298092, 2298131, 2298155, 2298328, 2298335, 2298378, 2298424, 2298833, 2298869, 2299005, 2299374, 2299417, 2299464, 2299519, 2299567, 2299606, 2299863, 2300123, 2300136, 2300243, 2300248, 2300376, 2300514, 2301955, 2302073, 2302136, 2302315, 2302352, 2302362, 2302610, 2302682, 2302726, 2303002, 2303024, 2303216, 2303294, 2303368, 2303511, 2303525, 2303738, 2303919, 2303955, 2303958, 2304090, 2304100, 2304136, 2304549, 2304860, 2305082, 2305132, 2305168, 2305589, 2305932, 2306030, 2306098, 2306515, 2306606, 2306779, 2306788, 2306868, 2306921, 2306929, 2307305, 2307731, 2307732, 2309435, 2309574, 2309886, 2309931, 2309951, 2310046, 2310056, 2310224, 2310528, 2310576, 2310830, 2310963, 2310993, 2311002, 2311185, 2311283, 2311362, 2311507, 2311580, 2311782, 2311795, 2311923, 2312125, 2312134, 2312239, 2312388, 2312475, 2312545, 2312572, 2312597, 2312665, 2312789, 2312812, 2313166, 2313175, 2313274, 2313672, 2313721, 2313807, 2314014, 2314067, 2314071, 2314146, 2314178, 2314183, 2314193, 2314244, 2314285, 2314573, 2314730, 2314799, 2314817, 2314870, 2315178, 2315249, 2315278, 2315663, 2315705, 2315752, 2316897, 2316925, 2317188, 2317209, 2317295, 2317684, 2317923, 2317987, 2318003, 2318040, 2318127, 2318158, 2318160, 2318303, 2318346, 2318351, 2321122, 2321148, 2321230, 2321343, 2321436, 2321473, 2321474, 2322429, 2323082, 2323157, 2323200, 2323210, 2323229, 2323292, 2323582, 2323794, 2324060, 2324077, 2324116, 2324168, 2324281, 2324284, 2324293, 2325393, 2325595, 2325644, 2325758, 2325978, 2326013, 2326343, 2326390, 2326602, 2327113, 2327133, 2327146, 2327172, 2327612, 2327701, 2327713, 2327958, 2327971, 2328195, 2328436, 2328489, 2328531, 2328542, 2328652, 2328762, 2328963, 2329433, 2329784, 2329856, 2329869, 2329931, 2330066, 2330976, 2330987, 2331010, 2331012, 2331016, 2331025, 2331040, 2331042, 2331047, 2331066, 2331156, 2331188, 2331191, 2331200, 2331208, 2331217, 2331220, 2331256, 2331258, 2331279, 2331330, 2331332, 2331335, 2331352, 2331369, 2331386, 2331395, 2331415, 2331418, 2331440, 2331450, 2331452, 2331488, 2331492, 2331506, 2331508, 2331514, 2331531, 2331537, 2331544, 2331555, 2331561, 2331567, 2331579, 2331581, 2331583, 2331588, 2331593, 2331596, 2331604, 2331608, 2331610, 2331614, 2331615, 2331618, 2331620, 2331632, 2331635, 2331641, 2331644, 2331648, 2331653, 2331662, 2331664, 2331668, 2331673, 2331679, 2331680, 2331682, 2331693, 2331703, 2331716, 2331729, 2331734, 2331738, 2331740, 2331743, 2331745, 2331748, 2331751, 2331753, 2331757, 2331760, 2331767, 2331769, 2331770, 2331773, 2331778, 2331781, 2331790, 2331791, 2331794, 2331804, 2331808, 2331811, 2331813, 2331823, 2331827, 2331834, 2331835, 2331838, 2331845, 2331848, 2331850, 2331856, 2331859, 2331863, 2331868, 2331870, 2331874, 2331877, 2331878, 2331879, 2331881, 2331882, 2331883, 2331894, 2331895, 2331896, 2331901, 2331902, 2331911, 2331913, 2331920, 2331922, 2331939, 2331946, 2331959, 2331970, 2331971, 2331979, 2331984, 2331987, 2331988, 2331989, 2331996, 2332006, 2332010, 2332012, 2332021, 2332024, 2332025, 2332028, 2332041, 2332045, 2332053, 2332057, 2332063, 2332075, 2332076, 2332084, 2332085, 233 ...
