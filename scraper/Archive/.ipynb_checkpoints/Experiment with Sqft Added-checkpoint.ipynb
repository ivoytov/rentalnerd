# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# read data into a DataFrame
data = pd.read_csv('SF Listings - Ex Zillow.csv', index_col=0)
del data['Term']
del data['URL']
del data['Source']
del data['Rented']
data['Date'] = pd.to_datetime(data['Date'])
data.head()

# create year dummy variables (because date isn't very intuitive variable)
data["Year"] = pd.DatetimeIndex(data["Date"]).to_period('Y')

# create dummy variables using get_dummies, then exclude the first dummy column
year_dummies = pd.get_dummies(data.Year, prefix='Year').iloc[:, :-1]

# concatenate the dummy variable columns onto the original DataFrame (axis=0 means rows, axis=1 means columns)
data = pd.concat([data, year_dummies], axis=1)

data.head()

# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 4, sharey=True)
data.plot(kind='scatter', x='Bedrooms', y='Price', ax=axs[0], figsize=(16, 8))
data.plot(kind='scatter', x='Bathrooms', y='Price', ax=axs[1])
data.plot(kind='scatter', x='Sqft', y='Price', ax=axs[2])
data.plot(x='Date', y='Price', ax=axs[3])

# follow the usual sklearn pattern: import, instantiate, fit
from sklearn.linear_model import LinearRegression

# create X and y
feature_cols = list(set(data.columns) - set(['Year','Neighborhood','Date','Price']))

X = data[feature_cols]
y = data.Price

# instantiate, fit
lm = LinearRegression()
lm.fit(X, y)

# print coefficients
print lm.intercept_
zip(feature_cols, lm.coef_)

# create dummy variables using get_dummies, then exclude the first dummy column
area_dummies = pd.get_dummies(data.Neighborhood, prefix='Neighborhood').iloc[:, 1:]

# concatenate the dummy variable columns onto the original DataFrame (axis=0 means rows, axis=1 means columns)
data = pd.concat([data, area_dummies], axis=1)
data.head()

import numpy as np
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((lm.predict(X) - y) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % lm.score(X, y))

# create X and y
feature_cols = list(set(data.columns) - set(['Year','Neighborhood','Date','Price']))

X = data[feature_cols]
y = data.Price

# instantiate, fit
lm = LinearRegression()
lm.fit(X, y)

# print coefficients
print lm.intercept_
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((lm.predict(X) - y) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % lm.score(X, y))
zip(feature_cols, lm.coef_)

# calculate predictions for the data set and plot errors
predictions = lm.predict(X)
errors = predictions-y
errors.name = 'Error'
zip(data.index,y,predictions,errors)

# visualize the relationship between the features and the response using scatterplots
errors.sort()

errors.plot(kind='bar').get_xaxis().set_ticks([])

# show errors by neighborhood to see if there are any neighborhoods with funky differences

hooderrors = data[['Neighborhood']]
print "data size pre categories: " + `len(hooderrors)`

errors = predictions-y
errors.name = 'Error'

hooderrors = pd.concat([hooderrors,errors.abs()],axis=1)

hood_group = hooderrors.groupby('Neighborhood')
print "data size grouped: " + `len(hood_group)`

import numpy
def median(lst):
    return numpy.median(numpy.array(lst))

error_avg = hood_group.median()
error_avg.sort(columns='Error',ascending=False).plot(kind='bar')

# show errors by year to see if there are any years with funky differences

yearerrors = data[['Year']]

yearerrors = pd.concat([yearerrors,errors.abs()],axis=1)
print "data size pre categories: " + `len(yearerrors)`

year_group = yearerrors.groupby('Year')
print "data size grouped: " + `len(year_group)`
error_avg = year_group.mean()
error_avg.sort(columns='Error',ascending=False).plot(kind='bar')
# Out:
# 1194.19951666
# Residual sum of squares: 1447596.27
# Variance score: 0.54
# 1534.34070901
# Residual sum of squares: 884463.32
# Variance score: 0.72
# data size pre categories: 283
# data size grouped: 55
# data size pre categories: 283
# data size grouped: 5

# %%
# Out:
#                         Neighborhood  Bedrooms  Bathrooms  Price  Sqft  \
# Address
# 539 Octavia Street #9   Hayes Valley         0          1   1500   180
# 539 Octavia Street #11  Hayes Valley         0          1   1600   200
# 539 Octavia Street #14  Hayes Valley         0          1   1850   221
# 539 Octavia Street #12  Hayes Valley         0          1   1800   240
# 539 Octavia Street #13  Hayes Valley         0          1   1995   280
#
#                              Date  Year  Year_2011  Year_2012  Year_2013  \
# Address
# 539 Octavia Street #9  2015-03-18  2015          0          0          0
# 539 Octavia Street #11 2015-03-30  2015          0          0          0
# 539 Octavia Street #14 2015-05-14  2015          0          0          0
# 539 Octavia Street #12 2015-04-16  2015          0          0          0
# 539 Octavia Street #13 2015-02-01  2015          0          0          0
#
#                         Year_2014
# Address
# 539 Octavia Street #9           0
# 539 Octavia Street #11          0
# 539 Octavia Street #14          0
# 539 Octavia Street #12          0
# 539 Octavia Street #13          0

# %%
# Out:
# 1194.19951666
# [('Bathrooms', 941.70980691752243),
#  ('Sqft', 1.4589599071204451),
#  ('Bedrooms', 173.94502709052779),
#  (u'Year_2012', -1427.3587715699446),
#  (u'Year_2013', -579.03620604360958),
#  (u'Year_2011', -314.48180732188968),
#  (u'Year_2014', -326.97263956255318)]

# %%
# Out:
# Residual sum of squares: 1447596.27
# Variance score: 0.54

# %%
# Out:
#                         Neighborhood  Bedrooms  Bathrooms  Price  Sqft  \
# Address
# 539 Octavia Street #9   Hayes Valley         0          1   1500   180
# 539 Octavia Street #11  Hayes Valley         0          1   1600   200
# 539 Octavia Street #14  Hayes Valley         0          1   1850   221
# 539 Octavia Street #12  Hayes Valley         0          1   1800   240
# 539 Octavia Street #13  Hayes Valley         0          1   1995   280
#
#                              Date  Year  Year_2011  Year_2012  Year_2013  \
# Address
# 539 Octavia Street #9  2015-03-18  2015          0          0          0
# 539 Octavia Street #11 2015-03-30  2015          0          0          0
# 539 Octavia Street #14 2015-05-14  2015          0          0          0
# 539 Octavia Street #12 2015-04-16  2015          0          0          0
# 539 Octavia Street #13 2015-02-01  2015          0          0          0
#
#                                   ...             Neighborhood_South Beach  \
# Address                           ...
# 539 Octavia Street #9             ...                                    0
# 539 Octavia Street #11            ...                                    0
# 539 Octavia Street #14            ...                                    0
# 539 Octavia Street #12            ...                                    0
# 539 Octavia Street #13            ...                                    0
#
#                         Neighborhood_South Financial District  \
# Address
# 539 Octavia Street #9                                       0
# 539 Octavia Street #11                                      0
# 539 Octavia Street #14                                      0
# 539 Octavia Street #12                                      0
# 539 Octavia Street #13                                      0
#
#                         Neighborhood_Telegraph Hill  \
# Address
# 539 Octavia Street #9                             0
# 539 Octavia Street #11                            0
# 539 Octavia Street #14                            0
# 539 Octavia Street #12                            0
# 539 Octavia Street #13                            0
#
#                         Neighborhood_Van Ness-Civic Center  \
# Address
# 539 Octavia Street #9                                    0
# 539 Octavia Street #11                                   0
# 539 Octavia Street #14                                   0
# 539 Octavia Street #12                                   0
# 539 Octavia Street #13                                   0
#
#                         Neighborhood_Visitacion Valley  \
# Address
# 539 Octavia Street #9                                0
# 539 Octavia Street #11                               0
# 539 Octavia Street #14                               0
# 539 Octavia Street #12                               0
# 539 Octavia Street #13                               0
#
#                         Neighborhood_Walnut Creek  Neighborhood_West Oakland  \
# Address
# 539 Octavia Street #9                           0                          0
# 539 Octavia Street #11                          0                          0
# 539 Octavia Street #14                          0                          0
# 539 Octavia Street #12                          0                          0
# 539 Octavia Street #13                          0                          0
#
#                         Neighborhood_Western Addition  \
# Address
# 539 Octavia Street #9                               0
# 539 Octavia Street #11                              0
# 539 Octavia Street #14                              0
# 539 Octavia Street #12                              0
# 539 Octavia Street #13                              0
#
#                         Neighborhood_Westwood Park  Neighborhood_Yerba Buena
# Address
# 539 Octavia Street #9                            0                         0
# 539 Octavia Street #11                           0                         0
# 539 Octavia Street #14                           0                         0
# 539 Octavia Street #12                           0                         0
# 539 Octavia Street #13                           0                         0
#
# [5 rows x 65 columns]

# %%
# Out:
# 1534.34070901
# Residual sum of squares: 884463.32
# Variance score: 0.72
# [('Neighborhood_Buena Vista', -376.56763340606858),
#  ('Neighborhood_Nob Hill', 95.473457657430799),
#  ('Neighborhood_Mission Dolores', 263.34464558804029),
#  ('Neighborhood_Clarendon Heights', -1703.6040468732963),
#  ('Neighborhood_Golden Gate Heights', -115.50212018507807),
#  ('Neighborhood_Outer Richmond', -692.8592145928086),
#  ('Neighborhood_Bernal Heights', -1545.9223026724278),
#  ('Neighborhood_Westwood Park', -2408.8863638365515),
#  ('Neighborhood_Rincon Hill', 110.40055143144751),
#  ('Neighborhood_Oakland', -1888.5206630045132),
#  ('Neighborhood_Russian Hill', -1985.319597413597),
#  ('Neighborhood_South Beach', 33.521094446855273),
#  ('Neighborhood_Eureka Valley', -758.70911036372434),
#  ('Neighborhood_Downtown San Francisco', -763.10194151399855),
#  ('Neighborhood_North Beach', 729.53236144631546),
#  ('Neighborhood_Central Richmond', -1036.9001686806744),
#  ('Neighborhood_Excelsior', -761.44990781823242),
#  ('Bedrooms', 260.91010600469156),
#  ('Neighborhood_Visitacion Valley', -3114.988748185544),
#  ('Neighborhood_Pacifica', -2319.4869258717117),
#  ('Neighborhood_Duboce Triangle', -199.34974477109677),
#  ('Neighborhood_Lone Mountain', -1118.4757664815977),
#  ('Neighborhood_Hayes Valley', -827.61073041769271),
#  ('Neighborhood_Cole Valley-Parnassus Heights', -904.82402380160522),
#  ('Neighborhood_Dogpatch', -777.96594480129716),
#  ('Neighborhood_North Panhandle', 254.99708058479422),
#  ('Neighborhood_Pacific Heights', 68.746590238185831),
#  ('Neighborhood_Glen Park', -2263.3266433962967),
#  ('Sqft', 1.3632145279621222),
#  ('Neighborhood_Noe Valley', -199.64456831274566),
#  ('Neighborhood_Walnut Creek', -2103.8324906393395),
#  ('Neighborhood_Lower Pacific Heights', -736.31834916327375),
#  ('Neighborhood_Portola', -2341.8410790847784),
#  ('Neighborhood_North Waterfront', -323.90005648587066),
#  ('Neighborhood_Emeryville', -1644.8037766271948),
#  (u'Year_2013', -737.31355263245666),
#  ('Bathrooms', 1023.4837656070898),
#  ('Neighborhood_Bayview', -1627.2586337003436),
#  ('Neighborhood_Ingleside', -1906.2223351968419),
#  ('Neighborhood_Mission Bay', -225.13915218984977),
#  ('Neighborhood_Downtown', -1200.9665953090396),
#  ('Neighborhood_West Oakland', -1726.0257482377026),
#  ('Neighborhood_Telegraph Hill', 844.01718054853404),
#  ('Neighborhood_Eureka Valley-Dolores Heights', 35.821468235349016),
#  ('Neighborhood_Potrero Hill', -428.62325135021547),
#  ('Neighborhood_Western Addition', -696.70161789950907),
#  ('Neighborhood_Financial District', -234.4268030575206),
#  ('Neighborhood_South Financial District', 173.38596466967431),
#  ('Neighborhood_Van Ness-Civic Center', -1027.7504208913547),
#  ('Neighborhood_Downtown Oakland', -3054.8081378184283),
#  ('Neighborhood_Central Waterfront', -412.10458755881058),
#  ('Neighborhood_Candlestick Point', -2222.4032617631337),
#  (u'Year_2014', -384.17774797373806),
#  ('Neighborhood_Inner Mission', -280.56890889814747),
#  (u'Year_2012', -1800.5654154437311),
#  ('Neighborhood_Yerba Buena', 1469.3001808789322),
#  ('Neighborhood_Marina', 89.822893082218968),
#  (u'Year_2011', 29.695583104392682),
#  ('Neighborhood_Diamond Heights', -2020.7277746193947),
#  ('Neighborhood_SOMA', -325.90498314490128),
#  ('Neighborhood_Berkeley', -1352.6912228255387)]

# %%
# Out:
# []

# %%
# Out:
# data size pre categories: 283
# data size grouped: 55

# %%
# Out:
# data size pre categories: 283
# data size grouped: 5
