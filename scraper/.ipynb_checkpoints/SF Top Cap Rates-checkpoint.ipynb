# %%
# %load_ext sql
import datetime

import pandas as pd
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /usr/local/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %sql mysql://prod:nerd@52.2.153.189/rental_nerd
# Out:
# u'Connected: prod@rental_nerd'

# %%
result = %sql (SELECT \
properties.address, \
properties.bedrooms, \
properties.bathrooms, \
properties.sqft, \
properties.source, \
properties.origin_url, \
properties.longitude, \
properties.latitude, \
properties.elevation, \
properties.year_built, \
properties.garage, \
property_transactions.transaction_type, \
property_transaction_logs.price, \
property_transaction_logs.transaction_status, \
property_transaction_logs.days_on_market, \
property_transaction_logs.date_closed, \
property_transaction_logs.date_listed, \
neighborhoods.name as 'neighborhood', \
neighborhoods.id as 'nid', \
prediction_results.predicted_rent, \
neighborhoods.shapefile_source \
FROM \
properties, \
property_transactions, \
property_transaction_logs, \
property_neighborhoods, \
prediction_results, \
neighborhoods \
WHERE \
properties.id = property_transactions.property_id AND \
property_transactions.property_transaction_log_id = property_transaction_logs.id AND \
property_transactions.transaction_type = "sales" AND \
neighborhoods.shapefile_source = "PH" AND \
properties.id = property_neighborhoods.property_id AND \
prediction_results.id = property_neighborhoods.property_id AND \
property_neighborhoods.neighborhood_id = neighborhoods.id)
        
data = result.DataFrame()
# Out:
# 1244 rows affected.

# %%
df = data[(data.transaction_status != 'closed') &
     (data.price > 300000)][['address','sqft','neighborhood','predicted_rent','price','date_closed','origin_url']]


df.head(100)
# Out:
#                                             address  sqft  \
# 201               5426 N 26th St, Phoenix, AZ 85016  2416
# 204           3411 N Valencia Ln, Phoenix, AZ 85018  4700
# 208          4945 E Camelback Rd, Phoenix, AZ 85018  2960
# 210          4015 E Glenrosa Ave, Phoenix, AZ 85018  1890
# 215           5530 E Exeter Blvd, Phoenix, AZ 85018  3800
# 234         1815 E Minnezona Ave, Phoenix, AZ 85016  1960
# 293            4724 N 69th St, Scottsdale, AZ 85251  2260
# 457           3020 W Beautiful Ln, Laveen, AZ 85339  2450
# 764   3017 W Via De Pedro Miguel, Phoenix, AZ 85086  3936
# 768              28104 N 17th Dr, Phoenix, AZ 85085  2884
# 801            4722 W Lapenna Dr, Phoenix, AZ 85087  1978
# 837          4020 E Hashknife Rd, Phoenix, AZ 85050  3524
# 872        3631 E Summerhaven Dr, Phoenix, AZ 85044  1828
# 898               16018 S 4th St, Phoenix, AZ 85048  3111
# 899             16423 S 34th Way, Phoenix, AZ 85048  2298
# 905          2922 W Amberwood Dr, Phoenix, AZ 85045  4109
# 1033          10228 N 57th St, Scottsdale, AZ 85253  2649
# 1040            2015 E Eugie Ter, Phoenix, AZ 85022   900
# 1120          4409 W Lawler Loop, Phoenix, AZ 85083  5066
# 1234              4232 N 5th Ave, Phoenix, AZ 85013  2040
# 1040          http://www.zillow.com/homedetails/2015-E-Eugie-Ter-Phoenix-AZ-85022/2123608841_zpid/
# 1120          http://www.zillow.com/homedetails/4409-W-Lawler-Loop-Phoenix-AZ-85083/52426858_zpid/
# 1234               http://www.zillow.com/homedetails/4232-N-5th-Ave-Phoenix-AZ-85013/7770366_zpid/
# 1238              http://www.zillow.com/homedetails/725-W-Lewis-Ave-Phoenix-AZ-85007/7520832_zpid/

# %%
cap_rate = df.predicted_rent * 12 / df.price
cap_rate.name = 'cap_rate'
df = pd.concat([df,cap_rate],axis=1)

# %%
df = df.sort('cap_rate',ascending=0)
df['cap_rate'] = df['cap_rate'].map('{:,.2f}'.format)
cols = df.columns - ['origin_url']
df[cols].head(100)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: using '-' to provide set differences with Indexes is deprecated, use .difference()
#   app.launch_new_instance()
#                                             address cap_rate date_closed  \
# 1238             725 W Lewis Ave, Phoenix, AZ 85007     0.26        None
# 1040            2015 E Eugie Ter, Phoenix, AZ 85022     0.22        None
# 1120          4409 W Lawler Loop, Phoenix, AZ 85083     0.12        None
# 801            4722 W Lapenna Dr, Phoenix, AZ 85087     0.09        None
# 837          4020 E Hashknife Rd, Phoenix, AZ 85050     0.08        None
# 872        3631 E Summerhaven Dr, Phoenix, AZ 85044     0.07        None
# 210          4015 E Glenrosa Ave, Phoenix, AZ 85018     0.05        None
# 201               5426 N 26th St, Phoenix, AZ 85016     0.05        None
# 768              28104 N 17th Dr, Phoenix, AZ 85085     0.04        None
# 764   3017 W Via De Pedro Miguel, Phoenix, AZ 85086     0.04        None
# 898               16018 S 4th St, Phoenix, AZ 85048     0.04        None
# 457           3020 W Beautiful Ln, Laveen, AZ 85339     0.03        None
# 1033          10228 N 57th St, Scottsdale, AZ 85253     0.02        None
# 208          4945 E Camelback Rd, Phoenix, AZ 85018     0.02        None
# 905          2922 W Amberwood Dr, Phoenix, AZ 85045     0.02        None
# 293            4724 N 69th St, Scottsdale, AZ 85251     0.02        None
# 899             16423 S 34th Way, Phoenix, AZ 85048     0.02        None
# 215           5530 E Exeter Blvd, Phoenix, AZ 85018     0.02        None
# 204           3411 N Valencia Ln, Phoenix, AZ 85018     0.01        None
# 234         1815 E Minnezona Ave, Phoenix, AZ 85016     0.01        None
# 1234              4232 N 5th Ave, Phoenix, AZ 85013     0.00        None
#
#                neighborhood  predicted_rent     price  sqft
# 1238                Encanto        7648.310    350000  1895
# 1040        Paradise Valley        5914.000    330000   900
# 1120            Deer Valley        7894.860    810000  5066
# 801             New Village        2469.870    319000  1978
# 837             Desert View        3581.360    557800  3524
# 872   Ahwatukee Foothills 0        1715.090    308000  1828
# 210          Camelback East        1879.070    425000  1890
# 201          Camelback East        2265.880    575000  2416
# 768           North Gateway        1551.110    424610  2884
# 764           North Gateway        1265.320    349995  3936
