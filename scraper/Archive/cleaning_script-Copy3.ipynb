# %%
# %load_ext sql
# %sql mysql://prod:nerd@52.2.153.189/rental_nerd
# %config SqlMagic.feedback=False
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
query = %sql (\
    SELECT \
    id as 'property_id' \
    FROM \
    properties)

i = query.DataFrame().values

# %%
bad_ones = []
i = i[3000000:] # change based on what set of IDs you want

# %%
for property_id in i:
    property_id = property_id[0]
    if property_id % 1000 == 0:
        print("%i property_id processed" % property_id)
        
    query = %sql (\
        SELECT \
        ptl_1.property_id, \
        count(1) as 'bad_instances'\
        FROM \
        property_transaction_logs AS ptl_1, \
        property_transaction_logs AS ptl_2 \
        WHERE \
        ptl_1.`property_id`= ptl_2.`property_id` AND \
        ptl_1.`transaction_type` = ptl_2.`transaction_type` AND \
        ptl_1.id <> ptl_2.id \
        AND \
        ( \
        ( ptl_1.date_listed IS NOT NULL AND \
        ptl_2.date_listed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_1.date_listed < ptl_2.date_listed AND ptl_2.date_listed < ptl_1.date_closed \
        ) \
        OR \
        ( ptl_1.date_listed IS NOT NULL AND \
        ptl_2.date_closed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_1.date_listed < ptl_2.date_closed AND \
        ptl_2.date_closed < ptl_1.date_closed \
        ) \
         OR ( \
        ptl_1.date_listed IS NOT NULL AND \
        ptl_1.date_closed IS NOT NULL AND \
        ptl_2.date_listed IS NOT NULL AND \
        ptl_2.date_closed IS NOT NULL AND \
        ptl_1.date_listed > ptl_2.date_listed AND \
        ptl_1.date_closed < ptl_2.date_closed ) ) \
        AND \
        ptl_1.property_id = :property_id )
    
    if(query.DataFrame().bad_instances.ix[0] == 1):
        bad_ones.append(property_id)
        f = open('bad_instances_4mm.txt', 'a')
        print(property_id, file=f,flush=False)
        f.close()
# Out:
# 5796000 property_id processed
# 5797000 property_id processed
# 5799000 property_id processed
# 5801000 property_id processed
# 5802000 property_id processed
# 5809000 property_id processed
# 5813000 property_id processed
# 5814000 property_id processed
# 5818000 property_id processed
# 5820000 property_id processed
# 5822000 property_id processed
# 5824000 property_id processed
# 5826000 property_id processed
# 5828000 property_id processed
# 5831000 property_id processed
# 5832000 property_id processed
# 5833000 property_id processed
# 5836000 property_id processed
# 5840000 property_id processed
# 5841000 property_id processed
# 5843000 property_id processed
# 5844000 property_id processed
# 5845000 property_id processed
# 5849000 property_id processed
# 5850000 property_id processed
# 5851000 property_id processed
# 5856000 property_id processed
# 5858000 property_id processed
# 5860000 property_id processed
# 5861000 property_id processed
# 5862000 property_id processed
# 5865000 property_id processed
# 5867000 property_id processed
# 5873000 property_id processed
# 5876000 property_id processed
# 5878000 property_id processed
# 5879000 property_id processed
# 5880000 property_id processed
# 5881000 property_id processed
# 5882000 property_id processed
# 5885000 property_id processed
# 5895000 property_id processed
# 5896000 property_id processed
# 5898000 property_id processed
# 5899000 property_id processed
# 5900000 property_id processed
# 5901000 property_id processed
# 5902000 property_id processed
# 5903000 property_id processed
# 5905000 property_id processed
# 5906000 property_id processed
# 5907000 property_id processed
# 5909000 property_id processed
# 5915000 property_id processed
# 5916000 property_id processed
# 5917000 property_id processed
# 5918000 property_id processed
# 5919000 property_id processed
# 5920000 property_id processed
# 5922000 property_id processed
# 5923000 property_id processed
# 5926000 property_id processed
# 5927000 property_id processed
# 5929000 property_id processed
# 5931000 property_id processed
# 5933000 property_id processed
# 5935000 property_id processed
# 5936000 property_id processed
# 5937000 property_id processed
# 5938000 property_id processed
# 5939000 property_id processed
# 5942000 property_id processed
# 5943000 property_id processed
# 5944000 property_id processed
# 5945000 property_id processed
# 5947000 property_id processed
# 5948000 property_id processed
# 5949000 property_id processed
# 5951000 property_id processed
# 5953000 property_id processed
# 5954000 property_id processed
# 5955000 property_id processed
# 5960000 property_id processed
# 5964000 property_id processed
# 5966000 property_id processed
# 5967000 property_id processed
# 5968000 property_id processed
# 5969000 property_id processed
# 5970000 property_id processed
# 5971000 property_id processed
# 5972000 property_id processed
# 5973000 property_id processed
# 5974000 property_id processed
# 5976000 property_id processed
# 5977000 property_id processed
# 5978000 property_id processed
# 5981000 property_id processed
# 5984000 property_id processed
# 5988000 property_id processed
# 5989000 property_id processed
# 5992000 property_id processed
# 5993000 property_id processed
# 5995000 property_id processed
# 5997000 property_id processed
# 5998000 property_id processed
# 5999000 property_id processed
# 6000000 property_id processed
# 6004000 property_id processed
# 6005000 property_id processed
# 6006000 property_id processed
# 6007000 property_id processed
# 6008000 property_id processed
# 6010000 property_id processed
# 6012000 property_id processed
# 6013000 property_id processed
# 6015000 property_id processed
# 6017000 property_id processed
# 6019000 property_id processed
# 6020000 property_id processed
# 6024000 property_id processed
# 6027000 property_id processed
# 6028000 property_id processed
# 6031000 property_id processed
# 6035000 property_id processed
# 6036000 property_id processed
# 6037000 property_id processed
# 6040000 property_id processed
# 6041000 property_id processed
# 6043000 property_id processed
# 6049000 property_id processed
# 6051000 property_id processed
# 6055000 property_id processed
# 6057000 property_id processed
# 6058000 property_id processed
# 6059000 property_id processed
# 6061000 property_id processed
# 6062000 property_id processed
# 6063000 property_id processed
# 6066000 property_id processed
# 6067000 property_id processed
# 6068000 property_id processed
# 6069000 property_id processed
# 6071000 property_id processed
# 6072000 property_id processed
# 6075000 property_id processed
# 6077000 property_id processed
# 6079000 property_id processed
# 6082000 property_id processed
# 6083000 property_id processed
# 6084000 property_id processed
# 6085000 property_id processed
# 6086000 property_id processed
# 6087000 property_id processed
# 6089000 property_id processed
# 6091000 property_id processed
# 6093000 property_id processed
# 6094000 property_id processed
# 6095000 property_id processed
# 6101000 property_id processed
# 6103000 property_id processed
# 6104000 property_id processed
# 6105000 property_id processed
# 6107000 property_id processed
# 6108000 property_id processed
# 6110000 property_id processed
# 6111000 property_id processed
# 6113000 property_id processed
# 6115000 property_id processed
# 6118000 property_id processed
# 6119000 property_id processed
# 6120000 property_id processed
# 6121000 property_id processed
# 6123000 property_id processed
# 6125000 property_id processed
# 6127000 property_id processed
# 6128000 property_id processed
# 6129000 property_id processed
# 6137000 property_id processed
# 6138000 property_id processed
# 6139000 property_id processed
# 6140000 property_id processed
# 6141000 property_id processed
# 6142000 property_id processed
# 6143000 property_id processed
# 6145000 property_id processed
# 6146000 property_id processed
# 6147000 property_id processed
# 6148000 property_id processed
# 6149000 property_id processed
# 6151000 property_id processed
# 6152000 property_id processed
# 6153000 property_id processed
# 6154000 property_id processed
# 6155000 property_id processed
# 6156000 property_id processed
# 6157000 property_id processed
# 6159000 property_id processed
# 6160000 property_id processed
# 6161000 property_id processed
# 6163000 property_id processed
# 6164000 property_id processed
# 6168000 property_id processed
# 6169000 property_id processed
# 6170000 property_id processed
# 6172000 property_id processed
# 6173000 property_id processed
# 6175000 property_id processed
# 6176000 property_id processed
# 6178000 property_id processed
# 6182000 property_id processed
# 6183000 property_id processed
# 6184000 property_id processed
# 6185000 property_id processed
# 6186000 property_id processed
# 6188000 property_id processed
# 6189000 property_id processed
# 6190000 property_id processed
# 6191000 property_id processed
# 6192000 property_id processed
# 6193000 property_id processed
# 6194000 property_id processed
# 6195000 property_id processed
# 6198000 property_id processed
# 6199000 property_id processed
# 6200000 property_id processed
# 6202000 property_id processed
# 6207000 property_id processed
# 6208000 property_id processed
# 6209000 property_id processed
# 6210000 property_id processed
# 6211000 property_id processed
# 6212000 property_id processed
# 6214000 property_id processed
# 6215000 property_id processed
# 6217000 property_id processed
# 6218000 property_id processed
# 6219000 property_id processed
# 6221000 property_id processed
# 6225000 property_id processed
# 6230000 property_id processed
# 6232000 property_id processed
# 6233000 property_id processed
# 6234000 property_id processed
# 6236000 property_id processed
# 6244000 property_id processed
# 6249000 property_id processed
# 6251000 property_id processed
# 6256000 property_id processed
# 6259000 property_id processed
# 6260000 property_id processed
# 6264000 property_id processed
# 6265000 property_id processed
# 6267000 property_id processed
# 6270000 property_id processed
# 6272000 property_id processed
# 6273000 property_id processed
# 6274000 property_id processed
# 6275000 property_id processed
# 6276000 property_id processed
# 6279000 property_id processed
# 6280000 property_id processed
# 6283000 property_id processed
# 6284000 property_id processed
# 6287000 property_id processed
# 6291000 property_id processed
# 6295000 property_id processed
# 6297000 property_id processed
# 6298000 property_id processed
# 6300000 property_id processed
# 6302000 property_id processed
# 6305000 property_id processed
# 6307000 property_id processed
# 6312000 property_id processed
# 6313000 property_id processed
# 6314000 property_id processed
# 6315000 property_id processed
# 6316000 property_id processed
# 6318000 property_id processed
# 6320000 property_id processed
# 6322000 property_id processed
# 6324000 property_id processed
# 6326000 property_id processed
# 6331000 property_id processed
# 6333000 property_id processed
# 6334000 property_id processed
# 6335000 property_id processed
# 6336000 property_id processed
# 6340000 property_id processed
# 6343000 property_id processed
# 6345000 property_id processed
# 6347000 property_id processed
# 6348000 property_id processed
# 6349000 property_id processed
# 6350000 property_id processed
# 6352000 property_id processed
# 6354000 property_id processed
# 6356000 property_id processed
# 6357000 property_id processed
# 6358000 property_id processed
# 6360000 property_id processed
# 6362000 property_id processed
# 6363000 property_id processed
# 6364000 property_id processed
# 6366000 property_id processed
# 6367000 property_id processed
# 6369000 property_id processed
# 6370000 property_id processed
# 6371000 property_id processed
# 6372000 property_id processed
# 6373000 property_id processed
# 6374000 property_id processed
# 6377000 property_id processed
# 6380000 property_id processed
# 6381000 property_id processed
# 6382000 property_id processed
# 6383000 property_id processed
# 6384000 property_id processed
# 6385000 property_id processed
# 6386000 property_id processed
# 6387000 property_id processed
# 6389000 property_id processed
# 6390000 property_id processed
# 6391000 property_id processed
# 6392000 property_id processed
# 6399000 property_id processed
# 6401000 property_id processed
# 6402000 property_id processed
# 6403000 property_id processed
# 6404000 property_id processed
# 6405000 property_id processed
# 6407000 property_id processed
# 6412000 property_id processed
# 6414000 property_id processed
# 6417000 property_id processed
# 6420000 property_id processed
# 6421000 property_id processed
# 6422000 property_id processed
# 6423000 property_id processed
# 6424000 property_id processed
# 6425000 property_id processed
# 6427000 property_id processed
# 6428000 property_id processed
# 6429000 property_id processed
# 6430000 property_id processed
# 6431000 property_id processed
# 6432000 property_id processed
# 6433000 property_id processed
# 6435000 property_id processed
# 6436000 property_id processed
# 6437000 property_id processed
# 6438000 property_id processed
# 6439000 property_id processed
# 6442000 property_id processed
# 6445000 property_id processed
# 6446000 property_id processed
# 6447000 property_id processed
# 6448000 property_id processed
# 6450000 property_id processed
# 6451000 property_id processed
# 6452000 property_id processed
# 6453000 property_id processed
# 6457000 property_id processed
# 6458000 property_id processed
# 6461000 property_id processed
# 6465000 property_id processed
# 6466000 property_id processed
# 6470000 property_id processed
# 6472000 property_id processed
# 6478000 property_id processed
# 6481000 property_id processed
# 6482000 property_id processed
# 6483000 property_id processed
# 6484000 property_id processed
# 6485000 property_id processed
# 6486000 property_id processed
# 6487000 property_id processed
# 6490000 property_id processed
# 6492000 property_id processed
# 6498000 property_id processed
# 6500000 property_id processed
# 6509000 property_id processed
# 6512000 property_id processed
# 6513000 property_id processed
# 6514000 property_id processed
# 6516000 property_id processed
# 6517000 property_id processed
# 6520000 property_id processed
# 6521000 property_id processed
# 6522000 property_id processed
# 6525000 property_id processed
# 6527000 property_id processed
# 6530000 property_id processed
# 6533000 property_id processed
# 6535000 property_id processed
# 6536000 property_id processed
# 6539000 property_id processed
# 6540000 property_id processed
# 6542000 property_id processed
# 6543000 property_id processed
# 6544000 property_id processed
# 6546000 property_id processed
# 6549000 property_id processed
# 6551000 property_id processed
# 6552000 property_id processed
# 6554000 property_id processed
# 6555000 property_id processed
# 6557000 property_id processed
# 6558000 property_id processed
# 6559000 property_id processed
# 6560000 property_id processed
# 6562000 property_id processed
# 6567000 property_id processed
# 6569000 property_id processed
# 6570000 property_id processed
# 6576000 property_id processed
# 6577000 property_id processed
# 6578000 property_id processed
# 6579000 property_id processed
# 6586000 property_id processed
# 6587000 property_id processed
# 6591000 property_id processed
# 6592000 property_id processed
# 6593000 property_id processed
# 6597000 property_id processed
# 6598000 property_id processed
# 6599000 property_id processed
# 6600000 property_id processed
# 6602000 property_id processed
# 6603000 property_id processed
# 6604000 property_id processed
# 6606000 property_id processed
# 6607000 property_id processed
# 6608000 property_id processed
# 6612000 property_id processed
# 6613000 property_id processed
# 6616000 property_id processed
# 6617000 property_id processed
# 6618000 property_id processed
# 6619000 property_id processed
# 6622000 property_id processed
# 6630000 property_id processed
# 6638000 property_id processed
# 6640000 property_id processed
# 6641000 property_id processed
# 6642000 property_id processed
# 6645000 property_id processed
# 6659000 property_id processed
# 6660000 property_id processed
# 6661000 property_id processed
# 6662000 property_id processed
# 6663000 property_id processed
# 6664000 property_id processed
# 6666000 property_id processed
# 6668000 property_id processed
# 6669000 property_id processed
# 6670000 property_id processed
# 6674000 property_id processed
# 6675000 property_id processed
# 6677000 property_id processed
# 6678000 property_id processed
# 6679000 property_id processed
# 6680000 property_id processed
# 6681000 property_id processed
# 6683000 property_id processed
# 6685000 property_id processed
# 6688000 property_id processed
# 6690000 property_id processed
# 6692000 property_id processed
# 6693000 property_id processed
# 6700000 property_id processed
# 6702000 property_id processed
# 6705000 property_id processed
# 6707000 property_id processed
# 6708000 property_id processed
# 6709000 property_id processed
# 6710000 property_id processed
# 6712000 property_id processed
# 6714000 property_id processed
# 6716000 property_id processed
# 6718000 property_id processed
# 6719000 property_id processed
# 6720000 property_id processed
# 6722000 property_id processed
# 6723000 property_id processed
# 6728000 property_id processed
# 6729000 property_id processed
# 6731000 property_id processed
# 6734000 property_id processed
# 6738000 property_id processed
# 6740000 property_id processed
# 6741000 property_id processed
# 6749000 property_id processed
# 6752000 property_id processed
# 6756000 property_id processed
# 6757000 property_id processed
# 6759000 property_id processed
# 6760000 property_id processed
# 6762000 property_id processed
# 6766000 property_id processed
# 6767000 property_id processed
# 6768000 property_id processed
# 6773000 property_id processed
# 6775000 property_id processed
# 6776000 property_id processed
# 6777000 property_id processed
# 6782000 property_id processed
# 6784000 property_id processed
# 6786000 property_id processed
# 6788000 property_id processed
# 6789000 property_id processed
# 6790000 property_id processed
# 6791000 property_id processed
# 6794000 property_id processed
# 6796000 property_id processed
# 6797000 property_id processed
# 6800000 property_id processed
# 6802000 property_id processed
# 6805000 property_id processed
# 6808000 property_id processed
# 6809000 property_id processed
# 6813000 property_id processed
# 6815000 property_id processed
# 6816000 property_id processed
# 6817000 property_id processed
# 6818000 property_id processed
# 6819000 property_id processed
# 6824000 property_id processed
# 6828000 property_id processed
# 6830000 property_id processed
# 6834000 property_id processed
# 6835000 property_id processed
# 6836000 property_id processed
# 6837000 property_id processed
# 6838000 property_id processed
# 6839000 property_id processed
# 6840000 property_id processed
# 6841000 property_id processed
# 6843000 property_id processed
# 6845000 property_id processed
# 6846000 property_id processed
# 6847000 property_id processed
# 6848000 property_id processed
# 6849000 property_id processed
# 6851000 property_id processed
# 6854000 property_id processed
# 6857000 property_id processed
# 6858000 property_id processed
# 6861000 property_id processed
# 6862000 property_id processed
# 6864000 property_id processed
# 6866000 property_id processed
# 6868000 property_id processed
# 6869000 property_id processed
# 6873000 property_id processed
# 6877000 property_id processed
# 6878000 property_id processed
# 6880000 property_id processed
# 6883000 property_id processed
# 6885000 property_id processed
# 6886000 property_id processed
# 6887000 property_id processed
# 6888000 property_id processed
# 6891000 property_id processed
# 6893000 property_id processed
# 6894000 property_id processed
# 6896000 property_id processed
# 6897000 property_id processed
# 6899000 property_id processed
# 6914000 property_id processed
# 6915000 property_id processed
# 6917000 property_id processed
# 6918000 property_id processed
# 6919000 property_id processed
# 6921000 property_id processed
# 6922000 property_id processed
# 6923000 property_id processed
# 6924000 property_id processed
# 6926000 property_id processed
# 6927000 property_id processed
# 6929000 property_id processed
# 6933000 property_id processed
# 6936000 property_id processed
# 6937000 property_id processed
# 6938000 property_id processed
# 6942000 property_id processed
# 6943000 property_id processed
# 6944000 property_id processed
# 6948000 property_id processed
# 6950000 property_id processed
# 6951000 property_id processed
# 6952000 property_id processed
# 6953000 property_id processed
# 6954000 property_id processed
# 6956000 property_id processed
# 6959000 property_id processed
# 6962000 property_id processed
# 6963000 property_id processed
# 6964000 property_id processed
# 6967000 property_id processed
# 6972000 property_id processed
# 6978000 property_id processed
# 6984000 property_id processed
# 6987000 property_id processed
# 6990000 property_id processed
# 6991000 property_id processed
# 6994000 property_id processed
# 6997000 property_id processed
# 6998000 property_id processed
# 6999000 property_id processed
# 7000000 property_id processed
# 7004000 property_id processed
# 7005000 property_id processed
# 7006000 property_id processed
# 7007000 property_id processed
# 7008000 property_id processed
# 7011000 property_id processed
# 7017000 property_id processed
# 7020000 property_id processed
# 7027000 property_id processed
# 7028000 property_id processed
# 7030000 property_id processed
# 7033000 property_id processed
# 7034000 property_id processed
# 7035000 property_id processed
# 7036000 property_id processed
# 7040000 property_id processed
# 7041000 property_id processed
# 7042000 property_id processed
# 7044000 property_id processed
# 7046000 property_id processed
# 7047000 property_id processed
# 7049000 property_id processed
# 7050000 property_id processed
# 7051000 property_id processed
# 7052000 property_id processed
# 7054000 property_id processed
# 7055000 property_id processed
# 7057000 property_id processed
# 7060000 property_id processed
# 7062000 property_id processed
# 7064000 property_id processed
# 7071000 property_id processed
# 7074000 property_id processed
# 7084000 property_id processed
# 7087000 property_id processed
# 7088000 property_id processed
# 7091000 property_id processed
# 7093000 property_id processed
# 7094000 property_id processed
# 7095000 property_id processed
# 7096000 property_id processed
# 7102000 property_id processed
# 7110000 property_id processed
# 7111000 property_id processed
# 7115000 property_id processed
# 7116000 property_id processed
# 7119000 property_id processed
# 7122000 property_id processed
# 7127000 property_id processed
# 7129000 property_id processed
# 7137000 property_id processed
# 7139000 property_id processed
# 7143000 property_id processed
# 7148000 property_id processed
# 7153000 property_id processed
# 7156000 property_id processed
# 7159000 property_id processed
# 7160000 property_id processed
# 7163000 property_id processed
# 7166000 property_id processed
# 7167000 property_id processed
# 7168000 property_id processed
# 7169000 property_id processed
# 7172000 property_id processed
# 7176000 property_id processed
# 7177000 property_id processed
# 7178000 property_id processed
# 7179000 property_id processed
# 7180000 property_id processed
# 7181000 property_id processed
# 7182000 property_id processed
# 7185000 property_id processed
# 7189000 property_id processed
# 7194000 property_id processed
# 7196000 property_id processed
# 7198000 property_id processed
# 7199000 property_id processed
# 7200000 property_id processed
# 7203000 property_id processed
# 7204000 property_id processed
# 7205000 property_id processed
# 7206000 property_id processed
# 7207000 property_id processed
# 7209000 property_id processed
# 7210000 property_id processed
# 7211000 property_id processed
# 7215000 property_id processed
# 7217000 property_id processed
# 7222000 property_id processed
# 7224000 property_id processed
# 7225000 property_id processed
# 7228000 property_id processed
# 7229000 property_id processed
# 7230000 property_id processed
# 7231000 property_id processed
# 7233000 property_id processed
# 7235000 property_id processed
# 7238000 property_id processed
# 7240000 property_id processed
# 7243000 property_id processed
# 7246000 property_id processed
# 7248000 property_id processed
# 7251000 property_id processed
# 7252000 property_id processed
# 7253000 property_id processed
# 7254000 property_id processed
# 7255000 property_id processed
# 7256000 property_id processed
# 7258000 property_id processed
# 7262000 property_id processed
# 7263000 property_id processed
# 7265000 property_id processed
# 7267000 property_id processed
# 7268000 property_id processed
# 7272000 property_id processed
# 7273000 property_id processed
# 7274000 property_id processed
# 7275000 property_id processed
# 7276000 property_id processed
# 7277000 property_id processed
# 7278000 property_id processed
# 7279000 property_id processed
# 7280000 property_id processed
# 7282000 property_id processed
# 7285000 property_id processed
# 7287000 property_id processed
# 7288000 property_id processed
# 7290000 property_id processed
# 7291000 property_id processed
# 7293000 property_id processed
# 7296000 property_id processed
# 7298000 property_id processed
# 7300000 property_id processed
# 7301000 property_id processed
# 7305000 property_id processed
# 7307000 property_id processed
# 7310000 property_id processed
# 7311000 property_id processed
# 7315000 property_id processed
# 7320000 property_id processed
# 7323000 property_id processed
# 7324000 property_id processed
# 7326000 property_id processed
# 7331000 property_id processed
# 7333000 property_id processed
# 7334000 property_id processed
# 7335000 property_id processed
# 7337000 property_id processed
# 7338000 property_id processed
# 7339000 property_id processed
# 7340000 property_id processed
# 7342000 property_id processed
# 7344000 property_id processed
# 7346000 property_id processed
# 7348000 property_id processed
# 7349000 property_id processed
# 7353000 property_id processed
# 7358000 property_id processed
# 7359000 property_id processed
# 7361000 property_id processed
# 7363000 property_id processed
# 7364000 property_id processed
# 7365000 property_id processed
# 7366000 property_id processed
# 7367000 property_id processed
# 7368000 property_id processed
# 7369000 property_id processed
# 7371000 property_id processed
# 7372000 property_id processed
# 7381000 property_id processed
# 7383000 property_id processed
# 7387000 property_id processed
# 7392000 property_id processed
# 7395000 property_id processed
# 7401000 property_id processed
# 7403000 property_id processed
# 7404000 property_id processed
# 7409000 property_id processed
# 7414000 property_id processed
# 7415000 property_id processed
# 7416000 property_id processed
# 7417000 property_id processed
# 7418000 property_id processed
# 7421000 property_id processed
# 7422000 property_id processed
# 7424000 property_id processed
# 7427000 property_id processed
# 7429000 property_id processed
# 7430000 property_id processed
# 7432000 property_id processed
# 7434000 property_id processed
# 7435000 property_id processed
# 7437000 property_id processed
# 7439000 property_id processed
# 7441000 property_id processed
# 7442000 property_id processed
# 7443000 property_id processed
# 7447000 property_id processed
# 7448000 property_id processed
# 7452000 property_id processed
# 7456000 property_id processed
# 7459000 property_id processed
# 7460000 property_id processed
# 7461000 property_id processed
# 7463000 property_id processed
# 7464000 property_id processed
# 7479000 property_id processed
# 7481000 property_id processed
# 7484000 property_id processed
# 7497000 property_id processed
# 7499000 property_id processed
# 7508000 property_id processed
# 7512000 property_id processed
# 7539000 property_id processed
# 7562000 property_id processed
# 7775000 property_id processed
# 8028000 property_id processed
# 8786000 property_id processed
# 8884000 property_id processed
# 8924000 property_id processed
# 8926000 property_id processed
# 8945000 property_id processed
# 8946000 property_id processed
# 8947000 property_id processed
# 8948000 property_id processed
# 8949000 property_id processed
# 8950000 property_id processed
# 8951000 property_id processed

# %%
print(bad_ones)
# Out:
# [5801548, 5801558, 5801566, 5801581, 5801604, 5801612, 5801632, 5801666, 5801712, 5801755, 5801796, 5801797, 5801815, 5801818, 5801853, 5801854, 5801889, 5801893, 5801901, 5801902, 5801903, 5801928, 5801947, 5802019, 5802036, 5802141, 5802217, 5802226, 5802255, 5802282, 5802301, 5802342, 5802375, 5802392, 5802427, 5802460, 5802537, 5802538, 5802576, 5802606, 5802641, 5802661, 5802662, 5802669, 5802686, 5802703, 5802769, 5802842, 5802881, 5802968, 5802970, 5802997, 5803025, 5803077, 5803100, 5803170, 5803182, 5803225, 5803272, 5803301, 5803304, 5803305, 5803307, 5803324, 5803339, 5803354, 5803480, 5803535, 5803581, 5803649, 5803823, 5803891, 5803936, 5803981, 5804069, 5804295, 5804316, 5804341, 5804361, 5804378, 5804471, 5804508, 5804615, 5804628, 5804648, 5804657, 5804702, 5804708, 5804711, 5804774, 5804794, 5804832, 5804845, 5804879, 5804880, 5804935, 5804938, 5804970, 5805015, 5805040, 5805092, 5805107, 5805109, 5805179, 5805186, 5805202, 5805236, 5805258, 5805407, 5805410, 5805435, 5805524, 5805774, 5805780, 5805806, 5805817, 5805843, 5805886, 5805973, 5806003, 5806051, 5806067, 5806074, 5806176, 5806256, 5806349, 5806375, 5806405, 5806451, 5806456, 5806457, 5806468, 5806478, 5806481, 5806491, 5806540, 5806541, 5806562, 5806571, 5806572, 5806597, 5806640, 5806681, 5806695, 5806705, 5806777, 5806810, 5806823, 5806846, 5806904, 5806961, 5807018, 5807041, 5807069, 5807146, 5807176, 5807181, 5807184, 5807281, 5809089, 5809244, 5809266, 5809519, 5809523, 5809552, 5809577, 5809638, 5809650, 5809755, 5809824, 5809844, 5809864, 5809874, 5809912, 5809941, 5809952, 5809964, 5809982, 5810068, 5810071, 5810135, 5810154, 5810164, 5810204, 5810281, 5810284, 5810341, 5810356, 5810380, 5810407, 5810427, 5810474, 5810514, 5810526, 5810533, 5810534, 5810591, 5810610, 5810712, 5810726, 5810758, 5810803, 5810855, 5810857, 5810915, 5810987, 5811049, 5811093, 5811130, 5814932, 5822467, 5825646, 5825662, 5825691, 5825698, 5825710, 5825747, 5825767, 5825850, 5825903, 5825916, 5825936, 5825941, 5826002, 5826032, 5826040, 5826067, 5826071, 5826083, 5826099, 5826198, 5826225, 5826285, 5826293, 5826296, 5826314, 5826353, 5826367, 5826392, 5826400, 5826405, 5826411, 5826443, 5826484, 5826526, 5826530, 5826542, 5826618, 5826666, 5826710, 5826740, 5826747, 5826819, 5826827, 5826837, 5826874, 5826945, 5826960, 5826961, 5827010, 5827031, 5827092, 5827094, 5827171, 5827190, 5827227, 5827228, 5827294, 5827295, 5827308, 5827355, 5827387, 5827395, 5827408, 5827423, 5827443, 5827478, 5827481, 5827483, 5827484, 5827485, 5827487, 5827490, 5827530, 5827624, 5827683, 5827711, 5827752, 5827759, 5827779, 5827781, 5827808, 5827813, 5827822, 5827823, 5827864, 5827880, 5827882, 5827900, 5827906, 5827916, 5827924, 5827928, 5827939, 5827984, 5828009, 5828017, 5828021, 5828043, 5828046, 5828080, 5828147, 5828148, 5828149, 5828155, 5828206, 5828215, 5828265, 5828323, 5828324, 5828329, 5828340, 5828350, 5828381, 5828383, 5828413, 5828482, 5828603, 5828652, 5828671, 5828702, 5828732, 5828909, 5828911, 5828945, 5828976, 5829042, 5829057, 5829059, 5829117, 5829143, 5829208, 5829220, 5829231, 5829254, 5829290, 5829307, 5829323, 5829334, 5829346, 5829382, 5829405, 5829413, 5829423, 5829434, 5829438, 5829455, 5829487, 5829542, 5829556, 5829588, 5829622, 5829725, 5829803, 5829807, 5829811, 5829891, 5829947, 5829950, 5829980, 5830016, 5830114, 5830167, 5830190, 5830209, 5830277, 5830353, 5830365, 5830396, 5830419, 5830445, 5830490, 5830506, 5830514, 5830555, 5830557, 5830560, 5830621, 5830635, 5830670, 5830734, 5830826, 5830852, 5830879, 5830908, 5837601, 5837633, 5837703, 5837726, 5837735, 5837777, 5837796, 5837809, 5837844, 5837848, 5837858, 5837881, 5837959, 5837990, 5837993, 5838001, 5838007, 5838014, 5838020, 5838085, 5838109, 5838135, 5838179, 5838210, 5838250, 5838255, 5838331, 5838362, 5838407, 5838431, 5838434, 5838456, 5838497, 5838540, 5838541, 5838640, 5838648, 5838661, 5838680, 5838705, 5838728, 5838743, 5838749, 5838758, 5838761, 5838820, 5838821, 5838838, 5838840, 583 ...
